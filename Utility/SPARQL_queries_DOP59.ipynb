# %% [markdown]
# # SPARQL Queries for Classes and Categories (DOP-59)
# ## Load data
# The following loads the TWONTO data from the turtle file and the required libraies for data processing.

# %%
from rdflib import Graph
import pandas as pd
g = Graph()
g.parse(r'../../GitHub/TWONTO/OWL/TWONTO.ttl')
# Out:
# <Graph identifier=N4c106827077149d3a9bc9d37ceefd998 (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# ## Class Query
# The following covers the code to query the turtle file for the class data. The scope of the assets are all the descendents of 'discrete asset' and 'system' with the following exclusions:
# 1. Assets with the 'tw:not_relevant_to_asset_or_maintenance_management' property 'true'
# 2. Assets with the 'tw:exclude_from_asset_class_list ' property 'true'
# 3. Assets with the 'owl:deprecated' property 'true'
#
# The output should have the following formatting:
#
# 1. Class name
# 2. Synonyms (comma seperated in multiple)
# 3. Class definition
# 4. Class IRI
# 5. Parent IRI

# %%
from collections import defaultdict
# --- SPARQL query ---
class_q = '''
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX tw: <http://www.toronto.ca/TWONTO#>

SELECT 
    (STR(?label) AS ?Class_name)
    (GROUP_CONCAT (DISTINCT(STR(COALESCE(?synonym, ""))); SEPARATOR=", ") AS ?Class_synonym)
    (STR(COALESCE(?def, "")) AS ?Class_definition)
    (STR(?sub) AS ?Class_IRI)
    (STR(?parent) AS ?Parent_IRI)
    (STR(COALESCE(?category, "")) AS ?Category)
    (STR(COALESCE(?defined_class, "")) AS ?Defined_class)
WHERE {     
    # ?sub rdfs:label ?label ;
        rdfs:subClassOf ?parent .
    # ?discrete_asset rdfs:label 'discrete asset' .
    # ?system rdfs:label 'system' .
    
    OPTIONAL { ?sub skos:altLabel ?synonym }
    OPTIONAL { ?sub rdfs:isDefinedBy ?def }
    OPTIONAL { ?sub tw:is_category_class ?category }
    OPTIONAL { ?sub tw:will_be_a_defined_class ?defined_class }
    
    FILTER NOT EXISTS { ?sub owl:deprecated "true"^^xsd:boolean }
    FILTER NOT EXISTS { ?sub tw:exclude_from_asset_class_list "true"^^xsd:boolean }
    FILTER NOT EXISTS { ?sub tw:not_relevant_to_AM_or_PM "true"^^xsd:boolean }

    # ?sub rdfs:subClassOf* ?ancestor .
    
    FILTER (?ancestor IN (
    <http://www.toronto.ca/TWONTO#00011>,
    <http://www.toronto.ca/TWONTO#00012>,
    <http://www.toronto.ca/TWONTO#00522>
    ))
}
GROUP BY ?label ?def ?sub ?parent
'''

# --- Execute query and build DataFrame ---
Class_name, Class_synonym, Class_definition, Class_IRI, Parent_IRI, Category, Defined_class = [], [], [], [], [], [], []
for x in g.query(class_q):
    Class_name.append(x['Class_name'].value)
    Class_synonym.append(x['Class_synonym'].value)
    Class_definition.append(x['Class_definition'].value)
    Class_IRI.append(x['Class_IRI'].value)
    Parent_IRI.append(x['Parent_IRI'].value)
    Category.append(x['Category'].value)
    Defined_class.append(x['Defined_class'].value)

Classes = pd.DataFrame({
    'Class name': Class_name,
    'Class synonym': Class_synonym,
    'Class definition': Class_definition,
    'Class IRI': Class_IRI,
    'Parent IRI': Parent_IRI,
    'Category': Category,
    'Defined class': Defined_class
})

# --- Normalize roots ---
ROOT_IDS = {
    'http://www.toronto.ca/TWONTO#00011',
    'http://www.toronto.ca/TWONTO#00012',
    'http://www.toronto.ca/TWONTO#00522'
}
Classes.loc[Classes['Class IRI'].isin(ROOT_IDS), 'Parent IRI'] = None

# --- Remove invalid parents ---
valid_ids = set(Classes['Class IRI'])
Classes = Classes[
    Classes['Parent IRI'].isna() |
    Classes['Parent IRI'].isin(valid_ids)
]

Classes.drop_duplicates(subset=['Class IRI'], inplace=True)
Classes.reset_index(drop=True, inplace=True)

# --- Build adjacency list ---
children = defaultdict(list)
for _, row in Classes.iterrows():
    children[row['Parent IRI']].append(row['Class IRI'])

# Sort children by readable name
iri_to_name = dict(zip(Classes['Class IRI'], Classes['Class name']))
for parent in children:
    children[parent].sort(key=lambda iri: iri_to_name.get(iri, '').lower())

# --- DFS to compute hierarchy ---
def build_paths(node_iri, path, results):
    for child in children.get(node_iri, []):
        name = iri_to_name[child]
        new_path = path + [name]
        results.append((child, " > ".join(new_path)))
        build_paths(child, new_path, results)

hierarchy_results = []
roots = Classes[Classes['Parent IRI'].isna()]['Class IRI'].tolist()
roots.sort(key=lambda iri: iri_to_name[iri].lower())

for root in roots:
    root_name = iri_to_name[root]
    hierarchy_results.append((root, root_name))  # root path
    build_paths(root, [root_name], hierarchy_results)

hierarchy_df = pd.DataFrame(hierarchy_results, columns=['Class IRI', 'Hierarchy Path'])
Classes = Classes.merge(hierarchy_df, on='Class IRI', how='left')

# --- Compute depth and indentation ---
Classes['Depth'] = Classes['Hierarchy Path'].apply(lambda p: len(p.split(" > ")) - 1 if isinstance(p, str) else 0)

def indent(name, depth):
    return ("    " * depth) + name

Classes['Class name'] = Classes.apply(
    lambda row: indent(row['Class name'], row['Depth']),
    axis=1
)

# --- Sort and save ---
Classes = Classes[['Class IRI','Depth','Class name','Class definition', 'Hierarchy Path', 'Category', 'Defined class', 'Class synonym']]
Classes['Class IRI'] = Classes['Class IRI'].str.replace('http://www.toronto.ca/TWONTO#','')
Classes = Classes.sort_values('Hierarchy Path')
Classes.to_csv('TWONTO_Classes.csv', index=False)

Classes
# Out:
#     Class IRI  Depth                                         Class name  \
# 62      00011      0                                     discrete asset
# 71      00105      1                                    DC power supply
# 309     00548      1                                                HMI
# 198     00321      1                                    HVAC evaporator
# 76      00115      1                                       ORP analyzer
# ..        ...    ...                                                ...
# 463     00932      2          water treatment facility intake structure
# 470     00943      2                      watercourse erosion structure
# 441     00805      2                         weather monitoring station
# 400     00715      1                      subsystem of a discrete asset
# 268     00434      2                                   hydraulic system
#
#                                       Class definition  \
# 62   An asset whose parts are unified, through phys...
# 71
# 309  A device that allows users to monitor, control...
# 198  A component that absorbs heat by allowing refr...
# 76
# ..                                                 ...
# 463
# 470
# 441
# 400  A subsystem of a discrete asset, which may or ...
# 268
#
#                                         Hierarchy Path Category Defined class  \
# 62                                      discrete asset     true
# 71                    discrete asset > DC power supply
# 309                               discrete asset > HMI
# 198                   discrete asset > HVAC evaporator
# 76                       discrete asset > ORP analyzer
# ..                                                 ...      ...           ...
# 463  system > localized function system > water tre...
# 470  system > localized function system > watercour...
# 441  system > localized function system > weather m...
# 400             system > subsystem of a discrete asset     true
# 268  system > subsystem of a discrete asset > hydra...
#
#                                          Class synonym
# 62
# 71
# 309  OIT, human machine interface, operator interfa...
# 198  AC indoor unit, air condition evaporator, evap...
# 76              oxidation-reduction potential analyzer
# ..                                                 ...
# 463
# 470
# 441
# 400
# 268
#
# [476 rows x 8 columns]

# %%
for x in g.query(class_q):
    print(x)
# Out:
# (rdflib.term.Literal('discrete asset'), rdflib.term.Literal(''), rdflib.term.Literal('An asset whose parts are unified, through physical integration, into a single object.'), rdflib.term.Literal('http://www.toronto.ca/TWONTO#00011'), rdflib.term.Literal('http://www.toronto.ca/TWONTO#00001'), rdflib.term.Literal('true'))
# (rdflib.term.Literal('system'), rdflib.term.Literal(''), rdflib.term.Literal('A collection of interrelated assets capable of some higher-order function.'), rdflib.term.Literal('http://www.toronto.ca/TWONTO#00012'), rdflib.term.Literal('http://www.toronto.ca/TWONTO#00001'), rdflib.term.Literal('true'))
# (rdflib.term.Literal('system'), rdflib.term.Literal(''), rdflib.term.Literal('A collection of interrelated assets capable of some higher-order function.'), rdflib.term.Literal('http://www.toronto.ca/TWONTO#00012'), rdflib.term.Literal('http://www.toronto.ca/TWONTO#00224'), rdflib.term.Literal('true'))
# (rdflib.term.Literal('distributed function system'), rdflib.term.Literal(''), rdflib.term.Literal('a system in a primary function is performed by assets occupying distinct positions that are distributed across different positions in its system topology.'), rdflib.term.Literal('http://www.toronto.ca/TWONTO#00016'), rdflib.term.Literal('http://www.toronto.ca/TWONTO#00012'), rdflib.term.Literal('true'))
# (rdflib.term.Literal('distributed system'), rdflib.term.Literal(''), rdflib.term.Literal(''), rdflib.term.Literal('http://www.toronto.ca/TWONTO#00282'), rdflib.term.Literal('http://www.toronto.ca/TWONTO#00016'), rdflib.term.Literal('true'))
# (rdflib.term.Literal('distribution system'), rdflib.term.Literal(''), rdflib.term.Literal('DRAFT: a system whose function is to distribute a resource from one or more sources to sites where they are needed.'), rdflib.term.Literal('http://www.toronto.ca/TWONTO#00283'), rdflib.term.Literal('http://www.toronto.ca/TWONTO#00016'), rdflib.term.Literal('true'))
# (rdflib.term.Literal('linear function structure'), rdflib.term.Literal(''), rdflib.term.Literal(''), rdflib.term.Literal('http://www.toronto.ca/TWONTO#00481'), rdflib.term.Literal('http://www.toronto.ca/TWONTO#00012'), rdflib.term.Literal('true'))
# (rdflib.term.Literal('subsystem of a discrete asset'), rdflib.term.Literal(''), rdflib.term.Literal('A subsystem of a discrete asset, which may or may not be a discrete asset or a localized function system.'), rdflib.term.Literal('http://www.toronto.ca/TWONTO#00715'), rdflib.term.Literal('http://www.toronto.ca/TWONTO#00012'), rdflib.term.Literal('true'))

# %% [markdown]
# ## Category Query
# The following covers the code to query the turtle file for the category data. The scope of the assets are all the descendents of 'member of a Toronto Water Broader Asset Category (MBC)' with the following exclusions:
# 1. Asset with the 'tw:is_category_class' property 'true'
# 1. Assets with the 'tw:not_relevant_to_asset_or_maintenance_management' property 'true'
# 2. Assets with the 'tw:exclude_from_asset_class_list ' property 'true'
# 3. Assets with the 'owl:deprecated' property 'true'
#
# The output should have the following formatting:
#
# 1. Class name
# 2. Synonyms (comma seperated in multiple)
# 3. Class definition
# 4. Class IRI
# 5. Parent IRI

# %%
cat_q ='''
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>  # Ensure SKOS is defined
PREFIX tw: <http://www.toronto.ca/TWONTO#>

SELECT 
    (STR(?label) AS ?Cat_name)
    (GROUP_CONCAT (DISTINCT(STR(COALESCE(?synonym, ""))); SEPARATOR=", ") AS ?Cat_synonym)  # If no synonym, return an empty string
    (STR(COALESCE(?def, "")) AS ?Cat_definition)   # If no definition, return an empty string
    (STR(?sub) AS ?Cat_IRI)
    (STR(?parent) AS ?Parent_IRI)  
WHERE {     
    # ?sub rdfs:label ?label ;
        rdfs:subClassOf ?parent .

    # ?MBC rdfs:label 'member of a Toronto Water Broader Asset Category (MBC)' .
    # ?sub rdfs:subClassOf+ ?MBC .
    # ?sub tw:is_category_class "true"^^xsd:boolean .

    OPTIONAL { ?sub skos:altLabel ?synonym }  # Synonym is optional
    OPTIONAL { ?sub rdfs:isDefinedBy ?def }   # Definition is optional
    
    FILTER NOT EXISTS { ?sub owl:deprecated "true"^^xsd:boolean }
    FILTER NOT EXISTS { ?sub tw:exclude_from_asset_class_list "true"^^xsd:boolean }
    FILTER NOT EXISTS { ?sub tw:not_relevant_to_asset_or_maintenance_management "true"^^xsd:boolean }
    
}
GROUP BY ?label ?def ?sub ?parent
'''
Cat_name, Cat_synonym, Cat_definition, Cat_IRI, Parent_IRI= [],[],[],[],[]

for x in g.query(cat_q):
    Cat_name.append(x['Cat_name'].value)
    Cat_synonym.append(x['Cat_synonym'].value)
    Cat_definition.append(x['Cat_definition'].value)
    Cat_IRI.append(x['Cat_IRI'].value)
    Parent_IRI.append(x['Parent_IRI'].value)

Cats = pd.DataFrame({'Cat_name':Cat_name,
'Cat_synonym':Cat_synonym,
'Cat_definition':Cat_definition,
'Cat_IRI':Cat_IRI,
'Parent_IRI':Parent_IRI})
Cats
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 42
#      40 Class_name, Class_synonym, Class_definition, Class_IRI, Parent_IRI = [], [], [], [], []
#      41 for x in g.query(class_q):
# ---> 42     Class_name.append(x['Class_name'].value)
#      43     Class_synonym.append(x['Class_synonym'].value)
#      44     Class_definition.append(x['Class_definition'].value)
#
# AttributeError: 'NoneType' object has no attribute 'value'
