# %% [markdown]
# # Avantis Mapping Instructions
#
# The following describes the process for mapping the current Avantis Classes to the new Classification system.

# %% [markdown]
# ## SQL connection
# The first step connects to the Avantis SQL server to get the list of entities

# %%
import pyodbc
import pandas as pd
import os
from sqlalchemy.engine import URL
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

connect = 'DSN=Avantis6-P;UID='+ os.environ['Avantis_User'] + ';PWD=' + os.environ['Avantis_Pass']
connection_url = URL.create("mssql+pyodbc", query={"odbc_connect": connect})

engine = create_engine(connection_url)

SQL1 = """SELECT Distinct MAINTENT.id as [Entity_number],
[MAINTENT].[aenm] as [Description],
MAINTENT2.id as [Parent],
MAINTENT2.aenm as [Parent_Description],
[contname] as [Category],
[entclsid] as [Class],
SUSPEND.suspoi as [Suspended]

FROM  [AvantisP].[mc].[MAINTENT]
	  Left Join [AvantisP].[mc].[ENTCLASS] on MAINTENT.entclsref_oi = ENTCLASS.entcloi
	  Left Join [AvantisP].[mc].CATVAL ON MAINTENT.cat1_oi = CATVAL.cvoi
	  Left Join MC.SUSPEND ON MAINTENT.susp_oi = SUSPEND.suspoi
	  Left Join MC.MELINK ON MAINTENT.mtnoi = MELINK.mtnchild_oi
	  Left Join MC.MAINTENT MAINTENT2 ON MELINK.mtnparn_oi = MAINTENT2.mtnoi
WHERE
    (SUSPEND.audt_updted_dttm <= '1900-01-01 23:59:59' OR SUSPEND.audt_updted_dttm IS NULL) AND
    (MAINTENT.okcost = 1)
"""


df = pd.read_sql(SQL1,engine)
df = df[df['Entity_number'].values != None]
df.head(10)
# Out:
#                Entity_number  \
# 0         \tFCL_ELS_CBL_001L
# 1         \tFCL_ELS_CBL_002D
# 2         \tFCL_ELS_CBL_002F
# 3         \tFCL_ELS_CBL_002H
# 4         \tFCL_ELS_CBL_002L
# 5       \tFCL_ELS_CBL_00B2-A
# 6         \tFCL_ELS_CBL_0100
# 7         \tFCL_ELS_CBL_0200
# 8         \tFCL_ELS_CBL_02CF
# 9                      17513
#
#                                          Description                Parent  \
# 0  Electrical Power Line,4.16KV,From BUS-00B1-A t...  FCL_ELS_4.16KV_LINES
# 1  Electrical Power Line,4.16KV,From BUS-00B2-A t...  FCL_ELS_4.16KV_LINES
# 2  Electrical Power Line,4.16KV,From BUS-00B2 to ...  FCL_ELS_4.16KV_LINES
# 3  Electrical Power Line,4.16KV,From BUS-00B1 to ...  FCL_ELS_4.16KV_LINES
# 4  Electrical Power Line,4.16KV,From BUS-00B2-A t...  FCL_ELS_4.16KV_LINES
# 5  Electrical Power Line,4.16KV,From BUS-00B2 to ...  FCL_ELS_4.16KV_LINES
# 6  Electrical Power Line,From BUS-00L1 to Transfo...  FCL_ELS_27.6KV_LINES
# 7  Electrical Power Line,From BUS-00L2 to Transfo...  FCL_ELS_27.6KV_LINES
# 8  Electrical Power Line,4.16KV,From BUS-00B2-A t...  FCL_ELS_4.16KV_LINES
# 9                               Piping, New Wet Well           TAB-DEW-WEL
#
#              Parent_Description           Category                  Class  \
# 0  Electrical Power Line,4.16KV  Air Handling Unit  Electrical Power Line
# 1  Electrical Power Line,4.16KV  Air Handling Unit  Electrical Power Line
# 2  Electrical Power Line,4.16KV  Air Handling Unit  Electrical Power Line
# 3  Electrical Power Line,4.16KV  Air Handling Unit  Electrical Power Line
# 4  Electrical Power Line,4.16KV  Air Handling Unit  Electrical Power Line
# 5  Electrical Power Line,4.16KV  Air Handling Unit  Electrical Power Line
# 6  Electrical Power Line,27.6KV  Air Handling Unit  Electrical Power Line
# 7  Electrical Power Line,27.6KV  Air Handling Unit  Electrical Power Line
# 8  Electrical Power Line,4.16KV  Air Handling Unit  Electrical Power Line
# 9            Centrate Wet Wells             Piping                 Piping
#
#   Suspended
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# 5      None
# 6      None
# 7      None
# 8      None
# 9      None

# %% [markdown]
# Here is were we capture the 13040 tag section if it is present in the entity number

# %%
import re

df_13040 = pd.read_excel('13040 Codes.xlsx', sheet_name='Append1')
dict_13040 = dict(zip(df_13040['CODE'], df_13040['DESCRIPTION']))

def extract_code(entity):
    # Use regex to match the third group between dashes
    match = re.match(r'^[^-]+-[^-]+-([^-]+)-[^-]+$', str(entity))
    return match.group(1) if match else None

def code_in_dict(code):
    return code if code in dict_13040 else None

df['Extracted_Code'] = df['Entity_number'].apply(extract_code)
df['Matched_Code'] = df['Extracted_Code'].apply(code_in_dict)
df.head(10)
# Out:
#                Entity_number  \
# 0         \tFCL_ELS_CBL_001L
# 1         \tFCL_ELS_CBL_002D
# 2         \tFCL_ELS_CBL_002F
# 3         \tFCL_ELS_CBL_002H
# 4         \tFCL_ELS_CBL_002L
# 5       \tFCL_ELS_CBL_00B2-A
# 6         \tFCL_ELS_CBL_0100
# 7         \tFCL_ELS_CBL_0200
# 8         \tFCL_ELS_CBL_02CF
# 9                      17513
#
#                                          Description                Parent  \
# 0  Electrical Power Line,4.16KV,From BUS-00B1-A t...  FCL_ELS_4.16KV_LINES
# 1  Electrical Power Line,4.16KV,From BUS-00B2-A t...  FCL_ELS_4.16KV_LINES
# 2  Electrical Power Line,4.16KV,From BUS-00B2 to ...  FCL_ELS_4.16KV_LINES
# 3  Electrical Power Line,4.16KV,From BUS-00B1 to ...  FCL_ELS_4.16KV_LINES
# 4  Electrical Power Line,4.16KV,From BUS-00B2-A t...  FCL_ELS_4.16KV_LINES
# 5  Electrical Power Line,4.16KV,From BUS-00B2 to ...  FCL_ELS_4.16KV_LINES
# 6  Electrical Power Line,From BUS-00L1 to Transfo...  FCL_ELS_27.6KV_LINES
# 7  Electrical Power Line,From BUS-00L2 to Transfo...  FCL_ELS_27.6KV_LINES
# 8  Electrical Power Line,4.16KV,From BUS-00B2-A t...  FCL_ELS_4.16KV_LINES
# 9                               Piping, New Wet Well           TAB-DEW-WEL
#
#              Parent_Description           Category                  Class  \
# 0  Electrical Power Line,4.16KV  Air Handling Unit  Electrical Power Line
# 1  Electrical Power Line,4.16KV  Air Handling Unit  Electrical Power Line
# 2  Electrical Power Line,4.16KV  Air Handling Unit  Electrical Power Line
# 3  Electrical Power Line,4.16KV  Air Handling Unit  Electrical Power Line
# 4  Electrical Power Line,4.16KV  Air Handling Unit  Electrical Power Line
# 5  Electrical Power Line,4.16KV  Air Handling Unit  Electrical Power Line
# 6  Electrical Power Line,27.6KV  Air Handling Unit  Electrical Power Line
# 7  Electrical Power Line,27.6KV  Air Handling Unit  Electrical Power Line
# 8  Electrical Power Line,4.16KV  Air Handling Unit  Electrical Power Line
# 9            Centrate Wet Wells             Piping                 Piping
#
#   Suspended Extracted_Code Matched_Code
# 0      None           None         None
# 1      None           None         None
# 2      None           None         None
# 3      None           None         None
# 4      None           None         None
# 5      None           None         None
# 6      None           None         None
# 7      None           None         None
# 8      None           None         None
# 9      None           None         None

# %% [markdown]
# ## SPARQL connection
# The following will now load the data from the OWL file

# %%
from rdflib import Graph
import pandas as pd

# Load the RDFS .ttl file into an RDFLib Graph
g = Graph()
g.parse(r"../TWONTO/OWL/TWONTO.ttl", format="turtle")

# Prepare a custom SPARQL query
query = """

PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX tw: <http://www.toronto.ca/TWONTO#>

SELECT DISTINCT ?label ?subject
       (COALESCE(?isEquivalentToCategory, "") AS ?isEquivalentToCategory)
       (COALESCE(?isEquivalentToClass, "") AS ?isEquivalentToClass)
       (COALESCE(?isSuperclassToCategory, "") AS ?isSuperclassToCategory)
       (COALESCE(?isSuperclassToClass, "") AS ?isSuperclassToClass)
       (COALESCE(?is_equivalent_to_tag_code, "") AS ?is_equivalent_to_tag_code)
       (COALESCE(?is_superclass_to_tag_code, "") AS ?is_superclass_to_tag_code)
WHERE {
  # ?subject rdfs:label ?label .

#  FILTER NOT EXISTS { ?subject owl:deprecated true }

#  ?assetClass rdfs:label "asset" .
#  ?subject rdfs:subClassOf+ ?assetClass .

  OPTIONAL { ?subject tw:is_equivalent_to_Avantis_category ?isEquivalentToCategory . }
  OPTIONAL { ?subject tw:is_equivalent_to_Avantis_class ?isEquivalentToClass . }
  OPTIONAL { ?subject tw:is_superclass_to_Avantis_category ?isSuperclassToCategory . }
  OPTIONAL { ?subject tw:is_superclass_to_Avantis_class ?isSuperclassToClass . }
  OPTIONAL { ?subject tw:is_equivalent_to_tag_code ?is_equivalent_to_tag_code . }
  OPTIONAL { ?subject tw:is_superclass_to_tag_code ?is_superclass_to_tag_code . }
}
"""

# Execute the query
results = g.query(query)

# Convert results to a DataFrame, do not replace None with empty string
data = []
for row in results:
    data.append([
        str(row.label) if row.label else None,
        str(row.subject) if row.subject else None,
        str(row.isEquivalentToCategory) if row.isEquivalentToCategory else None,
        str(row.isEquivalentToClass) if row.isEquivalentToClass else None,
        str(row.isSuperclassToCategory) if row.isSuperclassToCategory else None,
        str(row.isSuperclassToClass) if row.isSuperclassToClass else None,
        str(row.is_equivalent_to_tag_code) if row.is_equivalent_to_tag_code else None,
        str(row.is_superclass_to_tag_code) if row.is_superclass_to_tag_code else None
    ])

df_sparql = pd.DataFrame(data, columns=[
    "label",
    "subject",
    "isEquivalentToCategory",
    "isEquivalentToClass",
    "isSuperclassToCategory",
    "isSuperclassToClass",
    "is_equivalent_to_tag_code",
    "is_superclass_to_tag_code"
])

df_sparql.head(10)
# Out:
#                              label  \
# 0          new_13040_code_proposed
# 1                         contains
# 2                          created
# 3                    fully grounds
# 4                          grounds
# 5                          grounds
# 6  has boiler heating surface area
# 7                 has content part
# 8              has earlier version
# 9                has later version
#
#                                              subject isEquivalentToCategory  \
# 0  http://www.toronto.ca/TWONTO#new_13040_code_pr...                   None
# 1                 http://www.toronto.ca/TWONTO#00865                   None
# 2                 http://www.toronto.ca/TWONTO#00866                   None
# 3                 http://www.toronto.ca/TWONTO#00867                   None
# 4                 http://www.toronto.ca/TWONTO#00868                   None
# 5                 http://www.toronto.ca/TWONTO#00407                   None
# 6                 http://www.toronto.ca/TWONTO#00869                   None
# 7                 http://www.toronto.ca/TWONTO#00870                   None
# 8                 http://www.toronto.ca/TWONTO#00871                   None
# 9                 http://www.toronto.ca/TWONTO#00872                   None
#
#   isEquivalentToClass isSuperclassToCategory isSuperclassToClass  \
# 0                None                   None                None
# 1                None                   None                None
# 2                None                   None                None
# 3                None                   None                None
# 4                None                   None                None
# 5                None                   None                None
# 6                None                   None                None
# 7                None                   None                None
# 8                None                   None                None
# 9                None                   None                None
#
#   is_equivalent_to_tag_code is_superclass_to_tag_code
# 0                      None                      None
# 1                      None                      None
# 2                      None                      None
# 3                      None                      None
# 4                      None                      None
# 5                      None                      None
# 6                      None                      None
# 7                      None                      None
# 8                      None                      None
# 9                      None                      None

# %% [markdown]
# Now to create the dictionary items for easy lookup later

# %%
dict_class = {k: v for k, v in zip(df_sparql['isEquivalentToClass'], df_sparql['label']) if k is not None}
dict_superclass = {k: v for k, v in zip(df_sparql['isSuperclassToClass'], df_sparql['label']) if k is not None}
dict_category = {k: v for k, v in zip(df_sparql['isEquivalentToCategory'], df_sparql['label']) if k is not None}
dict_supercategory = {k: v for k, v in zip(df_sparql['isSuperclassToCategory'], df_sparql['label']) if k is not None}
dict_tag = {k: v for k, v in zip(df_sparql['is_equivalent_to_tag_code'], df_sparql['label']) if k is not None}
dict_supertag = {k: v for k, v in zip(df_sparql['is_superclass_to_tag_code'], df_sparql['label']) if k is not None}
dict_iri = {k: v for k, v in zip(df_sparql['subject'], df_sparql['label']) if k is not None}
dict_iri['x'] = 'unknown'

for key, value in list(dict_class.items())[:10]:
    print(f"Avantis Class: {key} -> New Class: {value}")
# Out:
# Avantis Class: Vehicle -> New Class: passenger vehicle
# Avantis Class: Fan -> New Class: fan
# Avantis Class: Structure -> New Class: structure
# Avantis Class: Power Supply Unit -> New Class: DC power supply
# Avantis Class: Programmable Logic Control -> New Class: PLC
# Avantis Class: Remote Processor Unit -> New Class: RPU panel
# Avantis Class: Remote Transmission Unit -> New Class: RPU panel
# Avantis Class: Uninterruptible Power Supply -> New Class: UPS
# Avantis Class: Ultraviolet Disinfection -> New Class: UV disinfection assembly
# Avantis Class: Variable Frequency Drive -> New Class: VFD

# %% [markdown]
# ## Manual Matching
# Here we will load the manual matched file

# %%
df_manual = pd.read_excel('manualMatch.xlsx', sheet_name='LLM capability Test Dataset')
df['Entity_number'] = df['Entity_number'].astype(str).str.strip()
df_manual.head(10)
# Out:
#          ID      Entity_number  \
# 0  104978.0            NX5232A
# 1  119738.0    TAB-WA1-SQ-1984
# 2   59232.0   THC-ACC-HTR-6025
# 3  119966.0    TAB-WA4-SQ-3430
# 4   59390.0  THC-ACC-PDIT-6291
# 5   76870.0   THR-PLT-FSL-2222
# 6  119721.0    TAB-WA1-SQ-1915
# 7   76217.0    THR-MCS-LD-9868
# 8   52817.0  TAB-RSP-FSL-1221D
# 9   79780.0    THR-WA1-LD-0051
#
#                                          Description            Parent  \
# 0                    Chiller, Silo Bldg Control Room        TAB-ACC-CI
# 1      Lanyard  6 Ft- Velasco, Gabriel\t\t\t\t\t\t\t   TAB-WA1-SQ-0001
# 2  Heater, Unit, Electric, Heating System, Lower ...  THC-ELS-LP-4042A
# 3                          Fall Limiter - MFLT2/705F   TAB-WA4-SQ-0010
# 4  Transmitter, Pressure Differential, Filter F-6...    THC-ACC-F-6291
# 5  Switch, Flow, Low, Water Scour, Aerated Grit T...    THR-PLT-T-0300
# 6                 Body Harness Xlarge- Hitish Mistry   TAB-WA1-SQ-0001
# 7                            Come Along, Work Area 2        THR-LD-WA2
# 8  Flow Switch, Low, Cooling Water Supply to Heat...    TAB-RSP-P-1220
# 9  Sling, Nylon, Work Area 1 (NYLON BELT SLING SI...   THR-LD-NYLN-WA1
#
#                Category             Class  Suspended   Tag  \
# 0      H.V.A.C.,Chiller              HVAC        NaN   NaN
# 1           PPE,Harness  Safety Equipment        NaN    SQ
# 2  H.V.A.C.,Heater,Unit              HVAC        NaN   HTR
# 3           PPE,Lanyard  Safety Equipment        NaN    SQ
# 4  Transmitter,Pressure              HVAC        NaN  PDIT
# 5       Switch,Flow-Low            Switch        NaN   FSL
# 6           PPE,Harness  Safety Equipment        NaN    SQ
# 7  Lifting Device,Chain    Lifting Device        NaN    LD
# 8           Switch,Flow            Switch        NaN   FSL
# 9  Lifting Device,Sling    Lifting Device        NaN    LD
#
#                           Valid_Class TH Suggestion  \
# 0  http://www.toronto.ca/TWONTO#00213           NaN
# 1  http://www.toronto.ca/TWONTO#00333           NaN
# 2  http://www.toronto.ca/TWONTO#00418           NaN
# 3  http://www.toronto.ca/TWONTO#00341           NaN
# 4  http://www.toronto.ca/TWONTO#00605           NaN
# 5  http://www.toronto.ca/TWONTO#00367           NaN
# 6  http://www.toronto.ca/TWONTO#00332           NaN
# 7  http://www.toronto.ca/TWONTO#00812           NaN
# 8  http://www.toronto.ca/TWONTO#00367           NaN
# 9  http://www.toronto.ca/TWONTO#00929           NaN
#
#                                   Parent_Description
# 0                            Chiller and Air Coolers
# 1                            WA1  Fall Arrest System
# 2          Lighting Panel, Vortex Gallery, Headworks
# 3                            WA4 Fall arrest systems
# 4  Filter, Outdoor Air Plenum, 2nd Floor, Mech Ro...
# 5  Tank, Grit Removal, Grit Tanks, North Grit Bui...
# 6                            WA1  Fall Arrest System
# 7  Lifting Devices, Chain Hoist, Come Along & Slings
# 8                        Pump,Raw Sewage Transfer #2
# 9                         Slings, Nylon, Work Area 1

# %%
dict_manual = {k: v for k, v in zip(df_manual['Entity_number'],df_manual['Valid_Class'].map(dict_iri)) if k is not None}

for key, value in list(dict_manual.items())[:10]:
    print(f"Avantis Manual Entity: {key} -> New Class: {value}")
# Out:
# Avantis Manual Entity: NX5232A -> New Class: chiller
# Avantis Manual Entity: TAB-WA1-SQ-1984 -> New Class: fall arrest lanyard
# Avantis Manual Entity: THC-ACC-HTR-6025 -> New Class: space heater
# Avantis Manual Entity: TAB-WA4-SQ-3430 -> New Class: fall restricting system
# Avantis Manual Entity: THC-ACC-PDIT-6291 -> New Class: pressure transmitter
# Avantis Manual Entity: THR-PLT-FSL-2222 -> New Class: flow switch
# Avantis Manual Entity: TAB-WA1-SQ-1915 -> New Class: fall arrest harness
# Avantis Manual Entity: THR-MCS-LD-9868 -> New Class: winch
# Avantis Manual Entity: TAB-RSP-FSL-1221D -> New Class: flow switch
# Avantis Manual Entity: THR-WA1-LD-0051 -> New Class: synthetic web sling

# %% [markdown]
# ## Applying the Mapping
# The mapping will now be applied, starting with the lest likely to be accurate to the most likely to be accurate

# %%
df['Valid_Class'] = None

df['Valid_Class'] = df['Category'].map(dict_supercategory).fillna(df['Valid_Class'])
print(f"After mapping Supercategory, {df['Valid_Class'].notna().sum()/df.shape[0]:.1%} mapped")
df['Valid_Class'] = df['Category'].map(dict_category).fillna(df['Valid_Class'])
print(f"After mapping Category, {df['Valid_Class'].notna().sum()/df.shape[0]:.1%} mapped, {df['Category'].map(dict_category).notna().sum()/df.shape[0]:.1%} changed")

df['Valid_Class'] = df['Class'].map(dict_superclass).fillna(df['Valid_Class'])
print(f"After mapping SuperClass, {df['Valid_Class'].notna().sum()/df.shape[0]:.1%} mapped, {df['Class'].map(dict_superclass).notna().sum()/df.shape[0]:.1%} changed")
df['Valid_Class'] = df['Class'].map(dict_class).fillna(df['Valid_Class'])
print(f"After mapping Class, {df['Valid_Class'].notna().sum()/df.shape[0]:.1%} mapped, {df['Class'].map(dict_class).notna().sum()/df.shape[0]:.1%} changed")
df['Valid_Class'] = df['Entity_number'].map(dict_manual).fillna(df['Valid_Class'])

df['Valid_Class'] = df['Extracted_Code'].map(dict_supertag).fillna(df['Valid_Class'])
print(f"After mapping Supertag, {df['Valid_Class'].notna().sum()/df.shape[0]:.1%} mapped, {df['Extracted_Code'].map(dict_supertag).notna().sum()/df.shape[0]:.1%} changed")
df['Valid_Class'] = df['Extracted_Code'].map(dict_tag).fillna(df['Valid_Class'])
print(f"After mapping Tag, {df['Valid_Class'].notna().sum()/df.shape[0]:.1%} mapped, {df['Extracted_Code'].map(dict_tag).notna().sum()/df.shape[0]:.1%} changed")

print(f"After mapping Manual Mapping, {df['Valid_Class'].notna().sum()/df.shape[0]:.1%} mapped, {df['Entity_number'].map(dict_manual).notna().sum()/df.shape[0]:.1%} changed")

df.head(10)
# Out:
# After mapping Supercategory, 32.5% mapped
# After mapping Category, 64.0% mapped, 31.6% changed
# After mapping SuperClass, 66.0% mapped, 3.1% changed
# After mapping Class, 90.8% mapped, 79.1% changed
# After mapping Supertag, 99.9% mapped, 13.0% changed
# After mapping Tag, 100.0% mapped, 64.9% changed
# After mapping Manual Mapping, 100.0% mapped, 26.9% changed
#         Entity_number                                        Description  \
# 0    FCL_ELS_CBL_001L  Electrical Power Line,4.16KV,From BUS-00B1-A t...
# 1    FCL_ELS_CBL_002D  Electrical Power Line,4.16KV,From BUS-00B2-A t...
# 2    FCL_ELS_CBL_002F  Electrical Power Line,4.16KV,From BUS-00B2 to ...
# 3    FCL_ELS_CBL_002H  Electrical Power Line,4.16KV,From BUS-00B1 to ...
# 4    FCL_ELS_CBL_002L  Electrical Power Line,4.16KV,From BUS-00B2-A t...
# 5  FCL_ELS_CBL_00B2-A  Electrical Power Line,4.16KV,From BUS-00B2 to ...
# 6    FCL_ELS_CBL_0100  Electrical Power Line,From BUS-00L1 to Transfo...
# 7    FCL_ELS_CBL_0200  Electrical Power Line,From BUS-00L2 to Transfo...
# 8    FCL_ELS_CBL_02CF  Electrical Power Line,4.16KV,From BUS-00B2-A t...
# 9               17513                               Piping, New Wet Well
#
#                  Parent            Parent_Description           Category  \
# 0  FCL_ELS_4.16KV_LINES  Electrical Power Line,4.16KV  Air Handling Unit
# 1  FCL_ELS_4.16KV_LINES  Electrical Power Line,4.16KV  Air Handling Unit
# 2  FCL_ELS_4.16KV_LINES  Electrical Power Line,4.16KV  Air Handling Unit
# 3  FCL_ELS_4.16KV_LINES  Electrical Power Line,4.16KV  Air Handling Unit
# 4  FCL_ELS_4.16KV_LINES  Electrical Power Line,4.16KV  Air Handling Unit
# 5  FCL_ELS_4.16KV_LINES  Electrical Power Line,4.16KV  Air Handling Unit
# 6  FCL_ELS_27.6KV_LINES  Electrical Power Line,27.6KV  Air Handling Unit
# 7  FCL_ELS_27.6KV_LINES  Electrical Power Line,27.6KV  Air Handling Unit
# 8  FCL_ELS_4.16KV_LINES  Electrical Power Line,4.16KV  Air Handling Unit
# 9           TAB-DEW-WEL            Centrate Wet Wells             Piping
#
#                    Class Suspended Extracted_Code Matched_Code    Valid_Class
# 0  Electrical Power Line      None           None         None  cable segment
# 1  Electrical Power Line      None           None         None  cable segment
# 2  Electrical Power Line      None           None         None  cable segment
# 3  Electrical Power Line      None           None         None  cable segment
# 4  Electrical Power Line      None           None         None  cable segment
# 5  Electrical Power Line      None           None         None  cable segment
# 6  Electrical Power Line      None           None         None  cable segment
# 7  Electrical Power Line      None           None         None  cable segment
# 8  Electrical Power Line      None           None         None  cable segment
# 9                 Piping      None           None         None   pipe segment

# %%
df[df['Valid_Class'].isna()].to_csv('Unmapped_Avantis_Entities.csv', index=False)

# %%
df[df['Valid_Class'].isna()]
# Out:
#    Entity_number                        Description  \
# 10         17800    TAB Power Distribution Projects
# 20         21381       TAB Process Control Projects
# 22         32752              TAB Process Computers
# 53          8831       All Buildings, Wet Wells WA8
# 68         36233  TAB Power Failure August 14, 2003
#
#                        Parent             Parent_Description Category Class  \
# 10                      52349         TAB Power Distribution     None  None
# 20                      52349         TAB Power Distribution     None  None
# 22                      52349         TAB Power Distribution     None  None
# 53                    TAB-WA8  Common to WA8  Bldg. Services     Tank  Tank
# 68                      52349         TAB Power Distribution     None  None
#
#    Suspended Extracted_Code Matched_Code Valid_Class
# 10      None           None         None        None
# 20      None           None         None        None
# 22      None           None         None        None
# 53      None           None         None        None
# 68      None           None         None        None
