# %% [markdown]
# # Avantis Mapping Instructions
#
# The following describes the process for mapping the current Avantis Classes to the new Classification system.

# %% [markdown]
# ## SQL connection
# The first step connects to the Avantis SQL server to get the list of entities

# %%
import pyodbc
import pandas as pd
import os
from sqlalchemy.engine import URL
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

connect = 'DSN=Avantis6-P;UID='+ os.environ['Avantis_User'] + ';PWD=' + os.environ['Avantis_Pass']
connection_url = URL.create("mssql+pyodbc", query={"odbc_connect": connect})

engine = create_engine(connection_url)

SQL1 = """SELECT Distinct MAINTENT.id as [Entity_number],
[MAINTENT].[aenm] as [Description],
MAINTENT2.id as [Parent],
MAINTENT2.aenm as [Parent_Description],
[contname] as [Category],
[entclsid] as [Class],
SUSPEND.suspoi as [Suspended],
SITE.id as [Site]

FROM  [AvantisP].[mc].[MAINTENT]
	  Left Join [AvantisP].[mc].[ENTCLASS] on MAINTENT.entclsref_oi = ENTCLASS.entcloi
	  Left Join [AvantisP].[mc].CATVAL ON MAINTENT.cat1_oi = CATVAL.cvoi
	  Left Join MC.SUSPEND ON MAINTENT.susp_oi = SUSPEND.suspoi
	  Left Join MC.MELINK ON MAINTENT.mtnoi = MELINK.mtnchild_oi
	  Left Join MC.MAINTENT MAINTENT2 ON MELINK.mtnparn_oi = MAINTENT2.mtnoi
      LEFT OUTER JOIN MC.SITE ON MAINTENT.beparn_oi = SITE.siteoi
WHERE
    (SUSPEND.audt_updted_dttm <= '1900-01-01 23:59:59' OR SUSPEND.audt_updted_dttm IS NULL) AND
    (MAINTENT.okcost = 1)
"""


df = pd.read_sql(SQL1,engine)
df = df[df['Entity_number'].values != None]
df.head(10)
# Out:
#           Entity_number                                        Description  \
# 0    \tFCL_ELS_CBL_001F  Electrical Power Line,4.16KV,From BUS-00B1 to ...
# 1    \tFCL_ELS_CBL_001G  Electrical Power Line,4.16KV,From BUS-00B1 to ...
# 2    \tFCL_ELS_CBL_001H  Electrical Power Line,4.16KV,From BUS-00B1 to ...
# 3    \tFCL_ELS_CBL_001L  Electrical Power Line,4.16KV,From BUS-00B1-A t...
# 4    \tFCL_ELS_CBL_002D  Electrical Power Line,4.16KV,From BUS-00B2-A t...
# 5    \tFCL_ELS_CBL_002L  Electrical Power Line,4.16KV,From BUS-00B2-A t...
# 6    \tFCL_ELS_CBL_003F  Electrical Power Line,4.16KV,From BUS-00B2 to ...
# 7  \tFCL_ELS_CBL_00B1-A  Electrical Power Line,4.16KV,From BUS-00B1 to ...
# 8  \tFCL_ELS_CBL_00B2-A  Electrical Power Line,4.16KV,From BUS-00B2 to ...
# 9    \tFCL_ELS_CBL_00L1  Electrical Power Line,From SW-00L1 to BUS-00L1...
#
#                  Parent            Parent_Description               Category  \
# 0  FCL_ELS_4.16KV_LINES  Electrical Power Line,4.16KV      Air Handling Unit
# 1  FCL_ELS_4.16KV_LINES  Electrical Power Line,4.16KV      Air Handling Unit
# 2  FCL_ELS_4.16KV_LINES  Electrical Power Line,4.16KV      Air Handling Unit
# 3  FCL_ELS_4.16KV_LINES  Electrical Power Line,4.16KV      Air Handling Unit
# 4  FCL_ELS_4.16KV_LINES  Electrical Power Line,4.16KV      Air Handling Unit
# 5  FCL_ELS_4.16KV_LINES  Electrical Power Line,4.16KV      Air Handling Unit
# 6  FCL_ELS_4.16KV_LINES  Electrical Power Line,4.16KV      Air Handling Unit
# 7  FCL_ELS_4.16KV_LINES  Electrical Power Line,4.16KV      Air Handling Unit
# 8  FCL_ELS_4.16KV_LINES  Electrical Power Line,4.16KV      Air Handling Unit
# 9  FCL_ELS_27.6KV_LINES  Electrical Power Line,27.6KV  Electrical Power Line
#
#                    Class Suspended Site
# 0  Electrical Power Line      None  FCL
# 1  Electrical Power Line      None  FCL
# 2  Electrical Power Line      None  FCL
# 3  Electrical Power Line      None  FCL
# 4  Electrical Power Line      None  FCL
# 5  Electrical Power Line      None  FCL
# 6  Electrical Power Line      None  FCL
# 7  Electrical Power Line      None  FCL
# 8  Electrical Power Line      None  FCL
# 9  Electrical Power Line      None  FCL

# %% [markdown]
# Here is were we capture the 13040 tag section if it is present in the entity number

# %%
import re

df_13040 = pd.read_excel('13040 Codes.xlsx', sheet_name='Append1')
dict_13040 = dict(zip(df_13040['CODE'], df_13040['DESCRIPTION']))

def extract_code(entity):
    # Use regex to match the third group between dashes
    match = re.match(r'^[^-]+-[^-]+-([^-]+)-[^-]+$', str(entity))
    return match.group(1) if match else None

def code_in_dict(code):
    return code if code in dict_13040 else None

df['Extracted_Code'] = df['Entity_number'].apply(extract_code)
df['Matched_Code'] = df['Extracted_Code'].apply(code_in_dict)
df
# Out:
#              Entity_number                                        Description  \
# 0       \tFCL_ELS_CBL_001F  Electrical Power Line,4.16KV,From BUS-00B1 to ...
# 1       \tFCL_ELS_CBL_001G  Electrical Power Line,4.16KV,From BUS-00B1 to ...
# 2       \tFCL_ELS_CBL_001H  Electrical Power Line,4.16KV,From BUS-00B1 to ...
# 3       \tFCL_ELS_CBL_001L  Electrical Power Line,4.16KV,From BUS-00B1-A t...
# 4       \tFCL_ELS_CBL_002D  Electrical Power Line,4.16KV,From BUS-00B2-A t...
# ...                    ...                                                ...
# 123649     YTF-SS-YAN-1000                      Security System Alarms/Sirens
# 123650      YTF-SS-YS-1000                      Security System Door Contacts
# 123651             YX2411A                Pump, Unwatering, Primary Tanks 1-2
# 123652             YX2412A                Pump, Unwatering, Primary Tanls 3-4
# 123653          ZB20-CA-31            Damper,Combustion Air, Steam Boiler #20
#
#                       Parent  \
# 0       FCL_ELS_4.16KV_LINES
# 1       FCL_ELS_4.16KV_LINES
# 2       FCL_ELS_4.16KV_LINES
# 3       FCL_ELS_4.16KV_LINES
# 4       FCL_ELS_4.16KV_LINES
# ...                      ...
# 123649                YTF-SS
# 123650                YTF-SS
# 123651        TAB-PRM-P-SUMP
# 123652        TAB-PRM-P-SUMP
# 123653       TAB-ACC-BO-0500
#
#                                        Parent_Description  \
# 0                            Electrical Power Line,4.16KV
# 1                            Electrical Power Line,4.16KV
# 2                            Electrical Power Line,4.16KV
# 3                            Electrical Power Line,4.16KV
# 4                            Electrical Power Line,4.16KV
# ...                                                   ...
# 123649                                   Security Systems
# 123650                                   Security Systems
# 123651  P Bldg & Old PS Buildings, Primary Treatment S...
# 123652  P Bldg & Old PS Buildings, Primary Treatment S...
# 123653                                Boiler #20, Volcano
#
#                              Category                  Class Suspended Site  \
# 0                   Air Handling Unit  Electrical Power Line      None  FCL
# 1                   Air Handling Unit  Electrical Power Line      None  FCL
# 2                   Air Handling Unit  Electrical Power Line      None  FCL
# 3                   Air Handling Unit  Electrical Power Line      None  FCL
# 4                   Air Handling Unit  Electrical Power Line      None  FCL
# ...                               ...                    ...       ...  ...
# 123649                           None        Security System      None  YTF
# 123650                           None        Security System      None  YTF
# 123651  Pump,Centrifugal,single-Stage                   Pump      None  TAB
# 123652  Pump,Centrifugal,single-Stage                   Pump      None  TAB
# 123653                  Damper/Louver          Damper/Louver      None  TAB
#
#        Extracted_Code Matched_Code
# 0                None         None
# 1                None         None
# 2                None         None
# 3                None         None
# 4                None         None
# ...               ...          ...
# 123649            YAN          YAN
# 123650             YS         None
# 123651           None         None
# 123652           None         None
# 123653           None         None
#
# [123654 rows x 10 columns]

# %% [markdown]
# ## SPARQL connection
# The following will now load the data from the OWL file

# %%
from rdflib import Graph
import pandas as pd

# Load the RDFS .ttl file into an RDFLib Graph
g = Graph()
g.parse(r"../TWONTO/OWL/TWONTO.ttl", format="turtle")

# Prepare a custom SPARQL query
query = """

PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX tw: <http://www.toronto.ca/TWONTO#>

SELECT DISTINCT ?label ?subject
       (COALESCE(?isEquivalentToCategory, "") AS ?isEquivalentToCategory)
       (COALESCE(?isEquivalentToClass, "") AS ?isEquivalentToClass)
       (COALESCE(?isSuperclassToCategory, "") AS ?isSuperclassToCategory)
       (COALESCE(?isSuperclassToClass, "") AS ?isSuperclassToClass)
       (COALESCE(?is_equivalent_to_tag_code, "") AS ?is_equivalent_to_tag_code)
       (COALESCE(?is_superclass_to_tag_code, "") AS ?is_superclass_to_tag_code)
WHERE {
  # ?subject rdfs:label ?label .

#  FILTER NOT EXISTS { ?subject owl:deprecated true }

#  ?assetClass rdfs:label "asset" .
#  ?subject rdfs:subClassOf+ ?assetClass .

  OPTIONAL { ?subject tw:is_equivalent_to_Avantis_category ?isEquivalentToCategory . }
  OPTIONAL { ?subject tw:is_equivalent_to_Avantis_class ?isEquivalentToClass . }
  OPTIONAL { ?subject tw:is_superclass_to_Avantis_category ?isSuperclassToCategory . }
  OPTIONAL { ?subject tw:is_superclass_to_Avantis_class ?isSuperclassToClass . }
  OPTIONAL { ?subject tw:is_equivalent_to_tag_code ?is_equivalent_to_tag_code . }
  OPTIONAL { ?subject tw:is_superclass_to_tag_code ?is_superclass_to_tag_code . }
}
"""

# Execute the query
results = g.query(query)

# Convert results to a DataFrame, do not replace None with empty string
data = []
for row in results:
    data.append([
        str(row.label) if row.label else None,
        str(row.subject) if row.subject else None,
        str(row.isEquivalentToCategory) if row.isEquivalentToCategory else None,
        str(row.isEquivalentToClass) if row.isEquivalentToClass else None,
        str(row.isSuperclassToCategory) if row.isSuperclassToCategory else None,
        str(row.isSuperclassToClass) if row.isSuperclassToClass else None,
        str(row.is_equivalent_to_tag_code) if row.is_equivalent_to_tag_code else None,
        str(row.is_superclass_to_tag_code) if row.is_superclass_to_tag_code else None
    ])

df_sparql = pd.DataFrame(data, columns=[
    "label",
    "subject",
    "isEquivalentToCategory",
    "isEquivalentToClass",
    "isSuperclassToCategory",
    "isSuperclassToClass",
    "is_equivalent_to_tag_code",
    "is_superclass_to_tag_code"
])

df_sparql
# Out:
#                         label  \
# 0     new_13040_code_proposed
# 1                    contains
# 2                     created
# 3               fully grounds
# 4                     grounds
# ...                       ...
# 1311                 NEMA HAZ
# 1312                    steam
# 1313              thermal oil
# 1314                    water
# 1315     water glycol mixture
#
#                                                 subject  \
# 0     http://www.toronto.ca/TWONTO#new_13040_code_pr...
# 1                    http://www.toronto.ca/TWONTO#00865
# 2                    http://www.toronto.ca/TWONTO#00866
# 3                    http://www.toronto.ca/TWONTO#00867
# 4                    http://www.toronto.ca/TWONTO#00868
# ...                                                 ...
# 1311                 http://www.toronto.ca/TWONTO#00113
# 1312                 http://www.toronto.ca/TWONTO#00704
# 1313                 http://www.toronto.ca/TWONTO#00745
# 1314                 http://www.toronto.ca/TWONTO#00798
# 1315                 http://www.toronto.ca/TWONTO#00799
#
#      isEquivalentToCategory isEquivalentToClass isSuperclassToCategory  \
# 0                      None                None                   None
# 1                      None                None                   None
# 2                      None                None                   None
# 3                      None                None                   None
# 4                      None                None                   None
# ...                     ...                 ...                    ...
# 1311                   None                None                   None
# 1312                   None                None                   None
# 1313                   None                None                   None
# 1314                   None                None                   None
# 1315                   None                None                   None
#
#      isSuperclassToClass is_equivalent_to_tag_code is_superclass_to_tag_code
# 0                   None                      None                      None
# 1                   None                      None                      None
# 2                   None                      None                      None
# 3                   None                      None                      None
# 4                   None                      None                      None
# ...                  ...                       ...                       ...
# 1311                None                      None                      None
# 1312                None                      None                      None
# 1313                None                      None                      None
# 1314                None                      None                      None
# 1315                None                      None                      None
#
# [1316 rows x 8 columns]

# %% [markdown]
# Now to create the dictionary items for easy lookup later

# %%
dict_class = {k: v for k, v in zip(df_sparql['isEquivalentToClass'], df_sparql['label']) if k is not None}
dict_superclass = {k: v for k, v in zip(df_sparql['isSuperclassToClass'], df_sparql['label']) if k is not None}
dict_category = {k: v for k, v in zip(df_sparql['isEquivalentToCategory'], df_sparql['label']) if k is not None}
dict_supercategory = {k: v for k, v in zip(df_sparql['isSuperclassToCategory'], df_sparql['label']) if k is not None}
dict_tag = {k: v for k, v in zip(df_sparql['is_equivalent_to_tag_code'], df_sparql['label']) if k is not None}
dict_supertag = {k: v for k, v in zip(df_sparql['is_superclass_to_tag_code'], df_sparql['label']) if k is not None}
dict_iri = {k: v for k, v in zip(df_sparql['subject'], df_sparql['label']) if k is not None}
dict_iri['x'] = 'unknown'

for key, value in list(dict_class.items())[:10]:
    print(f"Avantis Class: {key} -> New Class: {value}")
# Out:
# Avantis Class: Vehicle -> New Class: passenger vehicle
# Avantis Class: Fan -> New Class: fan
# Avantis Class: Structure -> New Class: structure
# Avantis Class: Power Supply Unit -> New Class: DC power supply
# Avantis Class: Programmable Logic Control -> New Class: PLC
# Avantis Class: Remote Processor Unit -> New Class: RPU panel
# Avantis Class: Remote Transmission Unit -> New Class: RPU panel
# Avantis Class: Uninterruptible Power Supply -> New Class: UPS
# Avantis Class: Ultraviolet Disinfection -> New Class: UV disinfection assembly
# Avantis Class: Variable Frequency Drive -> New Class: VFD

# %% [markdown]
# ## Manual Matching
# Here we will load the manual matched file

# %%
df_manual = pd.read_excel('manualMatch.xlsx', sheet_name='LLM capability Test Dataset')
df['Entity_number'] = df['Entity_number'].astype(str).str.strip()
df_manual
# Out:
#        ID   Entity_number                                        Description  \
# 0     NaN            8831                       All Buildings, Wet Wells WA8
# 1     NaN           17800                    TAB Power Distribution Projects
# 2     NaN           20657  TAB WA1  Internal telephones & Public address ...
# 3     NaN           20663  TAB WA2 Internal telephones & Public address s...
# 4     NaN           20663  TAB WA2 Internal telephones & Public address s...
# ...    ..             ...                                                ...
# 48227 NaN  WTR-PRV-T-0005  Tank, Water Expansion, Hot Water Expansion, Pu...
# 48228 NaN  WTR-PRV-T-0008  Tank, Water Expansion, Hot Water Expansion, Ge...
# 48229 NaN  WTR-RRV-T-0002  Tank, Hot Water, Domestic Hot Water, Valve Hou...
# 48230 NaN  WTR-RRV-T-0003   Tank, Hot Water, Domestic Hot Water, Valve House
# 48231 NaN  WTR-RRV-T-0007  Tank, Expansion, Hot Water Expansion, Valve House
#
#                  Parent                 Category                     Class  \
# 0               TAB-WA8                     Tank                      Tank
# 1                 52349                      NaN                       NaN
# 2               TAB-WA1                      NaN  Communications Equipment
# 3      TAB-WA2-ADM-0001                      NaN  Communications Equipment
# 4               TAB-WA8                      NaN  Communications Equipment
# ...                 ...                      ...                       ...
# 48227       WTR-PRV-ACC  Tank,Domestic Hot Water                      Tank
# 48228       WTR-PRV-ACC  Tank,Domestic Hot Water                      Tank
# 48229       WTR-RRV-ACC  Tank,Domestic Hot Water                      Tank
# 48230       WTR-RRV-ACC  Tank,Domestic Hot Water                      Tank
# 48231       WTR-RRV-ACC  Tank,Domestic Hot Water                      Tank
#
#        Suspended  Tag                                        Valid_Class  \
# 0            NaN  NaN                 http://www.toronto.ca/TWONTO#00260
# 1            NaN  NaN                                                  x
# 2            NaN  NaN  http://www.toronto.ca/TWONTO#OWLClass_aaa0534b...
# 3            NaN  NaN  http://www.toronto.ca/TWONTO#OWLClass_aaa0534b...
# 4            NaN  NaN  http://www.toronto.ca/TWONTO#OWLClass_aaa0534b...
# ...          ...  ...                                                ...
# 48227        NaN    T                 http://www.toronto.ca/TWONTO#00325
# 48228        NaN    T                 http://www.toronto.ca/TWONTO#00325
# 48229        NaN    T                 http://www.toronto.ca/TWONTO#00427
# 48230        NaN    T                 http://www.toronto.ca/TWONTO#00427
# 48231        NaN    T                 http://www.toronto.ca/TWONTO#00325
#
#       TH Suggestion                               Parent_Description
# 0               NaN                                              NaN
# 1               NaN                                              NaN
# 2               NaN  Common to WA1 - Safety,  Bldg. Services, , etc.
# 3               NaN                         Admin. Work- Work Area 2
# 4               NaN                    Common to WA8  Bldg. Services
# ...             ...                                              ...
# 48227           NaN                                              NaN
# 48228           NaN                                              NaN
# 48229           NaN                                              NaN
# 48230           NaN                                              NaN
# 48231           NaN                                              NaN
#
# [48232 rows x 11 columns]

# %%
dict_manual = {k: v for k, v in zip(df_manual['Entity_number'],df_manual['Valid_Class'].map(dict_iri)) if k is not None}

for key, value in list(dict_manual.items())[:10]:
    print(f"Avantis Manual Entity: {key} -> New Class: {value}")
# Out:
# Avantis Manual Entity: 8831 -> New Class: defined collection of assets
# Avantis Manual Entity: 17800 -> New Class: unknown
# Avantis Manual Entity: 20657 -> New Class: PA system
# Avantis Manual Entity: 20663 -> New Class: PA system
# Avantis Manual Entity: 20664 -> New Class: PA system
# Avantis Manual Entity: 20665 -> New Class: PA system
# Avantis Manual Entity: 20666 -> New Class: PA system
# Avantis Manual Entity: 20667 -> New Class: PA system
# Avantis Manual Entity: 20668 -> New Class: PA system
# Avantis Manual Entity: 20669 -> New Class: PA system

# %% [markdown]
# ## Applying the Mapping
# The mapping will now be applied, starting with the lest likely to be accurate to the most likely to be accurate

# %%
df['Valid_Class'] = None

df['Valid_Class'] = df['Category'].map(dict_supercategory).fillna(df['Valid_Class'])
print(f"After mapping Supercategory, {df['Valid_Class'].notna().sum()/df.shape[0]:.1%} mapped")
df['Valid_Class'] = df['Category'].map(dict_category).fillna(df['Valid_Class'])
print(f"After mapping Category, {df['Valid_Class'].notna().sum()/df.shape[0]:.1%} mapped, {df['Category'].map(dict_category).notna().sum()/df.shape[0]:.1%} changed")

df['Valid_Class'] = df['Class'].map(dict_superclass).fillna(df['Valid_Class'])
print(f"After mapping SuperClass, {df['Valid_Class'].notna().sum()/df.shape[0]:.1%} mapped, {df['Class'].map(dict_superclass).notna().sum()/df.shape[0]:.1%} changed")
df['Valid_Class'] = df['Class'].map(dict_class).fillna(df['Valid_Class'])
print(f"After mapping Class, {df['Valid_Class'].notna().sum()/df.shape[0]:.1%} mapped, {df['Class'].map(dict_class).notna().sum()/df.shape[0]:.1%} changed")

df['Valid_Class'] = df['Extracted_Code'].map(dict_supertag).fillna(df['Valid_Class'])
print(f"After mapping Supertag, {df['Valid_Class'].notna().sum()/df.shape[0]:.1%} mapped, {df['Extracted_Code'].map(dict_supertag).notna().sum()/df.shape[0]:.1%} changed")
df['Valid_Class'] = df['Extracted_Code'].map(dict_tag).fillna(df['Valid_Class'])
print(f"After mapping Tag, {df['Valid_Class'].notna().sum()/df.shape[0]:.1%} mapped, {df['Extracted_Code'].map(dict_tag).notna().sum()/df.shape[0]:.1%} changed")

df['Valid_Class'] = df['Entity_number'].map(dict_manual).fillna(df['Valid_Class'])
print(f"After mapping Manual Mapping, {df['Valid_Class'].notna().sum()/df.shape[0]:.1%} mapped, {df['Entity_number'].map(dict_manual).notna().sum()/df.shape[0]:.1%} changed")

df.head(10)
# Out:
# After mapping Supercategory, 32.9% mapped
# After mapping Category, 64.0% mapped, 31.2% changed
# After mapping SuperClass, 66.0% mapped, 3.1% changed
# After mapping Class, 90.9% mapped, 79.3% changed
# After mapping Supertag, 92.0% mapped, 13.0% changed
# After mapping Tag, 96.6% mapped, 65.3% changed
# After mapping Manual Mapping, 100.0% mapped, 28.5% changed
#       Entity_number                                        Description  \
# 0  FCL_ELS_CBL_001D  Electrical Power Line,4.16KV,From BUS-00B1-A t...
# 1  FCL_ELS_CBL_002F  Electrical Power Line,4.16KV,From BUS-00B2 to ...
# 2  FCL_ELS_CBL_002H  Electrical Power Line,4.16KV,From BUS-00B1 to ...
# 3  FCL_ELS_CBL_0100  Electrical Power Line,From BUS-00L1 to Transfo...
# 4  FCL_ELS_CBL_0200  Electrical Power Line,From BUS-00L2 to Transfo...
# 5  FCL_ELS_CBL_02CF  Electrical Power Line,4.16KV,From BUS-00B2-A t...
# 6             17513                               Piping, New Wet Well
# 7             20127                   Door,Overhead, Pellet Silo South
# 8             20128                  Door,Overhead, Pellet Silo, North
# 9             20663  TAB WA2 Internal telephones & Public address s...
#
#                  Parent            Parent_Description           Category  \
# 0  FCL_ELS_4.16KV_LINES  Electrical Power Line,4.16KV  Air Handling Unit
# 1  FCL_ELS_4.16KV_LINES  Electrical Power Line,4.16KV  Air Handling Unit
# 2  FCL_ELS_4.16KV_LINES  Electrical Power Line,4.16KV  Air Handling Unit
# 3  FCL_ELS_27.6KV_LINES  Electrical Power Line,27.6KV  Air Handling Unit
# 4  FCL_ELS_27.6KV_LINES  Electrical Power Line,27.6KV  Air Handling Unit
# 5  FCL_ELS_4.16KV_LINES  Electrical Power Line,4.16KV  Air Handling Unit
# 6           TAB-DEW-WEL            Centrate Wet Wells             Piping
# 7            TAB-MCS-DR   Plant Wide - Overhead Doors      Door,Overhead
# 8            TAB-MCS-DR   Plant Wide - Overhead Doors      Door,Overhead
# 9      TAB-WA2-ADM-0001      Admin. Work- Work Area 2               None
#
#                       Class Suspended Site Extracted_Code Matched_Code  \
# 0     Electrical Power Line      None  FCL           None         None
# 1     Electrical Power Line      None  FCL           None         None
# 2     Electrical Power Line      None  FCL           None         None
# 3     Electrical Power Line      None  FCL           None         None
# 4     Electrical Power Line      None  FCL           None         None
# 5     Electrical Power Line      None  FCL           None         None
# 6                    Piping      None  TAB           None         None
# 7                      Door      None  TAB           None         None
# 8                      Door      None  TAB           None         None
# 9  Communications Equipment      None  TAB           None         None
#
#                                    Valid_Class
# 0                                cable segment
# 1                                cable segment
# 2                                cable segment
# 3                                cable segment
# 4                                cable segment
# 5                                cable segment
# 6                                 pipe segment
# 7                                         door
# 8                                         door
# 9  communication or networking equipment (MBC)

# %% [markdown]
# ## Sample dataset for Peters work

# %%
from openpyxl.worksheet.table import Table, TableStyleInfo
Auto = [x not in dict_manual for x in df['Entity_number']]
Manual = [x in dict_manual for x in df['Entity_number']]
df['Manual Mapping'] = False
df['Manual Mapping'].iloc[Manual] = True

df_auto = df[Auto]
df_manual = df[Manual]
df_auto_sample = df_auto.groupby('Site', group_keys=False).apply(lambda g: g.sample(min(len(g), 10), random_state=42))
df_manual_sample = df_manual.groupby('Site', group_keys=False).apply(lambda g: g.sample(min(len(g), 10), random_state=42))


with pd.ExcelWriter('class_mapping_sample.xlsx', engine='openpyxl') as writer:
    
    # --- Write all DataFrames ---
    df_auto_sample.to_excel(writer, sheet_name='Automatic Sample', index=False)
    df_manual_sample.to_excel(writer, sheet_name='Manual Sample', index=False)
    df.to_excel(writer, sheet_name='All Data', index=False)

    # --- Helper function to convert a DF into an Excel Table ---
    def add_table(df, sheet_name):
        ws = writer.sheets[sheet_name]

        # Table range (A1:Z100 etc.)
        end_row = len(df) + 1              # +1 because of header
        end_col = len(df.columns)

        # Convert numeric column index to Excel letter (A, B, C…)
        from openpyxl.utils import get_column_letter
        end_col_letter = get_column_letter(end_col)

        table_ref = f"A1:{end_col_letter}{end_row}"

        table = Table(displayName=sheet_name.replace(" ", "_"), ref=table_ref)

        # Optional styling
        style = TableStyleInfo(
            name="TableStyleMedium21",
            showRowStripes=True,
            showColumnStripes=False
        )
        table.tableStyleInfo = style

        ws.add_table(table)

    # --- Add tables to all sheets ---
    add_table(df_auto_sample, "Automatic Sample")
    add_table(df_manual_sample, "Manual Sample")
    add_table(df, "All Data")
# Out:
# C:\Users\medney\AppData\Local\Temp\ipykernel_26068\1989429499.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Manual Mapping'].iloc[Manual] = True
# C:\Users\medney\AppData\Local\Temp\ipykernel_26068\1989429499.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Manual Mapping'].iloc[Manual] = True
# C:\Users\medney\AppData\Local\Temp\ipykernel_26068\1989429499.py:9: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_auto_sample = df_auto.groupby('Site', group_keys=False).apply(lambda g: g.sample(min(len(g), 10), random_state=42))
# C:\Users\medney\AppData\Local\Temp\ipykernel_26068\1989429499.py:10: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_manual_sample = df_manual.groupby('Site', group_keys=False).apply(lambda g: g.sample(min(len(g), 10), random_state=42))

# %% [markdown]
# ## Dataset required for the Asset and Functional location mapping

# %%
dict_class_iri = {v: k for k, v in zip(df_sparql['subject'], df_sparql['label']) if k is not None}
dict_class_iri
# Out:
# {'new_13040_code_proposed': 'http://www.toronto.ca/TWONTO#new_13040_code_proposed',
#  'contains': 'http://www.toronto.ca/TWONTO#00865',
#  'created': 'http://www.toronto.ca/TWONTO#00866',
#  'fully grounds': 'http://www.toronto.ca/TWONTO#00867',
#  'grounds': 'http://www.toronto.ca/TWONTO#00407',
#  'has boiler heating surface area': 'http://www.toronto.ca/TWONTO#00869',
#  'has content part': 'http://www.toronto.ca/TWONTO#00870',
#  'has earlier version': 'http://www.toronto.ca/TWONTO#00871',
#  'has later version': 'http://www.toronto.ca/TWONTO#00872',
#  'has max holding capacity': 'http://www.toronto.ca/TWONTO#00873',
#  'has max medium temperature': 'http://www.toronto.ca/TWONTO#00874',
#  'has max operating pressure': 'http://www.toronto.ca/TWONTO#00875',
#  'has next version': 'http://www.toronto.ca/TWONTO#00876',
#  'has nominal input voltage': 'http://www.toronto.ca/TWONTO#00877',
#  'has part': 'http://www.toronto.ca/TWONTO#00878',
#  'has physical part': 'http://www.toronto.ca/TWONTO#00879',
#  'has present measure of property': 'http://www.toronto.ca/TWONTO#00880',
#  'has present property': 'http://www.toronto.ca/TWONTO#00881',
#  'has present relation': 'http://www.toronto.ca/TWONTO#00882',
#  'has previous version': 'http://www.toronto.ca/TWONTO#00883',
#  'has process medium': 'http://www.toronto.ca/TWONTO#00884',
#  'has property': 'http://www.toronto.ca/TWONTO#00885',
#  'has publisher': 'http://www.toronto.ca/TWONTO#00886',
#  'has rated output power': 'http://www.toronto.ca/TWONTO#00887',
#  'has specification': 'http://www.toronto.ca/TWONTO#00888',
#  'has subject type': 'http://www.toronto.ca/TWONTO#00889',
#  'has subsystem': 'http://www.toronto.ca/TWONTO#00890',
#  'has unit of measure': 'http://www.toronto.ca/TWONTO#00891',
#  'includes content': 'http://www.toronto.ca/TWONTO#00892',
#  'includes content about': 'http://www.toronto.ca/TWONTO#00893',
#  'includes work instruction content': 'http://www.toronto.ca/TWONTO#00894',
#  'includes worker qualification content': 'http://www.toronto.ca/TWONTO#00895',
#  'is a development of': 'http://www.toronto.ca/TWONTO#00896',
#  'is created by': 'http://www.toronto.ca/TWONTO#00897',
#  'is developed into': 'http://www.toronto.ca/TWONTO#00898',
#  'is in a state of': 'http://www.toronto.ca/TWONTO#00899',
#  'is occupied by': 'http://www.toronto.ca/TWONTO#00900',
#  'is part of': 'http://www.toronto.ca/TWONTO#00901',
#  'is part of content': 'http://www.toronto.ca/TWONTO#00902',
#  'is physical part of': 'http://www.toronto.ca/TWONTO#00903',
#  'is quantified by': 'http://www.toronto.ca/TWONTO#00904',
#  'is subsystem of': 'http://www.toronto.ca/TWONTO#00905',
#  'occupies': 'http://www.toronto.ca/TWONTO#00906',
#  'partially grounds': 'http://www.toronto.ca/TWONTO#00907',
#  'possesses function': 'http://www.toronto.ca/TWONTO#00908',
#  'realization contingent on': 'http://www.toronto.ca/TWONTO#00909',
#  'references': 'http://www.toronto.ca/TWONTO#00910',
#  'references for adoption': 'http://www.toronto.ca/TWONTO#00911',
#  'relative to onset of': 'http://www.toronto.ca/TWONTO#00912',
#  'relative to termination of': 'http://www.toronto.ca/TWONTO#00913',
#  'sits within': 'http://www.toronto.ca/TWONTO#00914',
#  'the class': 'http://www.toronto.ca/TWONTO#00916',
#  'the individual': 'http://www.toronto.ca/TWONTO#00917',
#  'specifies trigger event': 'http://www.toronto.ca/TWONTO#01500',
#  'is plumbed': 'http://www.toronto.ca/TWONTO#OWLDataProperty_minuz-nusuf-dulat-kohon',
#  'eidf asset record data property': 'http://www.toronto.ca/TWONTO#00822',
#  'eidf change to physical asset': 'http://www.toronto.ca/TWONTO#00823',
#  'eidf has asset JSON-LD data': 'http://www.toronto.ca/TWONTO#00824',
#  'eidf has boiler energy source': 'http://www.toronto.ca/TWONTO#00825',
#  'eidf has boiler process medium': 'http://www.toronto.ca/TWONTO#00826',
#  'eidf has entity name': 'http://www.toronto.ca/TWONTO#00827',
#  'eidf has entity number': 'http://www.toronto.ca/TWONTO#00828',
#  'eidf has parent entity number': 'http://www.toronto.ca/TWONTO#00829',
#  'eidf uses bearing lubricant type': 'http://www.toronto.ca/TWONTO#00830',
#  'has NEMA enclosure type': 'http://www.toronto.ca/TWONTO#00831',
#  'has NEMA frame type': 'http://www.toronto.ca/TWONTO#00832',
#  'has asset status': 'http://www.toronto.ca/TWONTO#00833',
#  'has boiler service type': 'http://www.toronto.ca/TWONTO#00834',
#  'has content text': 'http://www.toronto.ca/TWONTO#00835',
#  'has creation time': 'http://www.toronto.ca/TWONTO#00836',
#  'has deaerator': 'http://www.toronto.ca/TWONTO#00837',
#  'has document URL': 'http://www.toronto.ca/TWONTO#00838',
#  'has intent description': 'http://www.toronto.ca/TWONTO#00839',
#  'has interpretation text': 'http://www.toronto.ca/TWONTO#00840',
#  'has name': 'http://www.toronto.ca/TWONTO#00841',
#  'has numeric value': 'http://www.toronto.ca/TWONTO#00842',
#  'has operational state': 'http://www.toronto.ca/TWONTO#00843',
#  'has present property indicated by literal value': 'http://www.toronto.ca/TWONTO#00844',
#  'has publication date': 'http://www.toronto.ca/TWONTO#00845',
#  'has record data value': 'http://www.toronto.ca/TWONTO#00846',
#  'has revision date': 'http://www.toronto.ca/TWONTO#00847',
#  'has scope description': 'http://www.toronto.ca/TWONTO#00848',
#  'has sealed or shielded bearing': 'http://www.toronto.ca/TWONTO#00849',
#  'has summary': 'http://www.toronto.ca/TWONTO#00850',
#  'includes work instruction text': 'http://www.toronto.ca/TWONTO#00851',
#  'is above ground': 'http://www.toronto.ca/TWONTO#00852',
#  'is actuated valve': 'http://www.toronto.ca/TWONTO#00853',
#  'is controlled valve': 'http://www.toronto.ca/TWONTO#00854',
#  'is designated by': 'http://www.toronto.ca/TWONTO#00855',
#  'is installed underground': 'http://www.toronto.ca/TWONTO#00856',
#  'is latest version': 'http://www.toronto.ca/TWONTO#00857',
#  'is manually powered': 'http://www.toronto.ca/TWONTO#00858',
#  'is portable': 'http://www.toronto.ca/TWONTO#00859',
#  'is powered': 'http://www.toronto.ca/TWONTO#00860',
#  'is stationary': 'http://www.toronto.ca/TWONTO#00861',
#  'is subject of note': 'http://www.toronto.ca/TWONTO#00862',
#  'is underground': 'http://www.toronto.ca/TWONTO#00863',
#  'uses bearing lubricant type': 'http://www.toronto.ca/TWONTO#00864',
#  'selective catalytic reduction system': 'http://www.toronto.ca/TWONTO#OWLClass_3ff3f355_a097_4e22_a789_b77f5047c458',
#  'light sensor element': 'http://www.toronto.ca/TWONTO#OWLClass_49c4dc7d_0231_4e1e_bccb_05806f03a274',
#  'conductivity analyzer': 'http://www.toronto.ca/TWONTO#OWLClass_576d9df1_5769_4397_9566_31bd0039a255',
#  'ORP sensor element': 'http://www.toronto.ca/TWONTO#OWLClass_60b5a74a_3d48_4466_94eb_e56d82e4430c',
#  'smoke detector': 'http://www.toronto.ca/TWONTO#OWLClass_7583e256_830f_4442_9dc6_45f34c91e70b',
#  'pH sensor element': 'http://www.toronto.ca/TWONTO#OWLClass_8cbd140c_9232_4d30_977e_0b22da393541',
#  'ground fault circuit interrupter': 'http://www.toronto.ca/TWONTO#OWLClass_8fe22f03_9605_44bb_b291_35e31be70ac1',
#  'vehicle': 'http://www.toronto.ca/TWONTO#OWLClass_9c6da0bd_4a16_42f6_90f8_dfc8f20b23d3',
#  'conductivity sensor element': 'http://www.toronto.ca/TWONTO#OWLClass_a1c9ec00_40d1_4598_a219_34f401ca40b3',
#  'PA system': 'http://www.toronto.ca/TWONTO#OWLClass_aaa0534b_8301_4f5e_86a4_f0d2cc6e91a2',
#  'tipping bucket': 'http://www.toronto.ca/TWONTO#OWLClass_be9155b2_62e7_4de4_bd13_75303aeff62e',
#  'lighting system': 'http://www.toronto.ca/TWONTO#OWLClass_bf4a19ed_88a8_4fe8_b294_bb31702c646f',
#  'fan': 'http://www.toronto.ca/TWONTO#OWLClass_binid-posum-pozar-motav',
#  'moisture separator': 'http://www.toronto.ca/TWONTO#OWLClass_bobag-juduf-gadav-rosoh',
#  'pressure controller': 'http://www.toronto.ca/TWONTO#OWLClass_bojij-nuvup-tifas-rijur',
#  'utility power meter': 'http://www.toronto.ca/TWONTO#OWLClass_datop-sarog-hakar-tugim',
#  'motorized vehicle': 'http://www.toronto.ca/TWONTO#OWLClass_dijuh-gotud-puruj-fazab',
#  'eletrical junction box': 'http://www.toronto.ca/TWONTO#OWLClass_dofik-jobom-pifup-puhuh',
#  'battery tester': 'http://www.toronto.ca/TWONTO#OWLClass_donoj-pofaf-tuson-bilom',
#  'turbidity sensor element': 'http://www.toronto.ca/TWONTO#OWLClass_f6bbfc33_149c_45c5_8934_8b613ac8690e',
#  'combustion analyzer': 'http://www.toronto.ca/TWONTO#OWLClass_finap-fahok-nubom-fahov',
#  'backflow preventer tester': 'http://www.toronto.ca/TWONTO#OWLClass_fivij-sibit-rikok-fapib',
#  'gantry crane': 'http://www.toronto.ca/TWONTO#OWLClass_fudit-jijuv-rabid-jopuj',
#  'monorail crane': 'http://www.toronto.ca/TWONTO#OWLClass_gamit-vobop-fuliz-ninuk',
#  'overhead crane': 'http://www.toronto.ca/TWONTO#OWLClass_gatol-fihof-jiman-vopit',
#  'plumbed emergency eyewash or shower': 'http://www.toronto.ca/TWONTO#OWLClass_gibob-sipub-mizaj-kivok',
#  'structure': 'http://www.toronto.ca/TWONTO#OWLClass_hafup-kotik-pugap-bobut',
#  'cathodic protection anode': 'http://www.toronto.ca/TWONTO#OWLClass_halat-kuhol-fihub-tahiz',
#  'test instrument': 'http://www.toronto.ca/TWONTO#OWLClass_jodif-halan-jodiv-bunab',
#  'flow diversion structure': 'http://www.toronto.ca/TWONTO#OWLClass_kitok-pazin-musuh-jafih',
#  'chlorine evaporator': 'http://www.toronto.ca/TWONTO#OWLClass_lagip-zabah-kafaj-gasol',
#  'emergency generator': 'http://www.toronto.ca/TWONTO#OWLClass_numan-loziv-hahol-gihuk',
#  'calibrator': 'http://www.toronto.ca/TWONTO#OWLClass_pokaf-husul-tosum-vapif',
#  'tachometer': 'http://www.toronto.ca/TWONTO#OWLClass_rakos-pujun-pasaj-makub',
#  'emergency eye/face wash': 'http://www.toronto.ca/TWONTO#OWLClass_risig-vubog-jasav-dafud',
#  'flow controller': 'http://www.toronto.ca/TWONTO#OWLClass_roban-fufig-vuvuf-kinor',
#  'temperature controller': 'http://www.toronto.ca/TWONTO#OWLClass_sivab-vazid-tokar-zanuk',
#  'resistance tester tool': 'http://www.toronto.ca/TWONTO#OWLClass_sobum-gizot-dozos-nafil',
#  'self-contained emergency eyewash or shower': 'http://www.toronto.ca/TWONTO#OWLClass_suzug-kuvik-fotol-vizir',
#  'jib crane': 'http://www.toronto.ca/TWONTO#OWLClass_tafaf-fujas-vivot-pinud',
#  'fire alarm panel': 'http://www.toronto.ca/TWONTO#OWLClass_tinik-gifim-dijov-zonav',
#  'signal tester': 'http://www.toronto.ca/TWONTO#OWLClass_vopak-tasag-numoj-mipaj',
#  'traveling screen': 'http://www.toronto.ca/TWONTO#dajij-dovir-dafom-hohiv',
#  'SCBA cylinder': 'http://www.toronto.ca/TWONTO#famog-dusim-ludut-gasof',
#  'limit switch': 'http://www.toronto.ca/TWONTO#fohur-bugut-lijif-zazom',
#  'level indicator': 'http://www.toronto.ca/TWONTO#fufop-dabag-pazir-kital',
#  'pump diffuser': 'http://www.toronto.ca/TWONTO#guvik-gosaf-bopuj-mulal',
#  'trommel screen': 'http://www.toronto.ca/TWONTO#guzut-majad-vagos-jagok',
#  'tie-off anchor': 'http://www.toronto.ca/TWONTO#hulol-galof-pivol-pojum',
#  'SCBA system component (MBC)': 'http://www.toronto.ca/TWONTO#kolis-tozuh-tudoz-vujuj',
#  'controller or manual control equipment (MBC)': 'http://www.toronto.ca/TWONTO#lisih-havul-pajis-pinit',
#  'access controlled entry point': 'http://www.toronto.ca/TWONTO#mazos-pikaz-gapob-dipam',
#  'SCBA mask': 'http://www.toronto.ca/TWONTO#nigot-zosip-fonus-sudof',
#  'speed indicator': 'http://www.toronto.ca/TWONTO#novid-vogiv-darod-munik',
#  'non-fuel oil tank': 'http://www.toronto.ca/TWONTO#paroz-karil-zuviv-zotol',
#  'flow indicator': 'http://www.toronto.ca/TWONTO#piguk-mumor-jugoj-sibif',
#  'pressure indicator': 'http://www.toronto.ca/TWONTO#punol-kujib-zolom-dolav',
#  'vehicle gate access control system': 'http://www.toronto.ca/TWONTO#sufov-kojip-romig-faraz',
#  'wireless communication device (MBC)': 'http://www.toronto.ca/TWONTO#tubom-vagid-foraf-falid',
#  'temperature indicator': 'http://www.toronto.ca/TWONTO#tujad-guzov-jilok-tubav',
#  'calibration tool or accessory (MBC)': 'http://www.toronto.ca/TWONTO#zuvit-botof-lofip-natah',
#  'asset': 'http://www.toronto.ca/TWONTO#00001',
#  'collection of things': 'http://www.toronto.ca/TWONTO#00002',
#  'event': 'http://www.toronto.ca/TWONTO#00003',
#  'information content entity': 'http://www.toronto.ca/TWONTO#00004',
#  'process': 'http://www.toronto.ca/TWONTO#00005',
#  'organization': 'http://www.toronto.ca/TWONTO#00006',
#  'property': 'http://www.toronto.ca/TWONTO#00007',
#  'material': 'http://www.toronto.ca/TWONTO#00008',
#  'role': 'http://www.toronto.ca/TWONTO#00009',
#  'space': 'http://www.toronto.ca/TWONTO#00010',
#  'discrete asset': 'http://www.toronto.ca/TWONTO#00011',
#  'system': 'http://www.toronto.ca/TWONTO#00720',
#  'collection of asset roles': 'http://www.toronto.ca/TWONTO#00013',
#  'discrete asset role': 'http://www.toronto.ca/TWONTO#00014',
#  'distributed function system': 'http://www.toronto.ca/TWONTO#00016',
#  'localized function system': 'http://www.toronto.ca/TWONTO#00017',
#  'system functional block': 'http://www.toronto.ca/TWONTO#00018',
#  'detection pond': 'http://www.toronto.ca/TWONTO#00100',
#  'BAS controller': 'http://www.toronto.ca/TWONTO#00101',
#  'BAS panel': 'http://www.toronto.ca/TWONTO#00102',
#  'compilation of content on activity specification': 'http://www.toronto.ca/TWONTO#00103',
#  'CSA-B149-6 membrane gasholder': 'http://www.toronto.ca/TWONTO#00104',
#  'DC power supply': 'http://www.toronto.ca/TWONTO#00105',
#  'receptacle': 'http://www.toronto.ca/TWONTO#00106',
#  'valve chamber': 'http://www.toronto.ca/TWONTO#00107',
#  'HVAC system component (MBC)': 'http://www.toronto.ca/TWONTO#00108',
#  'HV insulated blanket': 'http://www.toronto.ca/TWONTO#00109',
#  '600V electrical panel': 'http://www.toronto.ca/TWONTO#00110',
#  'medium voltage electrical panel': 'http://www.toronto.ca/TWONTO#00111',
#  'NEMA enclosure type': 'http://www.toronto.ca/TWONTO#00114',
#  'ORP analyzer': 'http://www.toronto.ca/TWONTO#00115',
#  'Ontario provincial regulation': 'http://www.toronto.ca/TWONTO#00116',
#  'PA speaker': 'http://www.toronto.ca/TWONTO#00117',
#  'PH analyzer': 'http://www.toronto.ca/TWONTO#00118',
#  'PLC': 'http://www.toronto.ca/TWONTO#00119',
#  'sewer inlet': 'http://www.toronto.ca/TWONTO#00120',
#  'PPE (MBC)': 'http://www.toronto.ca/TWONTO#00121',
#  'RPU panel': 'http://www.toronto.ca/TWONTO#00122',
#  'SCBA system': 'http://www.toronto.ca/TWONTO#00123',
#  'UPS': 'http://www.toronto.ca/TWONTO#00124',
#  'UV air disinfection unit': 'http://www.toronto.ca/TWONTO#00125',
#  'UV disinfection assembly': 'http://www.toronto.ca/TWONTO#00126',
#  'UV disinfection bank': 'http://www.toronto.ca/TWONTO#00127',
#  'VFD': 'http://www.toronto.ca/TWONTO#00128',
#  'a portion of material asset': 'http://www.toronto.ca/TWONTO#00129',
#  'a power desc': 'http://www.toronto.ca/TWONTO#00130',
#  'a pressure desc': 'http://www.toronto.ca/TWONTO#00131',
#  'a temperature desc': 'http://www.toronto.ca/TWONTO#00132',
#  'a voltage desc': 'http://www.toronto.ca/TWONTO#00133',
#  'a volumetric capacity desc': 'http://www.toronto.ca/TWONTO#00134',
#  'aboveground fuel oil tank': 'http://www.toronto.ca/TWONTO#00135',
#  'aboveground fuel tank temp': 'http://www.toronto.ca/TWONTO#00136',
#  'access control barrier': 'http://www.toronto.ca/TWONTO#00137',
#  'actuator': 'http://www.toronto.ca/TWONTO#00138',
#  'aeration gas diffuser head': 'http://www.toronto.ca/TWONTO#00139',
#  'aeration tank': 'http://www.toronto.ca/TWONTO#00140',
#  'air condition': 'http://www.toronto.ca/TWONTO#00141',
#  'damper': 'http://www.toronto.ca/TWONTO#00142',
#  'air dryer': 'http://www.toronto.ca/TWONTO#00143',
#  'air duct segment': 'http://www.toronto.ca/TWONTO#00144',
#  'air exchange unit': 'http://www.toronto.ca/TWONTO#00145',
#  'air filter unit': 'http://www.toronto.ca/TWONTO#00146',
#  'air handler unit': 'http://www.toronto.ca/TWONTO#00147',
#  'air scrubber': 'http://www.toronto.ca/TWONTO#00148',
#  'air separator': 'http://www.toronto.ca/TWONTO#00149',
#  'air silencer': 'http://www.toronto.ca/TWONTO#00150',
#  'alarm device': 'http://www.toronto.ca/TWONTO#00151',
#  'ambient vapourizer': 'http://www.toronto.ca/TWONTO#00152',
#  'ammonia analyzer': 'http://www.toronto.ca/TWONTO#00153',
#  'alarm annunciator panel': 'http://www.toronto.ca/TWONTO#00154',
#  'arc-flash suit': 'http://www.toronto.ca/TWONTO#00155',
#  'ash lagoon': 'http://www.toronto.ca/TWONTO#00156',
#  'asset description': 'http://www.toronto.ca/TWONTO#00158',
#  'asset manufacturer': 'http://www.toronto.ca/TWONTO#00159',
#  'asset operation state': 'http://www.toronto.ca/TWONTO#00160',
#  'asset owner': 'http://www.toronto.ca/TWONTO#00161',
#  'asset physical status': 'http://www.toronto.ca/TWONTO#00162',
#  'auto sampler': 'http://www.toronto.ca/TWONTO#00163',
#  'defibrillator': 'http://www.toronto.ca/TWONTO#00164',
#  'backflow preventer': 'http://www.toronto.ca/TWONTO#00165',
#  'bar screen': 'http://www.toronto.ca/TWONTO#00166',
#  'battery': 'http://www.toronto.ca/TWONTO#00167',
#  'battery charger': 'http://www.toronto.ca/TWONTO#00168',
#  'bearing': 'http://www.toronto.ca/TWONTO#00169',
#  'being a part of': 'http://www.toronto.ca/TWONTO#00170',
#  'belt conveyor': 'http://www.toronto.ca/TWONTO#00172',
#  'berm': 'http://www.toronto.ca/TWONTO#00174',
#  'biogas': 'http://www.toronto.ca/TWONTO#00176',
#  'bioreactor': 'http://www.toronto.ca/TWONTO#00177',
#  'bioswale': 'http://www.toronto.ca/TWONTO#00178',
#  'blower': 'http://www.toronto.ca/TWONTO#00179',
#  'boat': 'http://www.toronto.ca/TWONTO#00181',
#  'body material': 'http://www.toronto.ca/TWONTO#00182',
#  'boiler': 'http://www.toronto.ca/TWONTO#00183',
#  'boiler fitting (MBC)': 'http://www.toronto.ca/TWONTO#00184',
#  'boiler heating surface area': 'http://www.toronto.ca/TWONTO#00185',
#  'breaker': 'http://www.toronto.ca/TWONTO#00186',
#  'bridge': 'http://www.toronto.ca/TWONTO#00187',
#  'building': 'http://www.toronto.ca/TWONTO#00189',
#  'buidling or structure(MBC)': 'http://www.toronto.ca/TWONTO#00190',
#  'burner': 'http://www.toronto.ca/TWONTO#00191',
#  'cable segment': 'http://www.toronto.ca/TWONTO#00192',
#  'capacitor': 'http://www.toronto.ca/TWONTO#00194',
#  'capital project': 'http://www.toronto.ca/TWONTO#00195',
#  'cargo van': 'http://www.toronto.ca/TWONTO#00197',
#  'catch basin': 'http://www.toronto.ca/TWONTO#00198',
#  'category G boiler fitting': 'http://www.toronto.ca/TWONTO#00199',
#  'centrifuge': 'http://www.toronto.ca/TWONTO#00200',
#  'chain and flight collector': 'http://www.toronto.ca/TWONTO#00201',
#  'gate': 'http://www.toronto.ca/TWONTO#00202',
#  'channel segment': 'http://www.toronto.ca/TWONTO#00203',
#  'check valve': 'http://www.toronto.ca/TWONTO#00204',
#  'chemical contact tank': 'http://www.toronto.ca/TWONTO#00205',
#  'chemical dosing system': 'http://www.toronto.ca/TWONTO#00206',
#  'chemical feeder': 'http://www.toronto.ca/TWONTO#00207',
#  'chemical or concentration analyzer (MBC)': 'http://www.toronto.ca/TWONTO#00208',
#  'chemical or concentration sensor element (MBC)': 'http://www.toronto.ca/TWONTO#00209',
#  'chemical storage tank': 'http://www.toronto.ca/TWONTO#00211',
#  'chemical suit': 'http://www.toronto.ca/TWONTO#00212',
#  'chiller': 'http://www.toronto.ca/TWONTO#00213',
#  'chloramination analyzer': 'http://www.toronto.ca/TWONTO#00214',
#  'chlorinator': 'http://www.toronto.ca/TWONTO#00215',
#  'chlorine analyzer': 'http://www.toronto.ca/TWONTO#00216',
#  'chlorine disinfection tank': 'http://www.toronto.ca/TWONTO#00217',
#  'city by law': 'http://www.toronto.ca/TWONTO#00218',
#  'clarifier': 'http://www.toronto.ca/TWONTO#00219',
#  'classifier': 'http://www.toronto.ca/TWONTO#00220',
#  'coagulation-flocculation tank': 'http://www.toronto.ca/TWONTO#00221',
#  'coagulation tank': 'http://www.toronto.ca/TWONTO#00222',
#  'collection of assets': 'http://www.toronto.ca/TWONTO#00224',
#  'collector mechanism': 'http://www.toronto.ca/TWONTO#00226',
#  'combustible material': 'http://www.toronto.ca/TWONTO#00227',
#  'common boiler medium': 'http://www.toronto.ca/TWONTO#00228',
#  'communication': 'http://www.toronto.ca/TWONTO#00229',
#  'communication or networking equipment (MBC)': 'http://www.toronto.ca/TWONTO#00231',
#  'compactor': 'http://www.toronto.ca/TWONTO#00232',
#  'compressor': 'http://www.toronto.ca/TWONTO#00233',
#  'computer': 'http://www.toronto.ca/TWONTO#00234',
#  'condensate trap': 'http://www.toronto.ca/TWONTO#00235',
#  'condenser': 'http://www.toronto.ca/TWONTO#00236',
#  'conductivity sensing': 'http://www.toronto.ca/TWONTO#00237',
#  'construction or earthmoving machine (MBC)': 'http://www.toronto.ca/TWONTO#00238',
#  'containing': 'http://www.toronto.ca/TWONTO#00239',
#  'content compilation': 'http://www.toronto.ca/TWONTO#00240',
#  'content subject': 'http://www.toronto.ca/TWONTO#00241',
#  'content summary': 'http://www.toronto.ca/TWONTO#00242',
#  'control loop': 'http://www.toronto.ca/TWONTO#00243',
#  'door access control system': 'http://www.toronto.ca/TWONTO#00244',
#  'conveyor': 'http://www.toronto.ca/TWONTO#00245',
#  'cooling tower': 'http://www.toronto.ca/TWONTO#00246',
#  'corporate policy': 'http://www.toronto.ca/TWONTO#00247',
#  'corrective work': 'http://www.toronto.ca/TWONTO#00248',
#  'particle counter': 'http://www.toronto.ca/TWONTO#00250',
#  'crane': 'http://www.toronto.ca/TWONTO#00251',
#  'culvert': 'http://www.toronto.ca/TWONTO#00252',
#  'cyclone classifier': 'http://www.toronto.ca/TWONTO#00253',
#  'damper actuator': 'http://www.toronto.ca/TWONTO#00254',
#  'data logger': 'http://www.toronto.ca/TWONTO#00255',
#  'data record': 'http://www.toronto.ca/TWONTO#00256',
#  'davit crane': 'http://www.toronto.ca/TWONTO#00257',
#  'define set of discrete asset roles': 'http://www.toronto.ca/TWONTO#00258',
#  'define set of functional structure roles': 'http://www.toronto.ca/TWONTO#00259',
#  'defined collection of assets': 'http://www.toronto.ca/TWONTO#00260',
#  'defined set of roles': 'http://www.toronto.ca/TWONTO#00261',
#  'defined state': 'http://www.toronto.ca/TWONTO#00262',
#  'dehumidifier': 'http://www.toronto.ca/TWONTO#00263',
#  'density sensing': 'http://www.toronto.ca/TWONTO#00264',
#  'description': 'http://www.toronto.ca/TWONTO#00265',
#  'detention tank': 'http://www.toronto.ca/TWONTO#00266',
#  'diesel': 'http://www.toronto.ca/TWONTO#00268',
#  'digester gas': 'http://www.toronto.ca/TWONTO#00270',
#  'digester tank': 'http://www.toronto.ca/TWONTO#00271',
#  'discrete piece of work specification': 'http://www.toronto.ca/TWONTO#00275',
#  'discrete unit of treatment filter': 'http://www.toronto.ca/TWONTO#00277',
#  'discrete unit of work': 'http://www.toronto.ca/TWONTO#00278',
#  'display or monitor': 'http://www.toronto.ca/TWONTO#00279',
#  'dissolved oxygen analyzer': 'http://www.toronto.ca/TWONTO#00280',
#  'distributed system': 'http://www.toronto.ca/TWONTO#00282',
#  'distribution system': 'http://www.toronto.ca/TWONTO#00283',
#  'document content': 'http://www.toronto.ca/TWONTO#00284',
#  'dolly or hand truck': 'http://www.toronto.ca/TWONTO#00285',
#  'door': 'http://www.toronto.ca/TWONTO#00286',
#  'dosing pump': 'http://www.toronto.ca/TWONTO#00287',
#  'drain': 'http://www.toronto.ca/TWONTO#00288',
#  'drive mechanism': 'http://www.toronto.ca/TWONTO#00289',
#  'driving': 'http://www.toronto.ca/TWONTO#00290',
#  'dust collector': 'http://www.toronto.ca/TWONTO#00292',
#  'injector, ejector, or eductor': 'http://www.toronto.ca/TWONTO#00294',
#  'electrical conduit section': 'http://www.toronto.ca/TWONTO#00295',
#  'electrical current sensing': 'http://www.toronto.ca/TWONTO#00296',
#  'electrical distribution system component (MBC)': 'http://www.toronto.ca/TWONTO#00298',
#  'electrical duct bank section': 'http://www.toronto.ca/TWONTO#00299',
#  'electrical distribution panel': 'http://www.toronto.ca/TWONTO#00300',
#  'electrical power sensing': 'http://www.toronto.ca/TWONTO#00301',
#  'fixed electrical meter': 'http://www.toronto.ca/TWONTO#00302',
#  'electrostatic precipitator': 'http://www.toronto.ca/TWONTO#00303',
#  'eletrical resistance sensing': 'http://www.toronto.ca/TWONTO#00304',
#  'elevated water tank': 'http://www.toronto.ca/TWONTO#00305',
#  'elevator': 'http://www.toronto.ca/TWONTO#00306',
#  'emergency eyewash': 'http://www.toronto.ca/TWONTO#00307',
#  'emergency eyewash and shower': 'http://www.toronto.ca/TWONTO#00308',
#  'emergency power system': 'http://www.toronto.ca/TWONTO#00309',
#  'emergency shower': 'http://www.toronto.ca/TWONTO#00311',
#  'emergency work': 'http://www.toronto.ca/TWONTO#00312',
#  'energy recovery wheel': 'http://www.toronto.ca/TWONTO#00315',
#  'engine': 'http://www.toronto.ca/TWONTO#00316',
#  'environmental hazard': 'http://www.toronto.ca/TWONTO#00317',
#  'chamber': 'http://www.toronto.ca/TWONTO#00318',
#  'equipment local panel': 'http://www.toronto.ca/TWONTO#00319',
#  'equipment trailer': 'http://www.toronto.ca/TWONTO#00320',
#  'HVAC evaporator': 'http://www.toronto.ca/TWONTO#00321',
#  'exhaust stack': 'http://www.toronto.ca/TWONTO#00323',
#  'expansion joint': 'http://www.toronto.ca/TWONTO#00324',
#  'expansion tank': 'http://www.toronto.ca/TWONTO#00325',
#  'eyewash bottle': 'http://www.toronto.ca/TWONTO#00328',
#  'facility': 'http://www.toronto.ca/TWONTO#00330',
#  'fall protection system support struture': 'http://www.toronto.ca/TWONTO#00331',
#  'fall arrest harness': 'http://www.toronto.ca/TWONTO#00332',
#  'fall arrest lanyard': 'http://www.toronto.ca/TWONTO#00333',
#  'fall arrest rope grab': 'http://www.toronto.ca/TWONTO#00334',
#  'fall arrest system': 'http://www.toronto.ca/TWONTO#00335',
#  'fall protection descending device': 'http://www.toronto.ca/TWONTO#00336',
#  'fall protection system component (MBC)': 'http://www.toronto.ca/TWONTO#00339',
#  'fall restraint system': 'http://www.toronto.ca/TWONTO#00340',
#  'fall restricting system': 'http://www.toronto.ca/TWONTO#00341',
#  'federal regulation': 'http://www.toronto.ca/TWONTO#00342',
#  'fence section': 'http://www.toronto.ca/TWONTO#00343',
#  'figure content': 'http://www.toronto.ca/TWONTO#00344',
#  'filter sweep arm': 'http://www.toronto.ca/TWONTO#00346',
#  'filtration tank': 'http://www.toronto.ca/TWONTO#00348',
#  'fire extinguisher': 'http://www.toronto.ca/TWONTO#00350',
#  'fire hose': 'http://www.toronto.ca/TWONTO#00351',
#  'fire protection sprinkler': 'http://www.toronto.ca/TWONTO#00352',
#  'fire rated door': 'http://www.toronto.ca/TWONTO#00353',
#  'first aid equipment or component (MBC)': 'http://www.toronto.ca/TWONTO#00354',
#  'first aid kit': 'http://www.toronto.ca/TWONTO#00355',
#  'first aid room equipment': 'http://www.toronto.ca/TWONTO#00356',
#  'first aid station equipment': 'http://www.toronto.ca/TWONTO#00357',
#  'pipe fitting (MBC)': 'http://www.toronto.ca/TWONTO#00358',
#  'fixed gas detector': 'http://www.toronto.ca/TWONTO#00359',
#  'fixed ladder': 'http://www.toronto.ca/TWONTO#00360',
#  'flame arrester': 'http://www.toronto.ca/TWONTO#00361',
#  'flame sensor': 'http://www.toronto.ca/TWONTO#00362',
#  'flotation tank': 'http://www.toronto.ca/TWONTO#00363',
#  'flocculation tank': 'http://www.toronto.ca/TWONTO#00364',
#  'flow calibrator': 'http://www.toronto.ca/TWONTO#00365',
#  'flow sensor element': 'http://www.toronto.ca/TWONTO#00366',
#  'flow switch': 'http://www.toronto.ca/TWONTO#00367',
#  'flowmeter': 'http://www.toronto.ca/TWONTO#00369',
#  'fluoride analyzer': 'http://www.toronto.ca/TWONTO#00371',
#  'forklift': 'http://www.toronto.ca/TWONTO#00372',
#  'foundation of building or structure': 'http://www.toronto.ca/TWONTO#00373',
#  'fuel': 'http://www.toronto.ca/TWONTO#00374',
#  'fuel burning heater': 'http://www.toronto.ca/TWONTO#00376',
#  'fuel oil': 'http://www.toronto.ca/TWONTO#00377',
#  'fuel oil appliance': 'http://www.toronto.ca/TWONTO#00378',
#  'fuel oil tank': 'http://www.toronto.ca/TWONTO#00379',
#  'fuel piping system': 'http://www.toronto.ca/TWONTO#00380',
#  'fuel tank': 'http://www.toronto.ca/TWONTO#00381',
#  'function and capability': 'http://www.toronto.ca/TWONTO#00382',
#  'functional structure role': 'http://www.toronto.ca/TWONTO#00383',
#  'furnace': 'http://www.toronto.ca/TWONTO#00385',
#  'fuse': 'http://www.toronto.ca/TWONTO#00386',
#  'fusible plug': 'http://www.toronto.ca/TWONTO#00387',
#  'gas appliance': 'http://www.toronto.ca/TWONTO#00388',
#  'gas collector': 'http://www.toronto.ca/TWONTO#00389',
#  'gas detector calibrator': 'http://www.toronto.ca/TWONTO#00390',
#  'gas diffuser head': 'http://www.toronto.ca/TWONTO#00391',
#  'gaseous material': 'http://www.toronto.ca/TWONTO#00393',
#  'gasoline': 'http://www.toronto.ca/TWONTO#00394',
#  'gasoline tank': 'http://www.toronto.ca/TWONTO#00395',
#  'gearbox': 'http://www.toronto.ca/TWONTO#00396',
#  'generator': 'http://www.toronto.ca/TWONTO#00397',
#  'generator trailer': 'http://www.toronto.ca/TWONTO#00398',
#  'golf cart or utility task vehicle': 'http://www.toronto.ca/TWONTO#00400',
#  'government regulation': 'http://www.toronto.ca/TWONTO#00401',
#  'granular material': 'http://www.toronto.ca/TWONTO#00402',
#  'gravity sewer segment': 'http://www.toronto.ca/TWONTO#00403',
#  'grease gun': 'http://www.toronto.ca/TWONTO#00404',
#  'grinder or comminutor': 'http://www.toronto.ca/TWONTO#00405',
#  'ground fault tester': 'http://www.toronto.ca/TWONTO#00406',
#  'grounds or building service equipment (MBC)': 'http://www.toronto.ca/TWONTO#00408',
#  'guideline': 'http://www.toronto.ca/TWONTO#00409',
#  'manual switch': 'http://www.toronto.ca/TWONTO#00411',
#  'having a part': 'http://www.toronto.ca/TWONTO#00412',
#  'having process medium': 'http://www.toronto.ca/TWONTO#00413',
#  'hazard': 'http://www.toronto.ca/TWONTO#00414',
#  'health and safety hazard': 'http://www.toronto.ca/TWONTO#00415',
#  'heat exchanger': 'http://www.toronto.ca/TWONTO#00416',
#  'heat trace heating element': 'http://www.toronto.ca/TWONTO#00417',
#  'space heater': 'http://www.toronto.ca/TWONTO#00418',
#  'heating boiler': 'http://www.toronto.ca/TWONTO#00419',
#  'heating coil': 'http://www.toronto.ca/TWONTO#00420',
#  'heavy metal analyzer': 'http://www.toronto.ca/TWONTO#00421',
#  'hoist': 'http://www.toronto.ca/TWONTO#00422',
#  'hopper': 'http://www.toronto.ca/TWONTO#00423',
#  'horizontal lifeline': 'http://www.toronto.ca/TWONTO#00424',
#  'hose': 'http://www.toronto.ca/TWONTO#00425',
#  'hot stick': 'http://www.toronto.ca/TWONTO#00426',
#  'hot water heater': 'http://www.toronto.ca/TWONTO#00427',
#  'hot work equipment': 'http://www.toronto.ca/TWONTO#00428',
#  'humidifier': 'http://www.toronto.ca/TWONTO#00429',
#  'humidity sensor': 'http://www.toronto.ca/TWONTO#00430',
#  'hydrant': 'http://www.toronto.ca/TWONTO#00431',
#  'hydrant system': 'http://www.toronto.ca/TWONTO#00432',
#  'hydraulic power pack': 'http://www.toronto.ca/TWONTO#00433',
#  'hydraulic system': 'http://www.toronto.ca/TWONTO#00434',
#  'incinerator': 'http://www.toronto.ca/TWONTO#00435',
#  'infiltration trench segment': 'http://www.toronto.ca/TWONTO#00436',
#  'information reception': 'http://www.toronto.ca/TWONTO#00438',
#  'information transmission': 'http://www.toronto.ca/TWONTO#00439',
#  'informative resource': 'http://www.toronto.ca/TWONTO#00440',
#  'infrared camera': 'http://www.toronto.ca/TWONTO#00441',
#  'inspection route': 'http://www.toronto.ca/TWONTO#00442',
#  'instrument air or pneumatic control panel': 'http://www.toronto.ca/TWONTO#00443',
#  'instrument air or pneumatic system component (MBC)': 'http://www.toronto.ca/TWONTO#00444',
#  'instrument gauge or indicator (MBC)': 'http://www.toronto.ca/TWONTO#00445',
#  'sensor element (MBC)': 'http://www.toronto.ca/TWONTO#00446',
#  'intrument with a transmitter': 'http://www.toronto.ca/TWONTO#00447',
#  'interceptor segment': 'http://www.toronto.ca/TWONTO#00449',
#  'intercom station': 'http://www.toronto.ca/TWONTO#00450',
#  'interpretation': 'http://www.toronto.ca/TWONTO#00451',
#  'investigative work': 'http://www.toronto.ca/TWONTO#00452',
#  'jointer': 'http://www.toronto.ca/TWONTO#00453',
#  'junction': 'http://www.toronto.ca/TWONTO#00454',
#  'junction structure role': 'http://www.toronto.ca/TWONTO#00455',
#  'kerosene': 'http://www.toronto.ca/TWONTO#00456',
#  'ladder': 'http://www.toronto.ca/TWONTO#00457',
#  'landfill gas': 'http://www.toronto.ca/TWONTO#00458',
#  'landscape feature or green infrastructure (MBC)': 'http://www.toronto.ca/TWONTO#00459',
#  'lathe': 'http://www.toronto.ca/TWONTO#00460',
#  'lawn mower': 'http://www.toronto.ca/TWONTO#00461',
#  'legislation': 'http://www.toronto.ca/TWONTO#00463',
#  'level sensing': 'http://www.toronto.ca/TWONTO#00464',
#  'level sensor element': 'http://www.toronto.ca/TWONTO#00465',
#  'level switch': 'http://www.toronto.ca/TWONTO#00466',
#  'level transmitter': 'http://www.toronto.ca/TWONTO#00467',
#  'lifeline': 'http://www.toronto.ca/TWONTO#00470',
#  'lift truck or pallet jack': 'http://www.toronto.ca/TWONTO#00473',
#  'lifting device or lifting device component (MBC)': 'http://www.toronto.ca/TWONTO#00474',
#  'light sensing': 'http://www.toronto.ca/TWONTO#00476',
#  '120V/240V electrical panel': 'http://www.toronto.ca/TWONTO#00477',
#  'line': 'http://www.toronto.ca/TWONTO#00479',
#  'line structure role': 'http://www.toronto.ca/TWONTO#00480',
#  'linear function structure': 'http://www.toronto.ca/TWONTO#00481',
#  'linear function structure role': 'http://www.toronto.ca/TWONTO#00482',
#  'liquid': 'http://www.toronto.ca/TWONTO#00483',
#  'live voltage tester tool': 'http://www.toronto.ca/TWONTO#00485',
#  'load bearing': 'http://www.toronto.ca/TWONTO#00486',
#  'load break disconnect switch': 'http://www.toronto.ca/TWONTO#00487',
#  'machine component (MBC)': 'http://www.toronto.ca/TWONTO#00489',
#  'major treatment process role': 'http://www.toronto.ca/TWONTO#00491',
#  'man lift': 'http://www.toronto.ca/TWONTO#00492',
#  'manhole': 'http://www.toronto.ca/TWONTO#00493',
#  'mass spectrometer': 'http://www.toronto.ca/TWONTO#00500',
#  'max holding capacity': 'http://www.toronto.ca/TWONTO#00503',
#  'max input voltage': 'http://www.toronto.ca/TWONTO#00504',
#  'max medium temperature': 'http://www.toronto.ca/TWONTO#00505',
#  'max operating pressure': 'http://www.toronto.ca/TWONTO#00506',
#  'measure of area': 'http://www.toronto.ca/TWONTO#00507',
#  'measure of current flow': 'http://www.toronto.ca/TWONTO#00508',
#  'measure of mass': 'http://www.toronto.ca/TWONTO#00509',
#  'measure of mass flow': 'http://www.toronto.ca/TWONTO#00510',
#  'measure of power level': 'http://www.toronto.ca/TWONTO#00511',
#  'measure of pressure': 'http://www.toronto.ca/TWONTO#00512',
#  'measure of property': 'http://www.toronto.ca/TWONTO#00513',
#  'measure of rotational speed': 'http://www.toronto.ca/TWONTO#00514',
#  'measure of speed': 'http://www.toronto.ca/TWONTO#00515',
#  'measure of temperature': 'http://www.toronto.ca/TWONTO#00516',
#  'measure of voltage level': 'http://www.toronto.ca/TWONTO#00517',
#  'measure of volume': 'http://www.toronto.ca/TWONTO#00518',
#  'measurement': 'http://www.toronto.ca/TWONTO#00519',
#  'instrumentation (MBC)': 'http://www.toronto.ca/TWONTO#00520',
#  'member of TW Broader Asset Class Category (MBC)': 'http://www.toronto.ca/TWONTO#00522',
#  'membrane bioreactor': 'http://www.toronto.ca/TWONTO#00523',
#  'milling machine': 'http://www.toronto.ca/TWONTO#00524',
#  'min input voltage': 'http://www.toronto.ca/TWONTO#00525',
#  'mixer': 'http://www.toronto.ca/TWONTO#00526',
#  'mobile radio': 'http://www.toronto.ca/TWONTO#00527',
#  'modular trailer office': 'http://www.toronto.ca/TWONTO#00529',
#  'motion sensor element': 'http://www.toronto.ca/TWONTO#00530',
#  'motor': 'http://www.toronto.ca/TWONTO#00531',
#  'motor starter': 'http://www.toronto.ca/TWONTO#00532',
#  'multimeter': 'http://www.toronto.ca/TWONTO#00534',
#  'natural gas': 'http://www.toronto.ca/TWONTO#00535',
#  'network panel': 'http://www.toronto.ca/TWONTO#00537',
#  'network router': 'http://www.toronto.ca/TWONTO#00538',
#  'network switch': 'http://www.toronto.ca/TWONTO#00539',
#  'network termination panel': 'http://www.toronto.ca/TWONTO#00540',
#  'nitrate or nitrite analyzer': 'http://www.toronto.ca/TWONTO#00541',
#  'nominal input voltage': 'http://www.toronto.ca/TWONTO#00542',
#  'note taking': 'http://www.toronto.ca/TWONTO#00543',
#  'observation': 'http://www.toronto.ca/TWONTO#00544',
#  'occupying': 'http://www.toronto.ca/TWONTO#00545',
#  'oil grit separator': 'http://www.toronto.ca/TWONTO#00546',
#  'operation unit assets': 'http://www.toronto.ca/TWONTO#00547',
#  'HMI': 'http://www.toronto.ca/TWONTO#00548',
#  'orthophosphate analyzer': 'http://www.toronto.ca/TWONTO#00550',
#  'outfall': 'http://www.toronto.ca/TWONTO#00551',
#  'ozone analyzer': 'http://www.toronto.ca/TWONTO#00552',
#  'ozone generator': 'http://www.toronto.ca/TWONTO#00553',
#  'package of discrete work': 'http://www.toronto.ca/TWONTO#00554',
#  'paragraph content': 'http://www.toronto.ca/TWONTO#00557',
#  'building component or structural component (MBC)': 'http://www.toronto.ca/TWONTO#00558',
#  'passenger vehicle': 'http://www.toronto.ca/TWONTO#00559',
#  'pelletizer': 'http://www.toronto.ca/TWONTO#00560',
#  'personal floatation device': 'http://www.toronto.ca/TWONTO#00561',
#  'phosphate analyzer': 'http://www.toronto.ca/TWONTO#00562',
#  'physical security system component (MBC)': 'http://www.toronto.ca/TWONTO#00563',
#  'pickup truck': 'http://www.toronto.ca/TWONTO#00564',
#  'piece of content': 'http://www.toronto.ca/TWONTO#00565',
#  'piece of furniture (MBC)': 'http://www.toronto.ca/TWONTO#00566',
#  'lab equipment (MBC)': 'http://www.toronto.ca/TWONTO#00567',
#  'pipe manifold': 'http://www.toronto.ca/TWONTO#00568',
#  'pipe segment': 'http://www.toronto.ca/TWONTO#00569',
#  'pipette': 'http://www.toronto.ca/TWONTO#00570',
#  'piping end cap': 'http://www.toronto.ca/TWONTO#00571',
#  'piping system': 'http://www.toronto.ca/TWONTO#00572',
#  'piping system component (MBC)': 'http://www.toronto.ca/TWONTO#00573',
#  'planer': 'http://www.toronto.ca/TWONTO#00574',
#  'plumbing': 'http://www.toronto.ca/TWONTO#00577',
#  'pneumatic control system': 'http://www.toronto.ca/TWONTO#00578',
#  'polymer preparation system unit': 'http://www.toronto.ca/TWONTO#00579',
#  'pond': 'http://www.toronto.ca/TWONTO#00580',
#  'portable chlorine analyzer': 'http://www.toronto.ca/TWONTO#00581',
#  'portable compressed gas cylinder': 'http://www.toronto.ca/TWONTO#00582',
#  'portable gas detector': 'http://www.toronto.ca/TWONTO#00583',
#  'portable grounding cable': 'http://www.toronto.ca/TWONTO#00584',
#  'portable ladder': 'http://www.toronto.ca/TWONTO#00585',
#  'portable vibration analyzer': 'http://www.toronto.ca/TWONTO#00587',
#  'portion of granular filter medium': 'http://www.toronto.ca/TWONTO#00588',
#  'position sensing': 'http://www.toronto.ca/TWONTO#00589',
#  'position switch': 'http://www.toronto.ca/TWONTO#00590',
#  'position transmitter': 'http://www.toronto.ca/TWONTO#00591',
#  'power boiler': 'http://www.toronto.ca/TWONTO#00593',
#  'power disconnect switch': 'http://www.toronto.ca/TWONTO#00594',
#  'power washer': 'http://www.toronto.ca/TWONTO#00596',
#  'pressure calibrator': 'http://www.toronto.ca/TWONTO#00599',
#  'pressure relief device': 'http://www.toronto.ca/TWONTO#00600',
#  'pressure relief valve': 'http://www.toronto.ca/TWONTO#00601',
#  'pressure sensing': 'http://www.toronto.ca/TWONTO#00602',
#  'pressure sensor element': 'http://www.toronto.ca/TWONTO#00603',
#  'pressure switch': 'http://www.toronto.ca/TWONTO#00604',
#  'pressure transmitter': 'http://www.toronto.ca/TWONTO#00605',
#  'pressure vessel': 'http://www.toronto.ca/TWONTO#00606',
#  'pressurized piping system': 'http://www.toronto.ca/TWONTO#00607',
#  'pressurized sewer segment': 'http://www.toronto.ca/TWONTO#00608',
#  'preventive work': 'http://www.toronto.ca/TWONTO#00609',
#  'primary path line': 'http://www.toronto.ca/TWONTO#00610',
#  'primary path line role': 'http://www.toronto.ca/TWONTO#00611',
#  'process control panel': 'http://www.toronto.ca/TWONTO#00613',
#  'process controller': 'http://www.toronto.ca/TWONTO#00614',
#  'process pipe segment': 'http://www.toronto.ca/TWONTO#00616',
#  'processing': 'http://www.toronto.ca/TWONTO#00617',
#  'programmable controller': 'http://www.toronto.ca/TWONTO#00618',
#  'project': 'http://www.toronto.ca/TWONTO#00619',
#  'propane': 'http://www.toronto.ca/TWONTO#00620',
#  'protection relay': 'http://www.toronto.ca/TWONTO#00622',
#  'publisher': 'http://www.toronto.ca/TWONTO#00623',
#  'emergency pull station': 'http://www.toronto.ca/TWONTO#00624',
#  'pulsation dampener': 'http://www.toronto.ca/TWONTO#00625',
#  'pump': 'http://www.toronto.ca/TWONTO#00626',
#  'pumping station': 'http://www.toronto.ca/TWONTO#00628',
#  'pumping surge suppression tank': 'http://www.toronto.ca/TWONTO#00629',
#  'qualification': 'http://www.toronto.ca/TWONTO#00631',
#  'quality': 'http://www.toronto.ca/TWONTO#00632',
#  'quencher': 'http://www.toronto.ca/TWONTO#00633',
#  'radial arm drill': 'http://www.toronto.ca/TWONTO#00634',
#  'rated power output': 'http://www.toronto.ca/TWONTO#00635',
#  'treatment process reactor (MBC)': 'http://www.toronto.ca/TWONTO#00636',
#  'rectifier': 'http://www.toronto.ca/TWONTO#00637',
#  'refrigerated storage': 'http://www.toronto.ca/TWONTO#00638',
#  'relational state': 'http://www.toronto.ca/TWONTO#00639',
#  'relief valve': 'http://www.toronto.ca/TWONTO#00640',
#  'replaceable air filter': 'http://www.toronto.ca/TWONTO#00641',
#  'replaceable oil or fuel filter': 'http://www.toronto.ca/TWONTO#00642',
#  'requirement': 'http://www.toronto.ca/TWONTO#00643',
#  'reservoir tank': 'http://www.toronto.ca/TWONTO#00644',
#  'revision': 'http://www.toronto.ca/TWONTO#00646',
#  'road segment': 'http://www.toronto.ca/TWONTO#00647',
#  'roll up door': 'http://www.toronto.ca/TWONTO#00649',
#  'roof': 'http://www.toronto.ca/TWONTO#00650',
#  'rotating collector': 'http://www.toronto.ca/TWONTO#00652',
#  'insulated glove': 'http://www.toronto.ca/TWONTO#00653',
#  'rubber insulating sleeves': 'http://www.toronto.ca/TWONTO#00654',
#  'rupture disc': 'http://www.toronto.ca/TWONTO#00655',
#  'safety or hazard management equipment (MBC)': 'http://www.toronto.ca/TWONTO#00657',
#  'safety relief valve': 'http://www.toronto.ca/TWONTO#00658',
#  'safety valve': 'http://www.toronto.ca/TWONTO#00659',
#  'sampling point': 'http://www.toronto.ca/TWONTO#00660',
#  'sampling pump': 'http://www.toronto.ca/TWONTO#00661',
#  'sampling sink': 'http://www.toronto.ca/TWONTO#00662',
#  'sandblaster': 'http://www.toronto.ca/TWONTO#00663',
#  'scaffolding': 'http://www.toronto.ca/TWONTO#00664',
#  'screening unit': 'http://www.toronto.ca/TWONTO#00665',
#  'screw classifier': 'http://www.toronto.ca/TWONTO#00666',
#  'screw conveyor': 'http://www.toronto.ca/TWONTO#00667',
#  'screw press': 'http://www.toronto.ca/TWONTO#00668',
#  'seal or gasket': 'http://www.toronto.ca/TWONTO#00669',
#  'section content': 'http://www.toronto.ca/TWONTO#00670',
#  'security camera': 'http://www.toronto.ca/TWONTO#00671',
#  'security motion sensor': 'http://www.toronto.ca/TWONTO#00672',
#  'security system': 'http://www.toronto.ca/TWONTO#00673',
#  'pipe-mounted sediment trap': 'http://www.toronto.ca/TWONTO#00674',
#  'sedimentation tank': 'http://www.toronto.ca/TWONTO#00675',
#  'segment of linear asset (MBC)': 'http://www.toronto.ca/TWONTO#00676',
#  'self-retracting lifeline': 'http://www.toronto.ca/TWONTO#00677',
#  'semi-solid': 'http://www.toronto.ca/TWONTO#00678',
#  'sensing': 'http://www.toronto.ca/TWONTO#00679',
#  'server appliance': 'http://www.toronto.ca/TWONTO#00680',
#  'sewer segment': 'http://www.toronto.ca/TWONTO#00681',
#  'sewer service connection': 'http://www.toronto.ca/TWONTO#00682',
#  'simple line': 'http://www.toronto.ca/TWONTO#00684',
#  'simple line role': 'http://www.toronto.ca/TWONTO#00685',
#  'situated within': 'http://www.toronto.ca/TWONTO#00687',
#  'sludge density meter': 'http://www.toronto.ca/TWONTO#00689',
#  'sludge': 'http://www.toronto.ca/TWONTO#00690',
#  'sludge blanket analyzer': 'http://www.toronto.ca/TWONTO#00691',
#  'rotary drum thickener': 'http://www.toronto.ca/TWONTO#00692',
#  'solenoid valve': 'http://www.toronto.ca/TWONTO#00694',
#  'solid': 'http://www.toronto.ca/TWONTO#00695',
#  'specification description': 'http://www.toronto.ca/TWONTO#00697',
#  'speed sensing': 'http://www.toronto.ca/TWONTO#00698',
#  'speed switch': 'http://www.toronto.ca/TWONTO#00699',
#  'spill kit': 'http://www.toronto.ca/TWONTO#00700',
#  'sprinkler': 'http://www.toronto.ca/TWONTO#00701',
#  'landline telephone': 'http://www.toronto.ca/TWONTO#00702',
#  'machine tool (MBC)': 'http://www.toronto.ca/TWONTO#00703',
#  'mobile still or video camera': 'http://www.toronto.ca/TWONTO#00706',
#  'storage cabinet': 'http://www.toronto.ca/TWONTO#00707',
#  'storage tank': 'http://www.toronto.ca/TWONTO#00708',
#  'storm service connection': 'http://www.toronto.ca/TWONTO#00709',
#  'strainer': 'http://www.toronto.ca/TWONTO#00710',
#  'structural part': 'http://www.toronto.ca/TWONTO#00711',
#  'structural tank part of asset': 'http://www.toronto.ca/TWONTO#00712',
#  'structural wall': 'http://www.toronto.ca/TWONTO#00713',
#  'substation': 'http://www.toronto.ca/TWONTO#00714',
#  'subsystem of a discrete asset': 'http://www.toronto.ca/TWONTO#00715',
#  'sulphonation system': 'http://www.toronto.ca/TWONTO#00716',
#  'voltage surge suppressor': 'http://www.toronto.ca/TWONTO#00718',
#  'system process control': 'http://www.toronto.ca/TWONTO#00722',
#  'system train': 'http://www.toronto.ca/TWONTO#00723',
#  'system train role': 'http://www.toronto.ca/TWONTO#00724',
#  'table content': 'http://www.toronto.ca/TWONTO#00725',
#  'table saw': 'http://www.toronto.ca/TWONTO#00726',
#  'tank or vessel part of asset': 'http://www.toronto.ca/TWONTO#00727',
#  'technical standard': 'http://www.toronto.ca/TWONTO#00730',
#  'telephone system': 'http://www.toronto.ca/TWONTO#00731',
#  'temperature sensing': 'http://www.toronto.ca/TWONTO#00732',
#  'temperature sensor element': 'http://www.toronto.ca/TWONTO#00733',
#  'temperature switch': 'http://www.toronto.ca/TWONTO#00734',
#  'temperature transmitter': 'http://www.toronto.ca/TWONTO#00735',
#  'testing tool (MBC)': 'http://www.toronto.ca/TWONTO#00737',
#  'Maximum Allowable Working Pressure': 'http://www.toronto.ca/TWONTO#00738',
#  'Maxiumum Allowable Working Temperature': 'http://www.toronto.ca/TWONTO#00739',
#  'the max input voltage desc': 'http://www.toronto.ca/TWONTO#00740',
#  'Mininum Input Voltage': 'http://www.toronto.ca/TWONTO#00741',
#  'Nominal Output Power': 'http://www.toronto.ca/TWONTO#00742',
#  'the substance in containment': 'http://www.toronto.ca/TWONTO#00743',
#  'the volumetric capacity desc': 'http://www.toronto.ca/TWONTO#00744',
#  'thermostat or zone controller unit': 'http://www.toronto.ca/TWONTO#00746',
#  'tool (MBC)': 'http://www.toronto.ca/TWONTO#00747',
#  'tool kit': 'http://www.toronto.ca/TWONTO#00748',
#  'torque sensing': 'http://www.toronto.ca/TWONTO#00749',
#  'torque switch': 'http://www.toronto.ca/TWONTO#00750',
#  'total dissolved solids analyzer': 'http://www.toronto.ca/TWONTO#00751',
#  'total suspended solids analyzer': 'http://www.toronto.ca/TWONTO#00752',
#  'trailer': 'http://www.toronto.ca/TWONTO#00753',
#  'transfer switch': 'http://www.toronto.ca/TWONTO#00754',
#  'transformer': 'http://www.toronto.ca/TWONTO#00755',
#  'vehicle, transportation tool, or accessory (MBC)': 'http://www.toronto.ca/TWONTO#00756',
#  'trap priming device': 'http://www.toronto.ca/TWONTO#00757',
#  'travelling bridge collector': 'http://www.toronto.ca/TWONTO#00758',
#  'treatment process': 'http://www.toronto.ca/TWONTO#00759',
#  'truck loading dock': 'http://www.toronto.ca/TWONTO#00761',
#  'tunnel': 'http://www.toronto.ca/TWONTO#00762',
#  'turbidity analyzer': 'http://www.toronto.ca/TWONTO#00763',
#  'turbidity sensing': 'http://www.toronto.ca/TWONTO#00764',
#  'ultraviolet analyzer': 'http://www.toronto.ca/TWONTO#00767',
#  'underground fuel oil tank': 'http://www.toronto.ca/TWONTO#00768',
#  'underground fuel tank': 'http://www.toronto.ca/TWONTO#00769',
#  'unit of area': 'http://www.toronto.ca/TWONTO#00770',
#  'unit of electrical current': 'http://www.toronto.ca/TWONTO#00771',
#  'unit of mass': 'http://www.toronto.ca/TWONTO#00772',
#  'unit of measure': 'http://www.toronto.ca/TWONTO#00773',
#  'unit of power': 'http://www.toronto.ca/TWONTO#00774',
#  'unit of pressure': 'http://www.toronto.ca/TWONTO#00775',
#  'unit of temperature': 'http://www.toronto.ca/TWONTO#00776',
#  'unit of voltage': 'http://www.toronto.ca/TWONTO#00777',
#  'unit of volume': 'http://www.toronto.ca/TWONTO#00778',
#  'utility trailer': 'http://www.toronto.ca/TWONTO#00779',
#  'vacuum cleaner': 'http://www.toronto.ca/TWONTO#00780',
#  'valve': 'http://www.toronto.ca/TWONTO#00781',
#  'valve actuator': 'http://www.toronto.ca/TWONTO#00782',
#  'valve role': 'http://www.toronto.ca/TWONTO#00783',
#  'variable air volume unit': 'http://www.toronto.ca/TWONTO#00784',
#  'variable speed drive': 'http://www.toronto.ca/TWONTO#00785',
#  'ventilation system': 'http://www.toronto.ca/TWONTO#00787',
#  'vertical lifeline': 'http://www.toronto.ca/TWONTO#00790',
#  'vibration analyzer': 'http://www.toronto.ca/TWONTO#00791',
#  'vibration sensor element': 'http://www.toronto.ca/TWONTO#00792',
#  'volume capacity': 'http://www.toronto.ca/TWONTO#00793',
#  'vortex classifier': 'http://www.toronto.ca/TWONTO#00794',
#  'waste gas burner': 'http://www.toronto.ca/TWONTO#00795',
#  'wastewater storage pipe': 'http://www.toronto.ca/TWONTO#00796',
#  'water transmission, distribution, and collection system asset (MBC)': 'http://www.toronto.ca/TWONTO#00800',
#  'water service connection': 'http://www.toronto.ca/TWONTO#00801',
#  'water trailer': 'http://www.toronto.ca/TWONTO#00802',
#  'treatment process and support equipment (MBC)': 'http://www.toronto.ca/TWONTO#00803',
#  'watermain segment': 'http://www.toronto.ca/TWONTO#00804',
#  'weather monitoring station': 'http://www.toronto.ca/TWONTO#00805',
#  'weight scale': 'http://www.toronto.ca/TWONTO#00806',
#  'weight sensing': 'http://www.toronto.ca/TWONTO#00807',
#  'weir': 'http://www.toronto.ca/TWONTO#00809',
#  'welding machine': 'http://www.toronto.ca/TWONTO#00810',
#  'well': 'http://www.toronto.ca/TWONTO#00811',
#  'winch': 'http://www.toronto.ca/TWONTO#00812',
#  'windsock': 'http://www.toronto.ca/TWONTO#00813',
#  'wireless receiver': 'http://www.toronto.ca/TWONTO#00815',
#  'wireless tranceiver': 'http://www.toronto.ca/TWONTO#00816',
#  'radio transmitter': 'http://www.toronto.ca/TWONTO#00817',
#  'work': 'http://www.toronto.ca/TWONTO#00818',
#  'work order specification': 'http://www.toronto.ca/TWONTO#00819',
#  'work specification': 'http://www.toronto.ca/TWONTO#00820',
#  'wielding receptacle': 'http://www.toronto.ca/TWONTO#00821',
#  'fire and life-safety system component (MBC)': 'http://www.toronto.ca/TWONTO#00915',
#  'neutral grounding resistor': 'http://www.toronto.ca/TWONTO#00918',
#  'building service system component (MBC)': 'http://www.toronto.ca/TWONTO#00919',
#  'business administration and office equipment (MBC)': 'http://www.toronto.ca/TWONTO#00920',
#  'fire standpipe': 'http://www.toronto.ca/TWONTO#00921',
#  'ignitor': 'http://www.toronto.ca/TWONTO#00922',
#  'linear heat detection element': 'http://www.toronto.ca/TWONTO#00923',
#  'ventilation system component (MBC)': 'http://www.toronto.ca/TWONTO#00924',
#  'solids disposal bin': 'http://www.toronto.ca/TWONTO#00925',
#  'lifting device sling': 'http://www.toronto.ca/TWONTO#00926',
#  'wire-rope sling': 'http://www.toronto.ca/TWONTO#00927',
#  'metal mesh sling': 'http://www.toronto.ca/TWONTO#00928',
#  'synthetic web sling': 'http://www.toronto.ca/TWONTO#00929',
#  'steel chain sling': 'http://www.toronto.ca/TWONTO#00930',
#  'natural or synthetic fiber rope sling': 'http://www.toronto.ca/TWONTO#00931',
#  'water treatment facility intake structure': 'http://www.toronto.ca/TWONTO#00932',
#  'specialized UV disinfection system component (MBC)': 'http://www.toronto.ca/TWONTO#00933',
#  'emergency light': 'http://www.toronto.ca/TWONTO#00934',
#  'motor drive': 'http://www.toronto.ca/TWONTO#00935',
#  'specialized ozone system component (MBC)': 'http://www.toronto.ca/TWONTO#00936',
#  'component of a discrete asset (MBC)': 'http://www.toronto.ca/TWONTO#00939',
#  'density meter': 'http://www.toronto.ca/TWONTO#00942',
#  'watercourse erosion structure': 'http://www.toronto.ca/TWONTO#00943',
#  'analyzer (MBC)': 'http://www.toronto.ca/TWONTO#00944',
#  'fire department connection': 'http://www.toronto.ca/TWONTO#02945',
#  'vacuum pump': 'http://www.toronto.ca/TWONTO#00946',
#  'inverter': 'http://www.toronto.ca/TWONTO#01919',
#  'degF': 'http://www.toronto.ca/TWONTO#Fahrenheit',
#  'available': 'http://www.toronto.ca/TWONTO#asset_available_state',
#  'unavailable': 'http://www.toronto.ca/TWONTO#asset_unavailable_state',
#  'bar': 'http://www.toronto.ca/TWONTO#bar',
#  'degC': 'http://www.toronto.ca/TWONTO#celsius',
#  'ft^3': 'http://www.toronto.ca/TWONTO#cubic_feet',
#  'm^3': 'http://www.toronto.ca/TWONTO#cubic_metre',
#  'hp': 'http://www.toronto.ca/TWONTO#horsepower',
#  'degK': 'http://www.toronto.ca/TWONTO#kelvin',
#  'kPa': 'http://www.toronto.ca/TWONTO#kilo_pascal',
#  'kV': 'http://www.toronto.ca/TWONTO#kilovolt',
#  'kVA': 'http://www.toronto.ca/TWONTO#kilovolt-ampere',
#  'kW': 'http://www.toronto.ca/TWONTO#kilowatt',
#  'L': 'http://www.toronto.ca/TWONTO#litre',
#  'MVA': 'http://www.toronto.ca/TWONTO#megavolt-ampere',
#  'MW': 'http://www.toronto.ca/TWONTO#megawatt',
#  'psi': 'http://www.toronto.ca/TWONTO#pounds_per_square_inch',
#  'cm^2': 'http://www.toronto.ca/TWONTO#square_centimetre',
#  'ft^2': 'http://www.toronto.ca/TWONTO#square_feet',
#  'inch^2': 'http://www.toronto.ca/TWONTO#square_inch',
#  'km^2': 'http://www.toronto.ca/TWONTO#square_kilometre',
#  'm^2': 'http://www.toronto.ca/TWONTO#square_metre',
#  'mile^2': 'http://www.toronto.ca/TWONTO#square_mile',
#  'V': 'http://www.toronto.ca/TWONTO#volt',
#  'VA': 'http://www.toronto.ca/TWONTO#volt-ampere',
#  'W': 'http://www.toronto.ca/TWONTO#watt',
#  'NEMA EXPL': 'http://www.toronto.ca/TWONTO#00112',
#  'NEMA HAZ': 'http://www.toronto.ca/TWONTO#00113',
#  'steam': 'http://www.toronto.ca/TWONTO#00704',
#  'thermal oil': 'http://www.toronto.ca/TWONTO#00745',
#  'water': 'http://www.toronto.ca/TWONTO#00798',
#  'water glycol mixture': 'http://www.toronto.ca/TWONTO#00799'}

# %%
df['Class_IRI'] = df['Valid_Class'].map(dict_class_iri)
df[['Entity_number', 'Valid_Class', 'Class_IRI']].to_csv('Entity_to_new_classes.csv', index=False)
df[['Entity_number', 'Valid_Class', 'Class_IRI']]
# Out:
#                Entity_number      Valid_Class  \
# 0           FCL_ELS_CBL_001D    cable segment
# 1           FCL_ELS_CBL_002F    cable segment
# 2           FCL_ELS_CBL_002H    cable segment
# 3           FCL_ELS_CBL_0100    cable segment
# 4           FCL_ELS_CBL_0200    cable segment
# ...                      ...              ...
# 123649        YTF-SS-RC-1000  security system
# 123650       YTF-SS-UPS-1000  security system
# 123651               YX2413A             pump
# 123652         ZXDATA-PILOT1          unknown
# 123653  ZXDP WTR CH LOCN ORO          chamber
#
#                                  Class_IRI
# 0       http://www.toronto.ca/TWONTO#00192
# 1       http://www.toronto.ca/TWONTO#00192
# 2       http://www.toronto.ca/TWONTO#00192
# 3       http://www.toronto.ca/TWONTO#00192
# 4       http://www.toronto.ca/TWONTO#00192
# ...                                    ...
# 123649  http://www.toronto.ca/TWONTO#00673
# 123650  http://www.toronto.ca/TWONTO#00673
# 123651  http://www.toronto.ca/TWONTO#00626
# 123652                                 NaN
# 123653  http://www.toronto.ca/TWONTO#00318
#
# [123654 rows x 3 columns]
