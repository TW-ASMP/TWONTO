# %% [markdown]
# # Avnatis Mapping Instructions
#
# The following describes the process for mapping the current Avantis Classes to the new Classification system.
#
# ## Load SPARQL data
#
# The first step is to run SPARQL queires in protege to get the revelent metadata from the new classes. The SPARQL queires should look for classes with the specific annotation propertys:
# 1. is_equivalent_to_Avantis_class
# 2. is_equivalent_to_Avantis_category
# 3. is_equivalent_to_tag_code
# 4. is_superclass_of_Avantis_class
# 5. is_superclass_of_Avantis_category
# 6. is_superclass_of_tag_code
# The following code can be modified to acomplish this task.
#
# ```sparql
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
# PREFIX tw: <http://www.toronto.ca/TWONTO#>
#
# SELECT (STR(?label) as ?OWL) (STR(?object) as ?Avantis)
# WHERE {
#     ?entityIRI tw:is_equivalent_to_Avantis_class ?object ;
#               rdfs:label ?label .
# }
# ```
# Once the SPARQL queires are saved, they are open in python pandas dataframes. This is done with the following code:

# %%
import pandas as pd

df = pd.read_excel("SPARQL_class.xlsx", header= 1)
Class = dict(zip(df['Avantis_Class'],df['TWONTO']))

TWONTO_classes = pd.read_excel('TWONTO_classes.xlsx')
df
# Out:
#                                  TWONTO             Avantis_Class
# 0    http://www.toronto.ca/TWONTO#00122  Remote Transmission Unit
# 1    http://www.toronto.ca/TWONTO#00186           Circuit Breaker
# 2    http://www.toronto.ca/TWONTO#00680                    Server
# 3    http://www.toronto.ca/TWONTO#00755               Transformer
# 4    http://www.toronto.ca/TWONTO#00234         Computer Hardware
# ..                                  ...                       ...
# 117  http://www.toronto.ca/TWONTO#00189                 Structure
# 118  http://www.toronto.ca/TWONTO#00191                    Burner
# 119  http://www.toronto.ca/TWONTO#00181                      Boat
# 120  http://www.toronto.ca/TWONTO#00163                   Sampler
# 121  http://www.toronto.ca/TWONTO#00238     Earthmoving Equipment
#
# [122 rows x 2 columns]

# %% [markdown]
# There is an additonal step were the two column are saved as a dictionary. A python dictionary is a simple key value pair.

# %%
df = pd.read_excel("SPARQL_superclass.xlsx", header= 1)
Super_Class = dict(zip(df['Super_Class'],df['TWONTO']))

df = pd.read_excel("SPARQL_tag.xlsx", header= 1)
Tag = dict(zip(df['Tag'],df['TWONTO']))

df = pd.read_excel("SPARQL_supertag.xlsx", header= 1)
Super_Tag = dict(zip(df['Super_Tag'],df['TWONTO']))

df = pd.read_excel("SPARQL_category.xlsx", header= 1)
Category = dict(zip(df['Category'],df['TWONTO']))

df = pd.read_excel("SPARQL_supercategory.xlsx", header= 1)
Super_Category = dict(zip(df['Super_Category'],df['TWONTO']))

df = pd.read_excel("manualMatch.xlsx", sheet_name = 'LLM capability Test Dataset')
Manual_Match = dict(zip(df['Entity_number'],df['Valid_Class']))

Tag
# Out:
# {'DRN': 'http://www.toronto.ca/TWONTO#00288',
#  'V': 'http://www.toronto.ca/TWONTO#00781',
#  'AMP': 'http://www.toronto.ca/TWONTO#00117',
#  'HYD': 'http://www.toronto.ca/TWONTO#00431',
#  'FIT': 'http://www.toronto.ca/TWONTO#00369',
#  'LOA': 'http://www.toronto.ca/TWONTO#00761',
#  'WRT': 'http://www.toronto.ca/TWONTO#00806',
#  'AFR': 'http://www.toronto.ca/TWONTO#00622',
#  'INQ': 'http://www.toronto.ca/TWONTO#00520',
#  'FT': 'http://www.toronto.ca/TWONTO#00369',
#  'BAT': 'http://www.toronto.ca/TWONTO#00167',
#  'UV': 'http://www.toronto.ca/TWONTO#00933',
#  'MAN': 'http://www.toronto.ca/TWONTO#00568',
#  'M': 'http://www.toronto.ca/TWONTO#00531',
#  'IGN': 'http://www.toronto.ca/TWONTO#00922',
#  'RES': 'http://www.toronto.ca/TWONTO#00644',
#  'C': 'http://www.toronto.ca/TWONTO#00233',
#  'WSC': 'http://www.toronto.ca/TWONTO#00806',
#  'P': 'http://www.toronto.ca/TWONTO#00626',
#  'CRN': 'http://www.toronto.ca/TWONTO#00251',
#  'VSS': 'http://www.toronto.ca/TWONTO#00718',
#  'RTU': 'http://www.toronto.ca/TWONTO#00122',
#  'CLR': 'http://www.toronto.ca/TWONTO#00219',
#  'CU': 'http://www.toronto.ca/TWONTO#00236',
#  'AIT': 'http://www.toronto.ca/TWONTO#00447',
#  'ZIT': 'http://www.toronto.ca/TWONTO#00589',
#  'CV': 'http://www.toronto.ca/TWONTO#00245',
#  'RX': 'http://www.toronto.ca/TWONTO#00636',
#  'ENG': 'http://www.toronto.ca/TWONTO#00316',
#  'DEF': 'http://www.toronto.ca/TWONTO#00164',
#  'PCV': 'http://www.toronto.ca/TWONTO#00781',
#  'CT': 'http://www.toronto.ca/TWONTO#00614',
#  'RC': 'http://www.toronto.ca/TWONTO#00255',
#  'TEL': 'http://www.toronto.ca/TWONTO#00702',
#  'LAG': 'http://www.toronto.ca/TWONTO#00156',
#  'MS': 'http://www.toronto.ca/TWONTO#00530',
#  'ALR': 'http://www.toronto.ca/TWONTO#00151',
#  'CI': 'http://www.toronto.ca/TWONTO#00213',
#  'LRT': 'http://www.toronto.ca/TWONTO#00467',
#  'DU': 'http://www.toronto.ca/TWONTO#00144',
#  'SM': 'http://www.toronto.ca/TWONTO#00703',
#  'INT': 'http://www.toronto.ca/TWONTO#00932',
#  'OTF': 'http://www.toronto.ca/TWONTO#00551',
#  'LS': 'http://www.toronto.ca/TWONTO#00466',
#  'GB': 'http://www.toronto.ca/TWONTO#00396',
#  'SCBA': 'http://www.toronto.ca/TWONTO#00123',
#  'FAK': 'http://www.toronto.ca/TWONTO#00355',
#  'FA': 'http://www.toronto.ca/TWONTO#00154',
#  'NGR': 'http://www.toronto.ca/TWONTO#00918',
#  'FM': 'http://www.toronto.ca/TWONTO#00608',
#  'MX': 'http://www.toronto.ca/TWONTO#00526',
#  'SC': 'http://www.toronto.ca/TWONTO#00665',
#  'CF': 'http://www.toronto.ca/TWONTO#00200',
#  'ZT': 'http://www.toronto.ca/TWONTO#00589',
#  'BL': 'http://www.toronto.ca/TWONTO#00179',
#  'DD': 'http://www.toronto.ca/TWONTO#00279',
#  'CPU': 'http://www.toronto.ca/TWONTO#00234',
#  'CP': 'http://www.toronto.ca/TWONTO#00613',
#  'Grounds': 'http://www.toronto.ca/TWONTO#00408',
#  'WEL': 'http://www.toronto.ca/TWONTO#00811',
#  'CAP': 'http://www.toronto.ca/TWONTO#00194',
#  'VIT': 'http://www.toronto.ca/TWONTO#00791',
#  'HF': 'http://www.toronto.ca/TWONTO#00595',
#  'PA': 'http://www.toronto.ca/TWONTO#00117',
#  'RD': 'http://www.toronto.ca/TWONTO#00655',
#  'WIT': 'http://www.toronto.ca/TWONTO#00806',
#  'DP': 'http://www.toronto.ca/TWONTO#00502',
#  'BO': 'http://www.toronto.ca/TWONTO#00183',
#  'SERV': 'http://www.toronto.ca/TWONTO#00680',
#  'ST': 'http://www.toronto.ca/TWONTO#00532',
#  'UPS': 'http://www.toronto.ca/TWONTO#00124',
#  'WAP': 'http://www.toronto.ca/TWONTO#00814',
#  'PIT': 'http://www.toronto.ca/TWONTO#00605',
#  'HTR': 'http://www.toronto.ca/TWONTO#00418',
#  'DM': 'http://www.toronto.ca/TWONTO#00142',
#  'MON': 'http://www.toronto.ca/TWONTO#00279',
#  'XSH': 'http://www.toronto.ca/TWONTO#00750',
#  'DIT': 'http://www.toronto.ca/TWONTO#00689',
#  'FU': 'http://www.toronto.ca/TWONTO#00385',
#  'INJ': 'http://www.toronto.ca/TWONTO#00294',
#  'AM': 'http://www.toronto.ca/TWONTO#00359',
#  'PDM': 'http://www.toronto.ca/TWONTO#00625',
#  'CL': 'http://www.toronto.ca/TWONTO#00220',
#  'FX': 'http://www.toronto.ca/TWONTO#00361',
#  'STR': 'http://www.toronto.ca/TWONTO#00710',
#  'HE': 'http://www.toronto.ca/TWONTO#00416',
#  'TR': 'http://www.toronto.ca/TWONTO#00755',
#  'MT': 'http://www.toronto.ca/TWONTO#00703',
#  'FCV': 'http://www.toronto.ca/TWONTO#00781',
#  'ELV': 'http://www.toronto.ca/TWONTO#00306',
#  'RPU': 'http://www.toronto.ca/TWONTO#00122',
#  'SCP': 'http://www.toronto.ca/TWONTO#00668',
#  'DS': 'http://www.toronto.ca/TWONTO#00272',
#  'OZ': 'http://www.toronto.ca/TWONTO#00553',
#  'EV': 'http://www.toronto.ca/TWONTO#00321',
#  'FD': 'http://www.toronto.ca/TWONTO#00206',
#  'SS': 'http://www.toronto.ca/TWONTO#00563',
#  'PT': 'http://www.toronto.ca/TWONTO#00605',
#  'SO': 'http://www.toronto.ca/TWONTO#00716',
#  'DT': 'http://www.toronto.ca/TWONTO#00235',
#  'BFP': 'http://www.toronto.ca/TWONTO#00165',
#  'SB': 'http://www.toronto.ca/TWONTO#00148',
#  'GDR': 'http://www.toronto.ca/TWONTO#00405',
#  'DR': 'http://www.toronto.ca/TWONTO#00353',
#  'FS': 'http://www.toronto.ca/TWONTO#00367',
#  'AE': 'http://www.toronto.ca/TWONTO#00446',
#  'LHD': 'http://www.toronto.ca/TWONTO#00923',
#  'CH': 'http://www.toronto.ca/TWONTO#00318',
#  'LIT': 'http://www.toronto.ca/TWONTO#00467',
#  'VAV': 'http://www.toronto.ca/TWONTO#00784',
#  'LT': 'http://www.toronto.ca/TWONTO#00467',
#  'CBL': 'http://www.toronto.ca/TWONTO#00192',
#  'OIT': 'http://www.toronto.ca/TWONTO#00548',
#  'HPU': 'http://www.toronto.ca/TWONTO#00433',
#  'PSU': 'http://www.toronto.ca/TWONTO#00105',
#  'PIP': 'http://www.toronto.ca/TWONTO#00569',
#  'QUEN': 'http://www.toronto.ca/TWONTO#00633',
#  'CMP': 'http://www.toronto.ca/TWONTO#00232',
#  'FSP': 'http://www.toronto.ca/TWONTO#00921',
#  'G': 'http://www.toronto.ca/TWONTO#00202',
#  'GA': 'http://www.toronto.ca/TWONTO#00445',
#  'AHU': 'http://www.toronto.ca/TWONTO#00147',
#  'CHL': 'http://www.toronto.ca/TWONTO#00215',
#  'ZRT': 'http://www.toronto.ca/TWONTO#00589',
#  'D': 'http://www.toronto.ca/TWONTO#00263',
#  'TE': 'http://www.toronto.ca/TWONTO#00733',
#  'FDT': 'http://www.toronto.ca/TWONTO#00362',
#  'FEQ': 'http://www.toronto.ca/TWONTO#00915',
#  'SCAM': 'http://www.toronto.ca/TWONTO#00671',
#  'DCU': 'http://www.toronto.ca/TWONTO#00292',
#  'TPD': 'http://www.toronto.ca/TWONTO#00757',
#  'PWU': 'http://www.toronto.ca/TWONTO#00596',
#  'SPL': 'http://www.toronto.ca/TWONTO#00700',
#  'WS': 'http://www.toronto.ca/TWONTO#00805',
#  'AC': 'http://www.toronto.ca/TWONTO#00141',
#  'SEN': 'http://www.toronto.ca/TWONTO#00446',
#  'BN': 'http://www.toronto.ca/TWONTO#00925',
#  'TS': 'http://www.toronto.ca/TWONTO#00754',
#  'MH': 'http://www.toronto.ca/TWONTO#00493',
#  'HU': 'http://www.toronto.ca/TWONTO#00429',
#  'LE': 'http://www.toronto.ca/TWONTO#00465',
#  'STRC': 'http://www.toronto.ca/TWONTO#00558',
#  'FN': 'http://www.toronto.ca/TWONTO#00179',
#  'LDR': 'http://www.toronto.ca/TWONTO#00457',
#  'CM': 'http://www.toronto.ca/TWONTO#00226',
#  'LD': 'http://www.toronto.ca/TWONTO#00474',
#  'GEN': 'http://www.toronto.ca/TWONTO#00397',
#  'GRF': 'http://www.toronto.ca/TWONTO#00406',
#  'FE': 'http://www.toronto.ca/TWONTO#00366',
#  'SQ': 'http://www.toronto.ca/TWONTO#00657',
#  'LP': 'http://www.toronto.ca/TWONTO#00477',
#  'SP': 'http://www.toronto.ca/TWONTO#00163',
#  'T': 'http://www.toronto.ca/TWONTO#00708',
#  'BU': 'http://www.toronto.ca/TWONTO#00191'}

# %% [markdown]
# ## SQL connection
# The next step connects to the Avantis SQL server to get the list of entities

# %%
import pyodbc
import os
from sqlalchemy.engine import URL
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

sns.set_theme()

connect = 'DSN=Avantis6-P;UID='+ os.environ['Avantis_User'] + ';PWD=' + os.environ['Avantis_Pass']
connection_url = URL.create("mssql+pyodbc", query={"odbc_connect": connect})

engine = create_engine(connection_url)

SQL1 = """SELECT Distinct MAINTENT.id as [Entity_number],
[MAINTENT].[aenm] as [Description],
MAINTENT2.id as [Parent],
MAINTENT2.aenm as [Parent_Description],
[contname] as [Category],
[entclsid] as [Class],
SUSPEND.suspoi as [Suspended]

FROM  [AvantisP].[mc].[MAINTENT]
	  Left Join [AvantisP].[mc].[ENTCLASS] on MAINTENT.entclsref_oi = ENTCLASS.entcloi
	  Left Join [AvantisP].[mc].CATVAL ON MAINTENT.cat1_oi = CATVAL.cvoi
	  Left Join MC.SUSPEND ON MAINTENT.susp_oi = SUSPEND.suspoi
	  Left Join MC.MELINK ON MAINTENT.mtnoi = MELINK.mtnchild_oi
	  Left Join MC.MAINTENT MAINTENT2 ON MELINK.mtnparn_oi = MAINTENT2.mtnoi"""


df1 = pd.read_sql(SQL1,engine)
df1 = df1[df1['Entity_number'].values != None]
df1['Tag'] = df1['Entity_number'].str.extract(r"-([a-zA-Z]+)-\d+")
df1
# Out:
#                Entity_number  \
# 0         \tFCL_ELS_CBL_001D
# 1         \tFCL_ELS_CBL_001F
# 2         \tFCL_ELS_CBL_001G
# 3         \tFCL_ELS_CBL_001H
# 4         \tFCL_ELS_CBL_003F
# ...                      ...
# 148516               YX2413A
# 148517           ZDATA PILOT
# 148518       ZXDP ENTITY COL
# 148519        ZXDP OTHER COL
# 148520  ZXDP WTR CH LOCN ORO
#
#                                               Description  \
# 0       Electrical Power Line,4.16KV,From BUS-00B1-A t...
# 1       Electrical Power Line,4.16KV,From BUS-00B1 to ...
# 2       Electrical Power Line,4.16KV,From BUS-00B1 to ...
# 3       Electrical Power Line,4.16KV,From BUS-00B1 to ...
# 4       Electrical Power Line,4.16KV,From BUS-00B2 to ...
# ...                                                   ...
# 148516                  Pump, Dewatering, Old PS House #3
# 148517                                   ZCity of Toronto
# 148518                       DO NOT USE - City of Toronto
# 148519                     DO NOT USE - DP Other Entities
# 148520                 DO NOT USE - Toronto Water Chamber
#
#                       Parent  \
# 0       FCL_ELS_4.16KV_LINES
# 1       FCL_ELS_4.16KV_LINES
# 2       FCL_ELS_4.16KV_LINES
# 3       FCL_ELS_4.16KV_LINES
# 4       FCL_ELS_4.16KV_LINES
# ...                      ...
# 148516        TAB-PRM-P-SUMP
# 148517                  None
# 148518                  None
# 148519                  None
# 148520              MAIN-001
#
#                                        Parent_Description  \
# 0                            Electrical Power Line,4.16KV
# 1                            Electrical Power Line,4.16KV
# 2                            Electrical Power Line,4.16KV
# 3                            Electrical Power Line,4.16KV
# 4                            Electrical Power Line,4.16KV
# ...                                                   ...
# 148516  P Bldg & Old PS Buildings, Primary Treatment S...
# 148517                                               None
# 148518                                               None
# 148519                                               None
# 148520                                           Main 001
#
#                               Category                  Class  Suspended  Tag
# 0                    Air Handling Unit  Electrical Power Line        NaN  NaN
# 1                    Air Handling Unit  Electrical Power Line        NaN  NaN
# 2                    Air Handling Unit  Electrical Power Line        NaN  NaN
# 3                    Air Handling Unit  Electrical Power Line        NaN  NaN
# 4                    Air Handling Unit  Electrical Power Line        NaN  NaN
# ...                                ...                    ...        ...  ...
# 148516  Pump,Non Positive Displacement                   Pump        NaN  NaN
# 148517                            None                   None    39026.0  NaN
# 148518                            None                   None        NaN  NaN
# 148519                            None                   None        NaN  NaN
# 148520               Air Handling Unit                Chamber        NaN  NaN
#
# [148521 rows x 8 columns]

# %%
#df1 = df1[df1['Suspended'].isna()]

# %%
entityMatch = pd.DataFrame()
entityMatch['Entity_number'] = df1['Entity_number']

# Step 1: Class Match
entityMatch['First_Match'] = df1['Class'].map(Class).fillna("")
class_match_count = entityMatch['First_Match'].str.len().gt(0).sum()
print(f"Class Match: {class_match_count}/{len(df1)} ({class_match_count/len(df1)*100:.2f}%)")

# Step 2: Super Class Match (if no Class Match)
entityMatch['First_Match'] = entityMatch['First_Match'].mask(entityMatch['First_Match'] == "", df1['Class'].map(Super_Class).fillna(""))
super_class_match_count = entityMatch['First_Match'].str.len().gt(0).sum() - class_match_count
print(f"Super Class Match: {super_class_match_count}/{len(df1)} ({super_class_match_count/len(df1)*100:.2f}%)")

# Step 3: Tag Match (if no Class or Super Class Match)
entityMatch['First_Match'] = entityMatch['First_Match'].mask(entityMatch['First_Match'] == "", df1['Tag'].map(Tag).fillna(""))
tag_match_count = entityMatch['First_Match'].str.len().gt(0).sum() - (class_match_count + super_class_match_count)
print(f"Tag Match: {tag_match_count}/{len(df1)} ({tag_match_count/len(df1)*100:.2f}%)")

# Step 4: Super Tag Match (if no Class, Super Class, or Tag Match)
entityMatch['First_Match'] = entityMatch['First_Match'].mask(entityMatch['First_Match'] == "", df1['Tag'].map(Super_Tag).fillna(""))
super_tag_match_count = entityMatch['First_Match'].str.len().gt(0).sum() - (class_match_count + super_class_match_count + tag_match_count)
print(f"Super Tag Match: {super_tag_match_count}/{len(df1)} ({super_tag_match_count/len(df1)*100:.2f}%)")

# Step 5: Category Match (if no match yet)
entityMatch['First_Match'] = entityMatch['First_Match'].mask(entityMatch['First_Match'] == "", df1['Category'].map(Category).fillna(""))
category_match_count = entityMatch['First_Match'].str.len().gt(0).sum() - (class_match_count + super_class_match_count + tag_match_count + super_tag_match_count)
print(f"Category Match: {category_match_count}/{len(df1)} ({category_match_count/len(df1)*100:.2f}%)")

# Step 6: Super Category Match (final fallback)
entityMatch['First_Match'] = entityMatch['First_Match'].mask(entityMatch['First_Match'] == "", df1['Category'].map(Super_Category).fillna(""))
super_category_match_count = entityMatch['First_Match'].str.len().gt(0).sum() - (class_match_count + super_class_match_count + tag_match_count + super_tag_match_count + category_match_count)
print(f"Super Category Match: {super_category_match_count}/{len(df1)} ({super_category_match_count/len(df1)*100:.2f}%)")

# Total matches
total_match_count = entityMatch['First_Match'].str.len().gt(0).sum()
print(f"Auto Matches: {total_match_count}/{len(df1)} ({total_match_count/len(df1)*100:.2f}%)")

# Step 7: Manual Match
entityMatch['First_Match'] = df1['Entity_number'].map(Manual_Match).fillna(entityMatch['First_Match'])
manual_match_count = df1['Entity_number'].map(Manual_Match).str.len().gt(0).sum()
print(f"\nManual Match: {manual_match_count}/{len(df1)} ({manual_match_count/len(df1)*100:.2f}%)")
total_match_count = entityMatch['First_Match'].str.len().gt(0).sum()
print(f"\nTotal Matches: {total_match_count}/{len(df1)} ({total_match_count/len(df1)*100:.2f}%)")
# Out:
# Class Match: 114558/148521 (77.13%)
# Super Class Match: 3510/148521 (2.36%)
# Tag Match: 16025/148521 (10.79%)
# Super Tag Match: 7088/148521 (4.77%)
# Category Match: 875/148521 (0.59%)
# Super Category Match: 327/148521 (0.22%)
# Auto Matches: 142383/148521 (95.87%)
#
# Manual Match: 32785/148521 (22.07%)
#
# Total Matches: 147490/148521 (99.31%)

# %%
#excel_class = ['Fire Equipment','Pump', 'Meter']

#with pd.ExcelWriter('missing.xlsx', engine='openpyxl', mode='w') as writer:
#   for Value in excel_class:  
#      df1[df1['Class'] == Value].to_excel(writer, sheet_name = Value.replace(" ", "_"))
   
#   df1[df1['Class'].isna()].to_excel(writer, sheet_name = "None")

# %%
df1[df1['Entity_number'].isin(entityMatch[entityMatch['First_Match'] == '']['Entity_number'])]['Tag'].unique()
# Out:
# array([nan, 'TIT', 'FQ', 'FIR', 'AICR', 'HS', 'ASH', 'SF', 'EYE', 'FSS',
#        'FQIR', 'MEQ', 'ACC', 'GBP'], dtype=object)

# %%
df1[df1['Entity_number'].isin(entityMatch[entityMatch['First_Match'] == '']['Entity_number'])].groupby('Class').count()['Entity_number']
# Out:
# Class
# Fire Equipment    768
# Meter              65
# Pump              195
# Switch              1
# Name: Entity_number, dtype: int64

# %%
leftover = df1[df1['Entity_number'].isin(entityMatch[entityMatch['First_Match'] == '']['Entity_number'])]
leftover
# Out:
#                     Entity_number  \
# 36                          45459
# 37                          45459
# 76                          46247
# 96                          52863
# 97                          52874
# ...                           ...
# 148183                    WX2022A
# 148184                    WX2024A
# 148406           YTF-ACC-MEQ-0001
# 148515                    YX2412A
# 148516                    YX2413A
#
#                                               Description  \
# 36      Extinguisher, Fire, SN#45459, Carbon Dioxide, ...
# 37      Extinguisher, Fire, SN#45459, Carbon Dioxide, ...
# 76               Extinguisher, Fire,  WA2, Buggy SN378306
# 96      Extinguisher, Fire, SN#52863, Dry, Hallway, Se...
# 97      Extinguisher, Fire, SN#52874, 26 Unit, Dry, Tu...
# ...                                                   ...
# 148183                 Pump, Thermal Oil Recir Pump, 602A
# 148184                 Pump, Thermal Oil Recir Pump, 602C
# 148406  Pump, RN146, Pressure Washer, Miscellaneous De...
# 148515                Pump, Unwatering, Primary Tanls 3-4
# 148516                  Pump, Dewatering, Old PS House #3
#
#                       Parent  \
# 36      TAB-SUSPENDED ENTITY
# 37         TAB-WA7-FEQ-2175S
# 76          TAB-WA7-FEQ-0014
# 96         TAB-WA7-FEQ-2166S
# 97      TAB-SUSPENDED ENTITY
# ...                      ...
# 148183             TAB-SLD-P
# 148184             TAB-SLD-P
# 148406               YTF-ACC
# 148515        TAB-PRM-P-SUMP
# 148516        TAB-PRM-P-SUMP
#
#                                        Parent_Description  \
# 36                                     Suspended entities
# 37             Extinguisher, Fire - Laboratory/ Old Admin
# 76                          Extinguisher, Fire - Vehicles
# 96            Extinguisher, Fire - Security & D Buildings
# 97                                     Suspended entities
# ...                                                   ...
# 148183  Pelletizer Bldg. - Thermal  Oil Heating System...
# 148184  Pelletizer Bldg. - Thermal  Oil Heating System...
# 148406                                     HVAC Equipment
# 148515  P Bldg & Old PS Buildings, Primary Treatment S...
# 148516  P Bldg & Old PS Buildings, Primary Treatment S...
#
#                                           Category           Class  Suspended  \
# 36                    Fire Prevention,Extinguisher  Fire Equipment    33028.0
# 37                    Fire Prevention,Extinguisher  Fire Equipment    33028.0
# 76                    Fire Prevention,Extinguisher  Fire Equipment        NaN
# 96                    Fire Prevention,Extinguisher  Fire Equipment    41321.0
# 97                    Fire Prevention,Extinguisher  Fire Equipment    32967.0
# ...                                            ...             ...        ...
# 148183  Pump,Non Positive Displacement,Submersible            Pump        NaN
# 148184  Pump,Non Positive Displacement,Submersible            Pump        NaN
# 148406                                        Pump            Pump        NaN
# 148515               Pump,Centrifugal,single-Stage            Pump        NaN
# 148516              Pump,Non Positive Displacement            Pump        NaN
#
#         Tag
# 36      NaN
# 37      NaN
# 76      NaN
# 96      NaN
# 97      NaN
# ...     ...
# 148183  NaN
# 148184  NaN
# 148406  MEQ
# 148515  NaN
# 148516  NaN
#
# [1031 rows x 8 columns]

# %%
print(len(entityMatch['First_Match'][~entityMatch['First_Match'].isin(TWONTO_classes['Classes'])].unique()))
entityMatch['First_Match'][~entityMatch['First_Match'].isin(TWONTO_classes['Classes'])].unique()
# Out:
# 5
# array(['', 'x', 'http://www.toronto.ca/TWONTO#00719',
#        'http://www.toronto.ca/TWONTO#00696', '?'], dtype=object)

# %%
entityMatch.groupby('First_Match').count().sort_values('Entity_number').query('Entity_number < 6').merge(TWONTO_classes, left_on = 'First_Match', right_on = 'Classes')
# Out:
#     Entity_number                             Classes  \
# 0               1  http://www.toronto.ca/TWONTO#00126
# 1               1  http://www.toronto.ca/TWONTO#00713
# 2               1  http://www.toronto.ca/TWONTO#00320
# 3               1  http://www.toronto.ca/TWONTO#00729
# 4               1  http://www.toronto.ca/TWONTO#00408
# 5               1  http://www.toronto.ca/TWONTO#00352
# 6               1  http://www.toronto.ca/TWONTO#00647
# 7               1  http://www.toronto.ca/TWONTO#00640
# 8               1  http://www.toronto.ca/TWONTO#00752
# 9               2  http://www.toronto.ca/TWONTO#00292
# 10              2  http://www.toronto.ca/TWONTO#00450
# 11              2  http://www.toronto.ca/TWONTO#00300
# 12              2  http://www.toronto.ca/TWONTO#00254
# 13              2  http://www.toronto.ca/TWONTO#00373
# 14              2  http://www.toronto.ca/TWONTO#00125
# 15              2  http://www.toronto.ca/TWONTO#00815
# 16              2  http://www.toronto.ca/TWONTO#00625
# 17              2  http://www.toronto.ca/TWONTO#00538
# 18              2  http://www.toronto.ca/TWONTO#00529
# 19              2  http://www.toronto.ca/TWONTO#00152
# 20              2  http://www.toronto.ca/TWONTO#00779
# 21              2  http://www.toronto.ca/TWONTO#00156
# 22              2  http://www.toronto.ca/TWONTO#00181
# 23              2  http://www.toronto.ca/TWONTO#00809
# 24              2  http://www.toronto.ca/TWONTO#00489
# 25              2  http://www.toronto.ca/TWONTO#00686
# 26              2  http://www.toronto.ca/TWONTO#00143
# 27              2  http://www.toronto.ca/TWONTO#00638
# 28              2  http://www.toronto.ca/TWONTO#00246
# 29              3  http://www.toronto.ca/TWONTO#00449
# 30              3  http://www.toronto.ca/TWONTO#00813
# 31              3  http://www.toronto.ca/TWONTO#00816
# 32              3  http://www.toronto.ca/TWONTO#00633
# 33              3  http://www.toronto.ca/TWONTO#00637
# 34              3  http://www.toronto.ca/TWONTO#00280
# 35              3  http://www.toronto.ca/TWONTO#00796
# 36              3  http://www.toronto.ca/TWONTO#00768
# 37              3  http://www.toronto.ca/TWONTO#00758
# 38              4  http://www.toronto.ca/TWONTO#00427
# 39              4  http://www.toronto.ca/TWONTO#00101
# 40              4  http://www.toronto.ca/TWONTO#00805
# 41              4  http://www.toronto.ca/TWONTO#00756
# 42              4  http://www.toronto.ca/TWONTO#00195
# 43              4  http://www.toronto.ca/TWONTO#00150
# 44              4  http://www.toronto.ca/TWONTO#00534
# 45              4  http://www.toronto.ca/TWONTO#00390
# 46              4  http://www.toronto.ca/TWONTO#00718
# 47              4  http://www.toronto.ca/TWONTO#00305
# 48              4  http://www.toronto.ca/TWONTO#00701
# 49              4  http://www.toronto.ca/TWONTO#00663
# 50              5  http://www.toronto.ca/TWONTO#00222
# 51              5  http://www.toronto.ca/TWONTO#00404
# 52              5  http://www.toronto.ca/TWONTO#00197
# 53              5  http://www.toronto.ca/TWONTO#00731
# 54              5  http://www.toronto.ca/TWONTO#00802
# 55              5  http://www.toronto.ca/TWONTO#00786
#
#                                       Label
# 0                  UV disinfection assembly
# 1                           structural wall
# 2                         equipment trailer
# 3                     tankless water heater
# 4                  groundskeeping equipment
# 5                 fire protection sprinkler
# 6                              road segment
# 7                              relief valve
# 8           total suspended solids analyzer
# 9                            dust collector
# 10                         intercom station
# 11              electrical panel or cabinet
# 12                          damper actuator
# 13      foundation of building or structure
# 14                 UV air disinfection unit
# 15                        wireless receiver
# 16                       pulsation dampener
# 17                           network router
# 18                   modular trailer office
# 19                       ambient vapourizer
# 20                          utility trailer
# 21                               ash lagoon
# 22                                     boat
# 23                           weir structure
# 24  machine and mechanical system component
# 25              single parameter instrument
# 26                                air dryer
# 27                     refrigerated storage
# 28                            cooling tower
# 29                      interceptor segment
# 30                                 windsock
# 31                      wireless tranceiver
# 32                                 quencher
# 33                                rectifier
# 34                dissolved oxygen analyzer
# 35                  wastewater storage pipe
# 36           underground fuel oil tank temp
# 37              travelling bridge collector
# 38                         hot water heater
# 39                           BAS controller
# 40               weather monitoring station
# 41           transportation tool or vehicle
# 42                          capital project
# 43                             air silencer
# 44                               multimeter
# 45                  gas detector calibrator
# 46                         surge suppressor
# 47                      elevated water tank
# 48                                sprinkler
# 49                              sandblaster
# 50                         coagulation tank
# 51                               grease gun
# 52                                cargo van
# 53                telecommunication network
# 54                            water trailer
# 55                                     vent

# %%
totals = entityMatch.groupby('First_Match').count().merge(TWONTO_classes, left_on = 'First_Match', right_on = 'Classes')
totals[totals['Label'].str.contains('diffuser')]
# Out:
# Empty DataFrame
# Columns: [Entity_number, Classes, Label]
# Index: []

# %%
totals.sort_values('Entity_number',ascending = False).hist()
# Out:
# array([[<Axes: title={'center': 'Entity_number'}>]], dtype=object)

# %%
export = entityMatch.merge(df1, how= 'left').drop_duplicates('Entity_number')
export[(export['First_Match'] != 'x') & (export['First_Match'] != '?') & (export['First_Match'] != '')& (~export['Class'].isna())][['Entity_number', 'First_Match', 'Description']].to_csv('test2.csv')

# %%
export[(export['First_Match'] != 'x') & (export['First_Match'] != '?') & (export['First_Match'] != '')& (~export['Class'].isna())]['First_Match'].unique()
# Out:
# array(['http://www.toronto.ca/TWONTO#00192',
#        'http://www.toronto.ca/TWONTO#00260',
#        'http://www.toronto.ca/TWONTO#00569',
#        'http://www.toronto.ca/TWONTO#00117',
#        'http://www.toronto.ca/TWONTO#00318',
#        'http://www.toronto.ca/TWONTO#00731',
#        'http://www.toronto.ca/TWONTO#00333',
#        'http://www.toronto.ca/TWONTO#00286',
#        'http://www.toronto.ca/TWONTO#00186',
#        'http://www.toronto.ca/TWONTO#00447',
#        'http://www.toronto.ca/TWONTO#00236',
#        'http://www.toronto.ca/TWONTO#00478',
#        'http://www.toronto.ca/TWONTO#00649',
#        'http://www.toronto.ca/TWONTO#00200',
#        'http://www.toronto.ca/TWONTO#00781',
#        'http://www.toronto.ca/TWONTO#00308',
#        'http://www.toronto.ca/TWONTO#00583',
#        'http://www.toronto.ca/TWONTO#00111',
#        'http://www.toronto.ca/TWONTO#00400',
#        'http://www.toronto.ca/TWONTO#00208',
#        'http://www.toronto.ca/TWONTO#00339',
#        'http://www.toronto.ca/TWONTO#00142',
#        'http://www.toronto.ca/TWONTO#00564',
#        'http://www.toronto.ca/TWONTO#00559',
#        'http://www.toronto.ca/TWONTO#00372',
#        'http://www.toronto.ca/TWONTO#00475',
#        'http://www.toronto.ca/TWONTO#00234',
#        'http://www.toronto.ca/TWONTO#00359',
#        'http://www.toronto.ca/TWONTO#00418',
#        'http://www.toronto.ca/TWONTO#00251',
#        'http://www.toronto.ca/TWONTO#00802',
#        'http://www.toronto.ca/TWONTO#00179',
#        'http://www.toronto.ca/TWONTO#00263',
#        'http://www.toronto.ca/TWONTO#00592',
#        'http://www.toronto.ca/TWONTO#00680',
#        'http://www.toronto.ca/TWONTO#00211',
#        'http://www.toronto.ca/TWONTO#00294',
#        'http://www.toronto.ca/TWONTO#00269',
#        'http://www.toronto.ca/TWONTO#00151',
#        'http://www.toronto.ca/TWONTO#00613',
#        'http://www.toronto.ca/TWONTO#00433',
#        'http://www.toronto.ca/TWONTO#00466',
#        'http://www.toronto.ca/TWONTO#00626',
#        'http://www.toronto.ca/TWONTO#00445',
#        'http://www.toronto.ca/TWONTO#00754',
#        'http://www.toronto.ca/TWONTO#00124',
#        'http://www.toronto.ca/TWONTO#00590',
#        'http://www.toronto.ca/TWONTO#00297',
#        'http://www.toronto.ca/TWONTO#00122',
#        'http://www.toronto.ca/TWONTO#00594',
#        'http://www.toronto.ca/TWONTO#00734',
#        'http://www.toronto.ca/TWONTO#00811',
#        'http://www.toronto.ca/TWONTO#00154',
#        'http://www.toronto.ca/TWONTO#00644',
#        'http://www.toronto.ca/TWONTO#00628',
#        'http://www.toronto.ca/TWONTO#00253',
#        'http://www.toronto.ca/TWONTO#00446',
#        'http://www.toronto.ca/TWONTO#00202',
#        'http://www.toronto.ca/TWONTO#00397',
#        'http://www.toronto.ca/TWONTO#00548',
#        'http://www.toronto.ca/TWONTO#00604',
#        'http://www.toronto.ca/TWONTO#00755',
#        'http://www.toronto.ca/TWONTO#00307',
#        'http://www.toronto.ca/TWONTO#00165',
#        'http://www.toronto.ca/TWONTO#00915',
#        'http://www.toronto.ca/TWONTO#00531',
#        'http://www.toronto.ca/TWONTO#00110',
#        'http://www.toronto.ca/TWONTO#00665',
#        'http://www.toronto.ca/TWONTO#00673',
#        'http://www.toronto.ca/TWONTO#00539',
#        'http://www.toronto.ca/TWONTO#00622',
#        'http://www.toronto.ca/TWONTO#00405',
#        'http://www.toronto.ca/TWONTO#00147',
#        'http://www.toronto.ca/TWONTO#00785',
#        'http://www.toronto.ca/TWONTO#00369',
#        'http://www.toronto.ca/TWONTO#00368',
#        'http://www.toronto.ca/TWONTO#00746',
#        'http://www.toronto.ca/TWONTO#00379',
#        'http://www.toronto.ca/TWONTO#00728',
#        'http://www.toronto.ca/TWONTO#00532',
#        'http://www.toronto.ca/TWONTO#00119',
#        'http://www.toronto.ca/TWONTO#00183',
#        'http://www.toronto.ca/TWONTO#00145',
#        'http://www.toronto.ca/TWONTO#00233',
#        'http://www.toronto.ca/TWONTO#00642',
#        'http://www.toronto.ca/TWONTO#00255',
#        'http://www.toronto.ca/TWONTO#00614',
#        'http://www.toronto.ca/TWONTO#00128',
#        'http://www.toronto.ca/TWONTO#00366',
#        'http://www.toronto.ca/TWONTO#00416',
#        'http://www.toronto.ca/TWONTO#00367',
#        'http://www.toronto.ca/TWONTO#00708',
#        'http://www.toronto.ca/TWONTO#00406',
#        'http://www.toronto.ca/TWONTO#00355',
#        'http://www.toronto.ca/TWONTO#00696',
#        'http://www.toronto.ca/TWONTO#00702',
#        'http://www.toronto.ca/TWONTO#00146',
#        'http://www.toronto.ca/TWONTO#00163',
#        'http://www.toronto.ca/TWONTO#00331',
#        'http://www.toronto.ca/TWONTO#00306',
#        'http://www.toronto.ca/TWONTO#00677',
#        'http://www.toronto.ca/TWONTO#00537',
#        'http://www.toronto.ca/TWONTO#00141',
#        'http://www.toronto.ca/TWONTO#00213',
#        'http://www.toronto.ca/TWONTO#00361',
#        'http://www.toronto.ca/TWONTO#00291',
#        'http://www.toronto.ca/TWONTO#00189',
#        'http://www.toronto.ca/TWONTO#00332',
#        'http://www.toronto.ca/TWONTO#00338',
#        'http://www.toronto.ca/TWONTO#00422',
#        'http://www.toronto.ca/TWONTO#00470',
#        'http://www.toronto.ca/TWONTO#00123',
#        'http://www.toronto.ca/TWONTO#00561',
#        'http://www.toronto.ca/TWONTO#00653',
#        'http://www.toronto.ca/TWONTO#00328',
#        'http://www.toronto.ca/TWONTO#00753',
#        'http://www.toronto.ca/TWONTO#00197',
#        'http://www.toronto.ca/TWONTO#00756',
#        'http://www.toronto.ca/TWONTO#00320',
#        'http://www.toronto.ca/TWONTO#00238',
#        'http://www.toronto.ca/TWONTO#00181',
#        'http://www.toronto.ca/TWONTO#00493',
#        'http://www.toronto.ca/TWONTO#00288',
#        'http://www.toronto.ca/TWONTO#00235',
#        'http://www.toronto.ca/TWONTO#00606',
#        'http://www.toronto.ca/TWONTO#00601',
#        'http://www.toronto.ca/TWONTO#00641',
#        'http://www.toronto.ca/TWONTO#00277',
#        'http://www.toronto.ca/TWONTO#00526',
#        'http://www.toronto.ca/TWONTO#00710',
#        'http://www.toronto.ca/TWONTO#00148',
#        'http://www.toronto.ca/TWONTO#00215',
#        'http://www.toronto.ca/TWONTO#00325',
#        'http://www.toronto.ca/TWONTO#00806',
#        'http://www.toronto.ca/TWONTO#00716',
#        'http://www.toronto.ca/TWONTO#00167',
#        'http://www.toronto.ca/TWONTO#00487',
#        'http://www.toronto.ca/TWONTO#00364',
#        'http://www.toronto.ca/TWONTO#00346',
#        'http://www.toronto.ca/TWONTO#00457',
#        'http://www.toronto.ca/TWONTO#00572',
#        'http://www.toronto.ca/TWONTO#00760',
#        'http://www.toronto.ca/TWONTO#00527',
#        'http://www.toronto.ca/TWONTO#00492',
#        'http://www.toronto.ca/TWONTO#00812',
#        'http://www.toronto.ca/TWONTO#00150',
#        'http://www.toronto.ca/TWONTO#00144',
#        'http://www.toronto.ca/TWONTO#00794',
#        'http://www.toronto.ca/TWONTO#00520',
#        'http://www.toronto.ca/TWONTO#00582',
#        'http://www.toronto.ca/TWONTO#00164',
#        'http://www.toronto.ca/TWONTO#00357',
#        'http://www.toronto.ca/TWONTO#00700',
#        'http://www.toronto.ca/TWONTO#00629',
#        'http://www.toronto.ca/TWONTO#00599',
#        'http://www.toronto.ca/TWONTO#00219',
#        'http://www.toronto.ca/TWONTO#00245',
#        'http://www.toronto.ca/TWONTO#00278',
#        'http://www.toronto.ca/TWONTO#00737',
#        'http://www.toronto.ca/TWONTO#00605',
#        'http://www.toronto.ca/TWONTO#00300',
#        'http://www.toronto.ca/TWONTO#00821',
#        'http://www.toronto.ca/TWONTO#00921',
#        'http://www.toronto.ca/TWONTO#00348',
#        'http://www.toronto.ca/TWONTO#00647',
#        'http://www.toronto.ca/TWONTO#00701',
#        'http://www.toronto.ca/TWONTO#00703',
#        'http://www.toronto.ca/TWONTO#00810',
#        'http://www.toronto.ca/TWONTO#00598',
#        'http://www.toronto.ca/TWONTO#00310',
#        'http://www.toronto.ca/TWONTO#00360',
#        'http://www.toronto.ca/TWONTO#00585',
#        'http://www.toronto.ca/TWONTO#00484',
#        'http://www.toronto.ca/TWONTO#00314',
#        'http://www.toronto.ca/TWONTO#00121',
#        'http://www.toronto.ca/TWONTO#00411',
#        'http://www.toronto.ca/TWONTO#00530',
#        'http://www.toronto.ca/TWONTO#00675',
#        'http://www.toronto.ca/TWONTO#00429',
#        'http://www.toronto.ca/TWONTO#00246',
#        'http://www.toronto.ca/TWONTO#00193',
#        'http://www.toronto.ca/TWONTO#00390',
#        'http://www.toronto.ca/TWONTO#00534',
#        'http://www.toronto.ca/TWONTO#00757',
#        'http://www.toronto.ca/TWONTO#00655',
#        'http://www.toronto.ca/TWONTO#00449',
#        'http://www.toronto.ca/TWONTO#00152',
#        'http://www.toronto.ca/TWONTO#00105',
#        'http://www.toronto.ca/TWONTO#00205',
#        'http://www.toronto.ca/TWONTO#00714',
#        'http://www.toronto.ca/TWONTO#00194',
#        'http://www.toronto.ca/TWONTO#00316',
#        'http://www.toronto.ca/TWONTO#00477',
#        'http://www.toronto.ca/TWONTO#00768',
#        'http://www.toronto.ca/TWONTO#00431',
#        'http://www.toronto.ca/TWONTO#00353',
#        'http://www.toronto.ca/TWONTO#00596',
#        'http://www.toronto.ca/TWONTO#00473',
#        'http://www.toronto.ca/TWONTO#00285',
#        'http://www.toronto.ca/TWONTO#00460',
#        'http://www.toronto.ca/TWONTO#00748',
#        'http://www.toronto.ca/TWONTO#00206',
#        'http://www.toronto.ca/TWONTO#00212',
#        'http://www.toronto.ca/TWONTO#00335',
#        'http://www.toronto.ca/TWONTO#00426',
#        'http://www.toronto.ca/TWONTO#00540',
#        'http://www.toronto.ca/TWONTO#00750',
#        'http://www.toronto.ca/TWONTO#00220',
#        'http://www.toronto.ca/TWONTO#00362',
#        'http://www.toronto.ca/TWONTO#00747',
#        'http://www.toronto.ca/TWONTO#00408',
#        'http://www.toronto.ca/TWONTO#00396',
#        'http://www.toronto.ca/TWONTO#00657',
#        'http://www.toronto.ca/TWONTO#00280',
#        'http://www.toronto.ca/TWONTO#00689',
#        'http://www.toronto.ca/TWONTO#00490',
#        'http://www.toronto.ca/TWONTO#00567',
#        'http://www.toronto.ca/TWONTO#00435',
#        'http://www.toronto.ca/TWONTO#00266',
#        'http://www.toronto.ca/TWONTO#00570',
#        'http://www.toronto.ca/TWONTO#00551',
#        'http://www.toronto.ca/TWONTO#00467',
#        'http://www.toronto.ca/TWONTO#00706',
#        'http://www.toronto.ca/TWONTO#00787',
#        'http://www.toronto.ca/TWONTO#00107',
#        'http://www.toronto.ca/TWONTO#00638',
#        'http://www.toronto.ca/TWONTO#00733',
#        'http://www.toronto.ca/TWONTO#00578',
#        'http://www.toronto.ca/TWONTO#00402',
#        'http://www.toronto.ca/TWONTO#00125',
#        'http://www.toronto.ca/TWONTO#00138',
#        'http://www.toronto.ca/TWONTO#00191',
#        'http://www.toronto.ca/TWONTO#00149',
#        'http://www.toronto.ca/TWONTO#00271',
#        'http://www.toronto.ca/TWONTO#00363',
#        'http://www.toronto.ca/TWONTO#00735',
#        'http://www.toronto.ca/TWONTO#00174',
#        'http://www.toronto.ca/TWONTO#00140',
#        'http://www.toronto.ca/TWONTO#00619',
#        'http://www.toronto.ca/TWONTO#00699',
#        'http://www.toronto.ca/TWONTO#00795',
#        'http://www.toronto.ca/TWONTO#00674',
#        'http://www.toronto.ca/TWONTO#00707',
#        'http://www.toronto.ca/TWONTO#00719',
#        'http://www.toronto.ca/TWONTO#00226',
#        'http://www.toronto.ca/TWONTO#00232',
#        'http://www.toronto.ca/TWONTO#00254',
#        'http://www.toronto.ca/TWONTO#00279',
#        'http://www.toronto.ca/TWONTO#00671',
#        'http://www.toronto.ca/TWONTO#00203',
#        'http://www.toronto.ca/TWONTO#00808',
#        'http://www.toronto.ca/TWONTO#00579',
#        'http://www.toronto.ca/TWONTO#00222',
#        'http://www.toronto.ca/TWONTO#00683',
#        'http://www.toronto.ca/TWONTO#00471',
#        'http://www.toronto.ca/TWONTO#00660',
#        'http://www.toronto.ca/TWONTO#00341',
#        'http://www.toronto.ca/TWONTO#00568',
#        'http://www.toronto.ca/TWONTO#00792',
#        'http://www.toronto.ca/TWONTO#00143',
#        'http://www.toronto.ca/TWONTO#00789',
#        'http://www.toronto.ca/TWONTO#00625',
#        'http://www.toronto.ca/TWONTO#00718',
#        'http://www.toronto.ca/TWONTO#00450',
#        'http://www.toronto.ca/TWONTO#00633',
#        'http://www.toronto.ca/TWONTO#00726',
#        'http://www.toronto.ca/TWONTO#00758',
#        'http://www.toronto.ca/TWONTO#00694',
#        'http://www.toronto.ca/TWONTO#00663',
#        'http://www.toronto.ca/TWONTO#00321',
#        'http://www.toronto.ca/TWONTO#00489',
#        'http://www.toronto.ca/TWONTO#00529',
#        'http://www.toronto.ca/TWONTO#00779',
#        'http://www.toronto.ca/TWONTO#00566',
#        'http://www.toronto.ca/TWONTO#00434',
#        'http://www.toronto.ca/TWONTO#00815',
#        'http://www.toronto.ca/TWONTO#00425',
#        'http://www.toronto.ca/TWONTO#00474',
#        'http://www.toronto.ca/TWONTO#00365',
#        'http://www.toronto.ca/TWONTO#00640',
#        'http://www.toronto.ca/TWONTO#00786',
#        'http://www.toronto.ca/TWONTO#00672',
#        'http://www.toronto.ca/TWONTO#00305',
#        'http://www.toronto.ca/TWONTO#00373',
#        'http://www.toronto.ca/TWONTO#00538',
#        'http://www.toronto.ca/TWONTO#00805',
#        'http://www.toronto.ca/TWONTO#00752',
#        'http://www.toronto.ca/TWONTO#00427',
#        'http://www.toronto.ca/TWONTO#00244',
#        'http://www.toronto.ca/TWONTO#00404',
#        'http://www.toronto.ca/TWONTO#00101',
#        'http://www.toronto.ca/TWONTO#00352',
#        'http://www.toronto.ca/TWONTO#00126',
#        'http://www.toronto.ca/TWONTO#00816',
#        'http://www.toronto.ca/TWONTO#00729'], dtype=object)
