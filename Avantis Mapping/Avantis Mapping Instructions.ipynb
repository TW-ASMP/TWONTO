# %% [markdown]
# # Avnatis Mapping Instructions
#
# The following describes the process for mapping the current Avantis Classes to the new Classification system.

# %% [markdown]
# ## SQL connection
# The first step connects to the Avantis SQL server to get the list of entities

# %%
import pyodbc
import pandas as pd
import os
from sqlalchemy.engine import URL
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

sns.set_theme()

connect = 'DSN=Avantis6-P;UID='+ os.environ['Avantis_User'] + ';PWD=' + os.environ['Avantis_Pass']
connection_url = URL.create("mssql+pyodbc", query={"odbc_connect": connect})

engine = create_engine(connection_url)

SQL1 = """SELECT Distinct MAINTENT.id as [Entity_number],
[MAINTENT].[aenm] as [Description],
MAINTENT2.id as [Parent],
MAINTENT2.aenm as [Parent_Description],
[contname] as [Category],
[entclsid] as [Class],
SUSPEND.suspoi as [Suspended]

FROM  [AvantisP].[mc].[MAINTENT]
	  Left Join [AvantisP].[mc].[ENTCLASS] on MAINTENT.entclsref_oi = ENTCLASS.entcloi
	  Left Join [AvantisP].[mc].CATVAL ON MAINTENT.cat1_oi = CATVAL.cvoi
	  Left Join MC.SUSPEND ON MAINTENT.susp_oi = SUSPEND.suspoi
	  Left Join MC.MELINK ON MAINTENT.mtnoi = MELINK.mtnchild_oi
	  Left Join MC.MAINTENT MAINTENT2 ON MELINK.mtnparn_oi = MAINTENT2.mtnoi
WHERE
    (SUSPEND.audt_updted_dttm <= '1900-01-01 23:59:59' OR SUSPEND.audt_updted_dttm IS NULL)
"""


df = pd.read_sql(SQL1,engine)
df = df[df['Entity_number'].values != None]
df
# Out:
#              Entity_number                                        Description  \
# 0       \tFCL_ELS_CBL_001L  Electrical Power Line,4.16KV,From BUS-00B1-A t...
# 1       \tFCL_ELS_CBL_002D  Electrical Power Line,4.16KV,From BUS-00B2-A t...
# 2       \tFCL_ELS_CBL_002F  Electrical Power Line,4.16KV,From BUS-00B2 to ...
# 3       \tFCL_ELS_CBL_002H  Electrical Power Line,4.16KV,From BUS-00B1 to ...
# 4       \tFCL_ELS_CBL_002L  Electrical Power Line,4.16KV,From BUS-00B2-A t...
# ...                    ...                                                ...
# 126013          YTF-VSTORE                          Computer Storage Location
# 126014             YX2411A                Pump, Unwatering, Primary Tanks 1-2
# 126015          ZB20-CA-31            Damper,Combustion Air, Steam Boiler #20
# 126016       ZXDATA-PILOT1      DO NOT USE - City of Toronto Pump, RW Pump 18
# 126017      ZXDP VALVE COL                 DO NOT USE - Toronto Water DP Pump
#
#                       Parent  \
# 0       FCL_ELS_4.16KV_LINES
# 1       FCL_ELS_4.16KV_LINES
# 2       FCL_ELS_4.16KV_LINES
# 3       FCL_ELS_4.16KV_LINES
# 4       FCL_ELS_4.16KV_LINES
# ...                      ...
# 126013               YTF EUS
# 126014        TAB-PRM-P-SUMP
# 126015       TAB-ACC-BO-0500
# 126016                  None
# 126017                  None
#
#                                        Parent_Description  \
# 0                            Electrical Power Line,4.16KV
# 1                            Electrical Power Line,4.16KV
# 2                            Electrical Power Line,4.16KV
# 3                            Electrical Power Line,4.16KV
# 4                            Electrical Power Line,4.16KV
# ...                                                   ...
# 126013                     Production & End User  Support
# 126014  P Bldg & Old PS Buildings, Primary Treatment S...
# 126015                                Boiler #20, Volcano
# 126016                                               None
# 126017                                               None
#
#                              Category                  Class Suspended
# 0                   Air Handling Unit  Electrical Power Line      None
# 1                   Air Handling Unit  Electrical Power Line      None
# 2                   Air Handling Unit  Electrical Power Line      None
# 3                   Air Handling Unit  Electrical Power Line      None
# 4                   Air Handling Unit  Electrical Power Line      None
# ...                               ...                    ...       ...
# 126013                           None                   None      None
# 126014  Pump,Centrifugal,single-Stage                   Pump      None
# 126015                  Damper/Louver          Damper/Louver      None
# 126016               Pump,Centrifugal                   Pump      None
# 126017                           None                   None      None
#
# [126018 rows x 7 columns]

# %% [markdown]
# Here is were we capture the 13040 tag section if it is present in the entity number

# %%
import re

df_13040 = pd.read_excel('13040 Codes.xlsx', sheet_name='Append1')
dict_13040 = dict(zip(df_13040['CODE'], df_13040['DESCRIPTION']))

def extract_code(entity):
    # Use regex to match the third group between dashes
    match = re.match(r'^[^-]+-[^-]+-([^-]+)-[^-]+$', str(entity))
    return match.group(1) if match else None

def code_in_dict(code):
    return code if code in dict_13040 else None

df['Extracted_Code'] = df['Entity_number'].apply(extract_code)
df['Matched_Code'] = df['Extracted_Code'].apply(code_in_dict)
df
# Out:
#              Entity_number                                        Description  \
# 0       \tFCL_ELS_CBL_001L  Electrical Power Line,4.16KV,From BUS-00B1-A t...
# 1       \tFCL_ELS_CBL_002D  Electrical Power Line,4.16KV,From BUS-00B2-A t...
# 2       \tFCL_ELS_CBL_002F  Electrical Power Line,4.16KV,From BUS-00B2 to ...
# 3       \tFCL_ELS_CBL_002H  Electrical Power Line,4.16KV,From BUS-00B1 to ...
# 4       \tFCL_ELS_CBL_002L  Electrical Power Line,4.16KV,From BUS-00B2-A t...
# ...                    ...                                                ...
# 126013          YTF-VSTORE                          Computer Storage Location
# 126014             YX2411A                Pump, Unwatering, Primary Tanks 1-2
# 126015          ZB20-CA-31            Damper,Combustion Air, Steam Boiler #20
# 126016       ZXDATA-PILOT1      DO NOT USE - City of Toronto Pump, RW Pump 18
# 126017      ZXDP VALVE COL                 DO NOT USE - Toronto Water DP Pump
#
#                       Parent  \
# 0       FCL_ELS_4.16KV_LINES
# 1       FCL_ELS_4.16KV_LINES
# 2       FCL_ELS_4.16KV_LINES
# 3       FCL_ELS_4.16KV_LINES
# 4       FCL_ELS_4.16KV_LINES
# ...                      ...
# 126013               YTF EUS
# 126014        TAB-PRM-P-SUMP
# 126015       TAB-ACC-BO-0500
# 126016                  None
# 126017                  None
#
#                                        Parent_Description  \
# 0                            Electrical Power Line,4.16KV
# 1                            Electrical Power Line,4.16KV
# 2                            Electrical Power Line,4.16KV
# 3                            Electrical Power Line,4.16KV
# 4                            Electrical Power Line,4.16KV
# ...                                                   ...
# 126013                     Production & End User  Support
# 126014  P Bldg & Old PS Buildings, Primary Treatment S...
# 126015                                Boiler #20, Volcano
# 126016                                               None
# 126017                                               None
#
#                              Category                  Class Suspended  \
# 0                   Air Handling Unit  Electrical Power Line      None
# 1                   Air Handling Unit  Electrical Power Line      None
# 2                   Air Handling Unit  Electrical Power Line      None
# 3                   Air Handling Unit  Electrical Power Line      None
# 4                   Air Handling Unit  Electrical Power Line      None
# ...                               ...                    ...       ...
# 126013                           None                   None      None
# 126014  Pump,Centrifugal,single-Stage                   Pump      None
# 126015                  Damper/Louver          Damper/Louver      None
# 126016               Pump,Centrifugal                   Pump      None
# 126017                           None                   None      None
#
#        Extracted_Code Matched_Code
# 0                None         None
# 1                None         None
# 2                None         None
# 3                None         None
# 4                None         None
# ...               ...          ...
# 126013           None         None
# 126014           None         None
# 126015           None         None
# 126016           None         None
# 126017           None         None
#
# [126018 rows x 9 columns]

# %% [markdown]
# ## SPARQL connection
# The following will now load the data from the OWL file

# %%
from rdflib import Graph
import pandas as pd

# Load the RDFS .ttl file into an RDFLib Graph
g = Graph()
g.parse(r"../TWONTO/OWL/TWONTO.ttl", format="turtle")

# Prepare a custom SPARQL query
query = """

PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX tw: <http://www.toronto.ca/TWONTO#>

SELECT DISTINCT ?label ?subject
       (COALESCE(?isEquivalentToCategory, "") AS ?isEquivalentToCategory)
       (COALESCE(?isEquivalentToClass, "") AS ?isEquivalentToClass)
       (COALESCE(?isSuperclassToCategory, "") AS ?isSuperclassToCategory)
       (COALESCE(?isSuperclassToClass, "") AS ?isSuperclassToClass)
       (COALESCE(?is_equivalent_to_tag_code, "") AS ?is_equivalent_to_tag_code)
       (COALESCE(?is_superclass_to_tag_code, "") AS ?is_superclass_to_tag_code)
WHERE {
  # ?subject rdfs:label ?label .

#  FILTER NOT EXISTS { ?subject owl:deprecated true }

#  ?assetClass rdfs:label "asset" .
#  ?subject rdfs:subClassOf+ ?assetClass .

  OPTIONAL { ?subject tw:is_equivalent_to_Avantis_category ?isEquivalentToCategory . }
  OPTIONAL { ?subject tw:is_equivalent_to_Avantis_class ?isEquivalentToClass . }
  OPTIONAL { ?subject tw:is_superclass_to_Avantis_category ?isSuperclassToCategory . }
  OPTIONAL { ?subject tw:is_superclass_to_Avantis_class ?isSuperclassToClass . }
  OPTIONAL { ?subject tw:is_equivalent_to_tag_code ?is_equivalent_to_tag_code . }
  OPTIONAL { ?subject tw:is_superclass_to_tag_code ?is_superclass_to_tag_code . }
}
"""

# Execute the query
results = g.query(query)

# Convert results to a DataFrame, do not replace None with empty string
data = []
for row in results:
    data.append([
        str(row.label) if row.label else None,
        str(row.subject) if row.subject else None,
        str(row.isEquivalentToCategory) if row.isEquivalentToCategory else None,
        str(row.isEquivalentToClass) if row.isEquivalentToClass else None,
        str(row.isSuperclassToCategory) if row.isSuperclassToCategory else None,
        str(row.isSuperclassToClass) if row.isSuperclassToClass else None,
        str(row.is_equivalent_to_tag_code) if row.is_equivalent_to_tag_code else None,
        str(row.is_superclass_to_tag_code) if row.is_superclass_to_tag_code else None
    ])

df_sparql = pd.DataFrame(data, columns=[
    "label",
    "subject",
    "isEquivalentToCategory",
    "isEquivalentToClass",
    "isSuperclassToCategory",
    "isSuperclassToClass",
    "is_equivalent_to_tag_code",
    "is_superclass_to_tag_code"
])

df_sparql
# Out:
#                         label  \
# 0     new_13040_code_proposed
# 1                    contains
# 2                     created
# 3               fully grounds
# 4                     grounds
# ...                       ...
# 1323                    steam
# 1324              thermal oil
# 1325                    water
# 1326     water glycol mixture
# 1327     water-glycol mixture
#
#                                                 subject  \
# 0     http://www.toronto.ca/TWONTO#new_13040_code_pr...
# 1                    http://www.toronto.ca/TWONTO#00865
# 2                    http://www.toronto.ca/TWONTO#00866
# 3                    http://www.toronto.ca/TWONTO#00867
# 4                    http://www.toronto.ca/TWONTO#00868
# ...                                                 ...
# 1323                 http://www.toronto.ca/TWONTO#00704
# 1324                 http://www.toronto.ca/TWONTO#00745
# 1325                 http://www.toronto.ca/TWONTO#00798
# 1326                 http://www.toronto.ca/TWONTO#00799
# 1327                 http://www.toronto.ca/TWONTO#00799
#
#      isEquivalentToCategory isEquivalentToClass isSuperclassToCategory  \
# 0                      None                None                   None
# 1                      None                None                   None
# 2                      None                None                   None
# 3                      None                None                   None
# 4                      None                None                   None
# ...                     ...                 ...                    ...
# 1323                   None                None                   None
# 1324                   None                None                   None
# 1325                   None                None                   None
# 1326                   None                None                   None
# 1327                   None                None                   None
#
#      isSuperclassToClass is_equivalent_to_tag_code is_superclass_to_tag_code
# 0                   None                      None                      None
# 1                   None                      None                      None
# 2                   None                      None                      None
# 3                   None                      None                      None
# 4                   None                      None                      None
# ...                  ...                       ...                       ...
# 1323                None                      None                      None
# 1324                None                      None                      None
# 1325                None                      None                      None
# 1326                None                      None                      None
# 1327                None                      None                      None
#
# [1328 rows x 8 columns]

# %% [markdown]
# Now to create the dictionary items for easy lookup later

# %%
dict_class = dict(zip(df_sparql['isEquivalentToClass'], df_sparql['label']))
dict_superclass = dict(zip(df_sparql['isSuperclassToClass'], df_sparql['label']))
dict_category = dict(zip(df_sparql['isEquivalentToCategory'], df_sparql['label']))
dict_supercategory = dict(zip(df_sparql['isSuperclassToCategory'], df_sparql['label']))
dict_tag = dict(zip(df_sparql['is_equivalent_to_tag_code'], df_sparql['label']))
dict_supertag = dict(zip(df_sparql['is_superclass_to_tag_code'], df_sparql['label']))
dict_iri = dict(zip(df_sparql['subject'], df_sparql['label']))
dict_class
# Out:
# {None: 'water-glycol mixture',
#  'Vehicle': 'passenger vehicle',
#  'Fan': 'fan',
#  'Structure': 'structure',
#  'Power Supply Unit': 'DC power supply',
#  'Programmable Logic Control': 'PLC',
#  'Remote Processor Unit': 'RPU panel',
#  'Remote Transmission Unit': 'RPU panel',
#  'Uninterruptible Power Supply': 'UPS',
#  'Ultraviolet Disinfection': 'UV disinfection assembly',
#  'Variable Frequency Drive': 'VFD',
#  'Actuator': 'actuator',
#  'Damper/Louver': 'damper',
#  'Drier': 'air dryer',
#  'Duct': 'air duct segment',
#  'Vent': 'air duct segment',
#  'Air Exchanger Unit': 'air exchange unit',
#  'Air Handling Unit': 'air handler unit',
#  'Scrubber': 'air scrubber',
#  'Silencer': 'air silencer',
#  'Alarm': 'alarm device',
#  'Sampler': 'auto sampler',
#  'Safety,Defibrillator': 'automatic external defibrillator',
#  'Back Flow Preventer': 'backflow preventer',
#  'Battery': 'battery',
#  'Blower': 'blower',
#  'Boat': 'boat',
#  'Boiler': 'boiler',
#  'Circuit Breaker': 'breaker',
#  'Building': 'building',
#  'Burner': 'burner',
#  'Cable': 'cable segment',
#  'Capacitor': 'capacitor',
#  'Centrifuge': 'centrifuge',
#  'Gate': 'gate',
#  'Chemical Feeder': 'chemical feeder',
#  'Analyzer': 'chemical or concentration analyzer (MBC)',
#  'Chiller': 'chiller',
#  'Clarifier': 'clarifier',
#  'Classifier': 'classifier',
#  'Collector Mechanism': 'collector mechanism',
#  'Communications Equipment': 'communication or networking equipment (MBC)',
#  'Compactor': 'compactor',
#  'Compressor': 'compressor',
#  'Computer Hardware': 'computer',
#  'Condensing Unit': 'condenser',
#  'Earthmoving Equipment': 'construction or earthmoving machine (MBC)',
#  'Control Loop': 'control loop',
#  'Conveyor': 'conveyor',
#  'Cooling Tower': 'cooling tower',
#  'Crane': 'crane',
#  'Cyclone': 'cyclone classifier',
#  'Recorder': 'data logger',
#  'Dehumidifier': 'dehumidifier',
#  'Door': 'door',
#  'Drain': 'drain',
#  'Drive mechanism': 'drive mechanism',
#  'Injector': 'injector, ejector, or eductor',
#  'Elevator': 'elevator',
#  'Energy Wheel': 'energy recovery wheel',
#  'Engine': 'engine',
#  'Chamber': 'chamber',
#  'Evaporator': 'HVAC evaporator',
#  'Gas Monitoring': 'fixed gas detector',
#  'Flame Arrester': 'flame arrester',
#  'Gas Collection': 'gas collector',
#  'Gearbox': 'gearbox',
#  'Generator': 'generator',
#  'Grinder': 'grinder or comminutor',
#  'Grounds': 'grounds or building service equipment (MBC)',
#  'Heat Exchanger': 'heat exchanger',
#  'Heater': 'space heater',
#  'Domestic Hot Water': 'hot water heater',
#  'Humidifier': 'humidifier',
#  'Hydraulic System': 'hydraulic system',
#  'Incinerator': 'incinerator',
#  'Air Instrument': 'instrument air or pneumatic control panel',
#  'Indicator': 'instrument gauge or indicator (MBC)',
#  'Sensor': 'sensor element (MBC)',
#  'Transmitter': 'intrument with a transmitter',
#  'Lifting Device': 'lifting device or lifting device component (MBC)',
#  'Load Break Switch': 'load break disconnect switch',
#  'Man Lift': 'man lift',
#  'Maintenance Hole': 'maintenance hole',
#  'Agitator': 'mixer',
#  'Mixer': 'mixer',
#  'Motor': 'motor',
#  'Starter': 'motor starter',
#  'Network': 'network panel',
#  'Router': 'network router',
#  'Network Switch': 'network switch',
#  'Operator Interface Terminal': 'HMI',
#  'SCADA computer terminal': 'HMI',
#  'Outfall': 'outfall',
#  'Piping': 'pipe segment',
#  'Pipette': 'pipette',
#  'Plumbing': 'plumbing',
#  'Chlorine Monitoring Device,Por': 'portable chlorine analyzer',
#  'Power Washer': 'power washer',
#  'Control Panel': 'process control panel',
#  'Controller': 'process controller',
#  'Protective Relay': 'protection relay',
#  'Pump Station': 'pumping station',
#  'Quencher': 'quencher',
#  'Roof': 'roof',
#  'Rupture Disc': 'rupture disc',
#  'Safety Equipment': 'safety or hazard management equipment (MBC)',
#  'Screen': 'screening unit',
#  'Security System': 'security system',
#  'Server': 'server appliance',
#  'Camera': 'mobile still or video camera',
#  'Strainer': 'strainer',
#  'Substation': 'substation',
#  'System Process Control': 'system process control',
#  'Test Equipment': 'testing tool (MBC)',
#  'Tool': 'tool (MBC)',
#  'Transformer': 'transformer',
#  'Vacuum Cleaner': 'vacuum cleaner',
#  'Valve': 'valve',
#  'Vortex': 'vortex classifier',
#  'Water Trailer': 'water trailer',
#  'Weigh Scale': 'weight scale',
#  'Well': 'well',
#  'Office Equipment': 'business administration and office equipment (MBC)'}

# %% [markdown]
# ## Manual Matching
# Here we will load the manual matched file

# %%
df_manual = pd.read_excel('manualMatch.xlsx', sheet_name='LLM capability Test Dataset')
df_manual
# Out:
#              ID      Entity_number  \
# 0      104978.0            NX5232A
# 1      119738.0    TAB-WA1-SQ-1984
# 2       59232.0   THC-ACC-HTR-6025
# 3      119966.0    TAB-WA4-SQ-3430
# 4       59390.0  THC-ACC-PDIT-6291
# ...         ...                ...
# 44099       NaN    THC-PRM-TI-1204
# 44100       NaN    THC-PRM-TI-1214
# 44101       NaN    WTR-PPD-TI-1013
# 44102       NaN    WTR-PPD-TI-1014
# 44103       NaN    COL-RBB-UV-0121
#
#                                              Description            Parent  \
# 0                        Chiller, Silo Bldg Control Room        TAB-ACC-CI
# 1          Lanyard  6 Ft- Velasco, Gabriel\t\t\t\t\t\t\t   TAB-WA1-SQ-0001
# 2      Heater, Unit, Electric, Heating System, Lower ...  THC-ELS-LP-4042A
# 3                              Fall Limiter - MFLT2/705F   TAB-WA4-SQ-0010
# 4      Transmitter, Pressure Differential, Filter F-6...    THC-ACC-F-6291
# ...                                                  ...               ...
# 44099               Temperature, Indicate, Oil Tank 1210    THC-PRM-T-1210
# 44100               Temperature, Indicate, Oil Tank 1270    THC-PRM-T-1270
# 44101  Transmitter, Temperature, Indoor, AHU, Pump Ga...  WTR-PPD-AHU-1011
# 44102             Transmitter, Temperature, Outdoor Air,  WTR-PPD-AHU-1011
# 44103                           UV Chamber, disinfection      COL-RBB-MISC
#
#                       Category             Class  Suspended   Tag  \
# 0             H.V.A.C.,Chiller              HVAC        NaN   NaN
# 1                  PPE,Harness  Safety Equipment        NaN    SQ
# 2         H.V.A.C.,Heater,Unit              HVAC        NaN   HTR
# 3                  PPE,Lanyard  Safety Equipment        NaN    SQ
# 4         Transmitter,Pressure              HVAC        NaN  PDIT
# ...                        ...               ...        ...   ...
# 44099  Transmitter,Temperature       Transmitter        NaN    TI
# 44100  Transmitter,Temperature       Transmitter        NaN    TI
# 44101  Transmitter,Temperature         Indicator        NaN    TI
# 44102  Transmitter,Temperature         Indicator        NaN    TI
# 44103                      NaN           Chamber        NaN    UV
#
#                                              Valid_Class TH Suggestion  \
# 0                     http://www.toronto.ca/TWONTO#00213           NaN
# 1                     http://www.toronto.ca/TWONTO#00333           NaN
# 2                     http://www.toronto.ca/TWONTO#00418           NaN
# 3                     http://www.toronto.ca/TWONTO#00341           NaN
# 4                     http://www.toronto.ca/TWONTO#00605           NaN
# ...                                                  ...           ...
# 44099  http://www.toronto.ca/TWONTO#tujad-guzov-jilok...           NaN
# 44100  http://www.toronto.ca/TWONTO#tujad-guzov-jilok...           NaN
# 44101  http://www.toronto.ca/TWONTO#tujad-guzov-jilok...           NaN
# 44102  http://www.toronto.ca/TWONTO#tujad-guzov-jilok...           NaN
# 44103                 http://www.toronto.ca/TWONTO#00126           NaN
#
#                                       Parent_Description
# 0                                Chiller and Air Coolers
# 1                                WA1  Fall Arrest System
# 2              Lighting Panel, Vortex Gallery, Headworks
# 3                                WA4 Fall arrest systems
# 4      Filter, Outdoor Air Plenum, 2nd Floor, Mech Ro...
# ...                                                  ...
# 44099                                                NaN
# 44100                                                NaN
# 44101                                                NaN
# 44102                                                NaN
# 44103                                                NaN
#
# [44104 rows x 11 columns]

# %%
dict_manual = dict(zip(df_manual['Entity_number'],df_manual['Valid_Class'].map(dict_iri)))
dict_manual
# Out:
# {'NX5232A': 'chiller',
#  'TAB-WA1-SQ-1984': 'fall arrest lanyard',
#  'THC-ACC-HTR-6025': 'space heater',
#  'TAB-WA4-SQ-3430': 'fall restricting system',
#  'THC-ACC-PDIT-6291': 'pressure transmitter',
#  'THR-PLT-FSL-2222': 'flow switch',
#  'TAB-WA1-SQ-1915': 'fall arrest harness',
#  'THR-MCS-LD-9868': 'winch',
#  'TAB-RSP-FSL-1221D': 'flow switch',
#  'THR-WA1-LD-0051': 'synthetic web sling',
#  'THR-AER-PSL-1915': 'pressure switch',
#  'FHA-ELS-PDP-2100': '600V electrical panel',
#  'FHO-SM-SPL-0005': 'spill kit',
#  'COL-YKP-DA-0017S': nan,
#  'THR-SES-SCBA-0520': 'portable compressed gas cylinder',
#  'THC-MCS-SM-0240': 'welding machine',
#  'TAB-ACC-FN-6433': 'fan',
#  'THR-SES-SQ-9833S': nan,
#  'TAB-ACC-TSL-1247': 'temperature switch',
#  'FHA-SED-ZSH-0304F': 'limit switch',
#  'FCL-ACC-FS-0403': 'flow switch',
#  'THC-ELS-SQ-211160R': 'insulated glove',
#  'TNT-PRM-LS-0504': 'level switch',
#  'THC-ACC-HS-0119': 'manual switch',
#  'THC-AER-F-7220': 'replaceable air filter',
#  'THR-WA3-LD-0097S': nan,
#  'THR-SES-PGM-35920': 'portable gas detector',
#  'THR-AER-PSH-1315': 'pressure switch',
#  'TNT-CSO-G-0201': 'gate',
#  'TAB-PLT-T-1101': 'sedimentation tank',
#  'FHO-GRK-DR-1001L': 'fire rated door',
#  'COL-YKP-DA-0020(S)': nan,
#  'PA50294': 'PA system',
#  'FHA-SES-SQ-0086': 'fall protection system support struture',
#  'THR-SPC-COM-1310S': nan,
#  'COL-YKP-DA-0002(S)': nan,
#  'THR-GRK-FE-W': 'door',
#  'WTR-PMI-ZS-0029': 'position switch',
#  'TAB-PWA-LSHH-5152': 'level switch',
#  'COL-YKP-VEH-0032S': nan,
#  'THC-DIG-FX-5200': 'flame arrester',
#  'THR-DR-WH-0508': 'roll up door',
#  'THC-ACC-DM-0121': 'damper',
#  'SWM-PMG-SW-0002': 'power disconnect switch',
#  'THC-OCS-RPU-1803': 'RPU panel',
#  'THR-DIG-FSL-5680': 'flow switch',
#  'FHA-SED-ZSH-0204H': 'limit switch',
#  'COL-PWR-LSH-0103': 'level switch',
#  'COL-PNT-PSL-0120': 'pressure switch',
#  'THC-PRM-G-5141': 'gate',
#  'QT0503A': 'welding machine',
#  'COL-YKP-FAK-0020S': nan,
#  'THR-PLT-TSH-2120': 'temperature switch',
#  'THR-SES-SCBA-0526S': nan,
#  'FIS-DEW-LSH-0010': 'level switch',
#  'THC-FEQ-CP-6201': nan,
#  'WTR-RMI-ZS-0051': 'position switch',
#  'PA50283': 'PA system',
#  'TAB-THK-LSHH-8051A': 'level switch',
#  'FHO-CLB-T-0301': 'expansion tank',
#  'TAB-DIG-LSHH-8065A': 'level switch',
#  'COL-PLB-TIC-0100': 'thermostat or zone controller unit',
#  'THR-PRM-PSL-3320': 'pressure switch',
#  'TAB-CW-FSH-0035': 'flow switch',
#  'TAB-PRM-T-0700': 'clarifier',
#  'TAB-STR-F-4004S': 'replaceable air filter',
#  'TAB-WA2-SQ-1275': 'lifting device or lifting device component (MBC)',
#  'TAB-DEW-F-4121': 'discrete unit of treatment filter',
#  'TAB-THK-FD-4021': 'polymer preparation system unit',
#  'WTR-RDF-ZS-0305': 'position switch',
#  'THR-DIS-PSH-0100': 'pressure switch',
#  'TAB-WA3-LD-9537': 'synthetic web sling',
#  'THR-BG-VSH-0111': 'vibration sensor element',
#  'TAB-WA6-SQ-3834': 'fall arrest lanyard',
#  'THC-THK-T-1220': 'chemical storage tank',
#  'WTR-PLW-DR-0002': 'door',
#  'COL-YKP-VEH-0023': 'pickup truck',
#  'FCL-SH-17': 'fall arrest harness',
#  'FCL-SES-SQ-1006': 'insulated glove',
#  'TAB-ACC-HE-6402': 'heat exchanger',
#  'THC-ACC-DM-3071': nan,
#  'THC-GRK-DR-G': 'door',
#  'TAB-SES-LTG-2283B': 'emergency light',
#  'THR-MCS-LD-2134': 'winch',
#  'THR-MCS-LD-0334': 'hoist',
#  'TAB-CW-FSH-0039': 'flow switch',
#  'FHO-ELS-MCC-0910': '600V electrical panel',
#  'TAB-GRK-VEH-378272': 'golf cart or utility task vehicle',
#  'TAB-SLO-PLQ-0001': 'piping system',
#  'THR-ACC-NX-743S': nan,
#  'COL-PMP-RPU-0001': 'RPU panel',
#  'COL-MTI-LSH-2302B': 'level switch',
#  'WTR-PJS-BUS-0201': '600V electrical panel',
#  'TAB-EL1-MCC-6542': '600V electrical panel',
#  'TAB-ACC-AC-9201': 'condenser',
#  'TAB-WA3-LD-2370': 'synthetic web sling',
#  'FIS-POL-LSH-0001': 'level switch',
#  'THR-SE-LD-2566': nan,
#  'FIS-MCS-LD-0023': 'fall protection system support struture',
#  'FIS-SPC-RPU-1524': 'RPU panel',
#  'THC-PRM-ZSL-1173': 'position switch',
#  'TAB-PRM-LSHH-8071': 'level switch',
#  'THR-SES-SQ-1448': 'fall arrest lanyard',
#  'THR-ELS-MCC-0022A': '600V electrical panel',
#  'FHA-SED-ZSH-0201B': 'limit switch',
#  'THR-DIG-RPU-0012': 'RPU panel',
#  'WTR-RRG-SW-0002': 'power disconnect switch',
#  'FIS-CLB-CHL-0301': 'chlorinator',
#  'TAB-SES-LTX-2294': nan,
#  'FHA-AM-T-0401': nan,
#  'TAB-ACC-FS-8220': 'flow switch',
#  'TAB-WA3-SQ-7146': 'fall arrest harness',
#  'TAB-ACC-V-6402': 'valve',
#  'MTMH123': 'defined collection of assets',
#  'TAB-DIG-BU': 'defined collection of assets',
#  'THR-DIG-LSH-0106': 'level switch',
#  'THC-PRM-ZSH-1151': 'position switch',
#  'COL-YKP-VEH-0042': 'pickup truck',
#  'THR-WA3-LD-0028S': nan,
#  'TAB-ACC-PDS-8232A': 'pressure switch',
#  'TAB-EL2-MCC-6001': '600V electrical panel',
#  'THR-DIS-LSH-6001': 'level switch',
#  'YTF-ACC-AHU-4701': 'air handler unit',
#  'THR-SQ-FAK-CSE': 'first aid kit',
#  'WTR-RRG-LSH-0002': 'level switch',
#  'COL-PCF-LSHH-0104': 'level switch',
#  'THR-ACC-PSL-2201': 'pressure switch',
#  'TNT-CSO-POL-2401': 'polymer preparation system unit',
#  'THR-DIS-FSL-1304': 'flow switch',
#  'THC-ELS-SQ-6185131': 'insulated glove',
#  'FCL-SPC-RPU-1523': 'RPU panel',
#  'TAB-CW-FSH-0003S': nan,
#  'FHA-SED-ZSH-0403D': 'limit switch',
#  'THR-WA2-LD-0027S': 'wire-rope sling',
#  'WTR-PRH-TSH-0004': 'temperature switch',
#  'FCL-ELS-LB-0101-SUS': nan,
#  'THC-ACC-V-6022': 'valve',
#  'WTR-PEL-LSH-1102': 'level switch',
#  'FHA-GRK-DR-0100': 'roll up door',
#  'THC-DEW-G-6561': 'valve',
#  'TAB-EL1-MCC-6225': '600V electrical panel',
#  'FHO-ELS-DP-0314-SUS': nan,
#  'THC-ACC-V-6057': 'valve',
#  'TAB-ACC-FSL-6306': 'flow switch',
#  'THC-MCS-LD-1119-008': 'lifting device sling',
#  'COL-PNT-LSH-0001': nan,
#  'TAB-ACC-6000': 'defined collection of assets',
#  'WTR-RRG-RPU-0001': 'RPU panel',
#  'THR-SES-T-0506': 'portable compressed gas cylinder',
#  'COL-PGA-LSH-0103': 'level switch',
#  'THR-FT-FSL-3005S': nan,
#  'WTR-PWT-ZS-0001': 'position switch',
#  'THC - A01 - S160': 'door',
#  'THR-PRM-G-N': 'gate',
#  'FHA-SED-ZSH-0105': 'limit switch',
#  'THC-SPC-COM-2205': 'network termination panel',
#  'FHO-ELS-DP-0110-SUS': nan,
#  'TNT-SES-RING-1002': 'personal floatation device',
#  'SQ-47076': nan,
#  'TAB-DIS-SQ-0101': nan,
#  'THR-CG-LSH-1263': 'level switch',
#  'MTMH523': 'defined collection of assets',
#  'THC-ITS-PA-2310': 'PA system',
#  'TAB-ACC-HTR-6506': 'space heater',
#  'THR-DIG-PSH-6601': 'pressure switch',
#  'FCL-SES-FA-0002-SUS': nan,
#  'THC-MCS-LD-0619-001': 'lifting device sling',
#  'TAB-DIG-PSL-4140A': 'pressure switch',
#  'THR-ACC-MAINSUB': 'defined collection of assets',
#  'FHO-GRK-DR-1008L': 'fire rated door',
#  'THC-GRK-VEH-076088': 'pickup truck',
#  'THC-ACC-T-6872': 'expansion tank',
#  'TAB-ELS-SQ-6154': 'insulated glove',
#  'FIS-ELS-WR-0604': 'wielding receptacle',
#  'THR-ACC-DM-0113': 'damper',
#  'FHO-GRK-COM-0001': 'PA system',
#  'TAB-ACC-AHU-1244': 'air handler unit',
#  'FHO-DOZ-TSL-4504': 'temperature switch',
#  'COL-MTI-T-0101': 'chemical storage tank',
#  'WTR-PHL-TSL-0001': 'temperature switch',
#  'THC-DIG-TSH-0443': 'temperature switch',
#  'FIS-FLT-FSL-0002SUS': nan,
#  'WTR-RST-ZS-0003': 'position switch',
#  'TAB-RSP-PSL-1211': 'pressure switch',
#  'THR-SES-LD-8819': 'winch',
#  'FCL-PAC-LSH-0001': 'level switch',
#  'THR-GRK-SM': 'discrete unit of work',
#  'THR-ACC-NR-662': 'space heater',
#  'COL-YKP-DA-150856': 'fall protection system component (MBC)',
#  'FHO-SPC-RPU-1722': 'RPU panel',
#  'FHO-ACC-FS-1551': 'flow switch',
#  'FHO-ACC-F-0507': 'replaceable air filter',
#  'TAB-WA2-ADM-0001': 'defined collection of assets',
#  'THC-DEW-T-7580': 'chemical storage tank',
#  'TAB-ACC-FSL-5853': 'flow switch',
#  'THR-SES-SQ-0111': 'emergency eyewash and shower',
#  'THR-AER-F-1110': 'replaceable air filter',
#  'THR-ELS-MCC-1501': '600V electrical panel',
#  'TAB-ELS-LTG-1050': 'emergency light',
#  'DOS-YCM-FAK-VEH076090': 'first aid kit',
#  'DOS-YCM-VEH-285024': 'passenger vehicle',
#  'THC-ACC-FN-0583': 'fan',
#  'FHA-ELS-WR-0603': 'wielding receptacle',
#  'THC-PWA-RPU-2201': 'RPU panel',
#  'COL-PMM-LSH-0203': 'level switch',
#  'TAB-EL2-MCC-6624': '600V electrical panel',
#  'THC-ACC-V-6411': 'valve',
#  'WTR-PLW-PSHL-0003': 'pressure switch',
#  'THR-ITS-COM-4011': 'network panel',
#  'THC-MCS-LD-1603288': 'lifting device sling',
#  'THR-PLT-RPU-0203': 'RPU panel',
#  'FHO-ELS-MCC-0510': '600V electrical panel',
#  'THR-ACC-AC-0004': 'air condition',
#  'FHA-AUX-T-0401': 'pressure vessel',
#  'THR-WA1-LD-0030': 'wire-rope sling',
#  'WTR-PRV-SQ-0001': 'emergency eyewash',
#  'TAB-DIS-RPU-0522S': nan,
#  'THR-DIS-CHL-1211': nan,
#  'WTR-RMI-ZS-0015': 'position switch',
#  'TAB-ACC-TE-1404B': 'temperature sensor element',
#  'TAB-DEW-PSH-3370': 'pressure switch',
#  'THC-PLT-G-0133': 'gate',
#  'TAB-SA-D-3402': 'air dryer',
#  'FHA-SES-LDR-0105': 'ladder',
#  'TAB-AUX-LSHH-8034A': 'level switch',
#  'FCL-CLB-FSL-0003A-SUS': nan,
#  'THC-SPC-COM-1102': 'network termination panel',
#  'THC-STR-T-8400': nan,
#  'FCL-ELS-MCC-0801-SUS': nan,
#  'THC-MCS-LD-0000000002': 'lifting device sling',
#  'TAB-ELS-SQ-6105': 'insulated glove',
#  'THC-SES-DEF-0003': 'automatic external defibrillator',
#  'THR-GRK-VEH-076011': 'pickup truck',
#  'TAB-DIG-LSH-1103': 'level switch',
#  'THR-ELS-MCC-1901S': nan,
#  'FHA-SED-ZSH-0505': 'limit switch',
#  'THC-ACC-HTR-0267': 'space heater',
#  'FHA-SES-FAK-0401': 'first aid station equipment',
#  'TAB-ELS-SQ-6001': 'first aid kit',
#  'THR-DIG-PSL-4711': 'pressure switch',
#  'THC-DIG-BU-5220S': nan,
#  'THR-FT-T-0503S': nan,
#  'FIS-FEQ-DR-0071(S)': 'door',
#  'THC-ACC-TIT-6003': 'temperature transmitter',
#  'FCL-SES-CYL-0013': 'portable compressed gas cylinder',
#  'FHA-SED-T-0101': 'flocculation tank',
#  'TAB-DEW-SSL-6005': 'speed switch',
#  'THR-MCS-MT-0681': 'welding machine',
#  'THC-OCS-LSL-0400': 'level switch',
#  'FHO-MCS-LD-0304': 'lift truck or pallet jack',
#  'THR-ACC-AC-2204': 'air condition',
#  'TAB-DIG-BU-7300': 'waste gas burner',
#  'WTR-RKL-ZS-0002': 'position switch',
#  'CL2003A1': 'injector, ejector, or eductor',
#  'WTR-PHL-T-0007-SUS': nan,
#  'TAB-WA2-SQ-7634': 'fall arrest lanyard',
#  'THC-DEW-T-7310': 'storage tank',
#  'COL-YKP-FAK-0032S': nan,
#  'FHO-ACC-FS-0702': 'flow switch',
#  '(S)': nan,
#  'THC-ACC-HTR-0235': 'space heater',
#  'THR-WA2-LD-95-23': 'synthetic web sling',
#  'COL ADMIN': 'defined collection of assets',
#  'THC-ELS-MCC-2202': '600V electrical panel',
#  'THR-MCS-LD-0002': 'hoist',
#  'THC-ELS-MCC-3601': '600V electrical panel',
#  '378170SUS': nan,
#  'THR-GRK-PRTY-0103': 'discrete unit of work',
#  'TAB-WA4-SQ-9106': nan,
#  'TAB-ACC-FSL-4410': 'flow switch',
#  'WTR-RMI-LSH-0101': 'level switch',
#  'FCL-GRK-VEH-0001': 'pickup truck',
#  'COL-PWN-TSL-0001': 'temperature switch',
#  'WTR-RKL-RPU-0001': 'RPU panel',
#  'FIS-FEQ-DR-0030(S)': 'door',
#  'COL-YKP-DA-108201': 'fall protection system component (MBC)',
#  'THR-WA3-LD-0036': 'wire-rope sling',
#  'FHO-PCL-P-0301-KQ': 'chemical dosing system',
#  'FCL-TRW-LSH-0004': 'level switch',
#  'COL-YKP-DA-0016S': nan,
#  'SWM-PBL-LSH-0105': 'level switch',
#  'WTR-PRH-AC-0001': 'air condition',
#  'SWM-PMG-LSHH-0107': 'level switch',
#  'TAB-PLT-MSL-0461': 'motion sensor element',
#  'TNT-AER-PSL-2001': 'pressure switch',
#  'THC-GRK-VEH-396107': 'golf cart or utility task vehicle',
#  'FCL-ACC-RPU-0601': 'RPU panel',
#  'FHA-SES-LTX-0702': nan,
#  'TAB-PLT-SP-0401': nan,
#  'THC-ELS-MCC-0802': '600V electrical panel',
#  'FHO-GRK-DR-2008SB': 'fire rated door',
#  'FIS-SPC-CPU-1310': 'HMI',
#  'TAB-ACC-HE-6531': 'heat exchanger',
#  'FHO-ACC-RPU-0701': 'RPU panel',
#  'THR-WA3-LD-0098': 'synthetic web sling',
#  'TAB-ACC-RPU-6100': 'RPU panel',
#  'FHO-GRK-VEH-0101': 'golf cart or utility task vehicle',
#  'FHO-SES-SCBA-6014': 'portable compressed gas cylinder',
#  'COL-MTI-HPU-2401': 'hydraulic power pack',
#  'FHO-ELS-LP-0511': '120V/240V electrical panel',
#  'FCL-SES-CYL-0002': 'portable compressed gas cylinder',
#  'COL-BEB-LSH-0001': 'level switch',
#  'TAB-RSP-UPS-0232': 'UPS',
#  'THR-ELS-MCC-0601': '600V electrical panel',
#  'THC - A01 - D192': 'door',
#  'TAB-RSP-F-1221A': 'replaceable oil or fuel filter',
#  'THC-INC-IG-0001': 'incinerator',
#  'THR-DIG-SSH-5190A': 'speed switch',
#  'FHA-AM-T-0201': 'chemical storage tank',
#  'TAB-WA3-LD-1355': 'synthetic web sling',
#  'TAB-ACC-TSL-3670': 'temperature switch',
#  'FHA-GRK-DR-1001': 'door',
#  'TAB-PLT-LSL-0288': 'level switch',
#  'THR-PRS-T-0120S': nan,
#  'THR-MCS-LD-0090': 'hoist',
#  'WTR-PMI-ZS-0004': 'position switch',
#  'FIS-FEQ-FEQ-4006-SUS': nan,
#  'WTR-PEG-ZS-0002': 'position switch',
#  'TAB-PRM-RPU-0313': 'RPU panel',
#  'THR-DIG-SD-0400': 'digester tank',
#  'COL-YKP-DA-1734509': 'fall protection system support struture',
#  'FCL-DEW-LSH-0002': 'level switch',
#  'THC-ACC-T-5940': 'chemical storage tank',
#  'TAB-STR-F-4002S': 'replaceable air filter',
#  'THR-MCS-LD-1276': 'winch',
#  'WTR-RDF-DR-0013': 'door',
#  'WTR-PMI-T-0002': 'underground fuel oil tank',
#  'THR-THK-RPU-0005': 'RPU panel',
#  'THC-STR-LSH-0181': 'level switch',
#  'FHA-SES-LD-0094': 'fixed ladder',
#  'TAB-SES-LTX-2291': nan,
#  'TAB-ACC-V-6416': 'valve',
#  'THR-SQ-FAK-DIS': nan,
#  'TAB-ACC-AHU-4501': 'air handler unit',
#  'COL-PGA-COM-0001': 'network switch',
#  'FHO-GRK-DR-2047L': 'fire rated door',
#  'FHA-FLT-MX-3801': 'filter sweep arm',
#  'FCL-SES-EYE-0006': 'emergency eyewash',
#  'THC-ACC-HTR-0055': 'space heater',
#  'FHA-GQ-53791': 'road segment',
#  'FCL-ACC-FS-0703': 'flow switch',
#  'COL-YKP-DA-1671146': 'fall protection system support struture',
#  'THC-ACC-V-6091': 'valve',
#  'FIS-FEQ-FEQ-4002-SUS': nan,
#  'FHO-GRK-DR-4015S': 'fire rated door',
#  'TAB-GAS-T-0101': 'pressure vessel',
#  'FHO-NEX-5 CHANNEL 5-SUS': nan,
#  'TAB-DEW-RPU-1111': 'RPU panel',
#  'FCL-SH-16': 'fall arrest harness',
#  'THR-GRK-GRIT': 'space',
#  'COL-YKP-SRL-0050': nan,
#  'THC-M01-D086': 'door',
#  'THC-EPG-MCC-2870': '600V electrical panel',
#  'THR-ACC-NR-787': 'space heater',
#  'THR-ACC-T-0530': nan,
#  'THR-ACC-T-0701': 'chemical storage tank',
#  'THR-DIS-CP-0008': 'process control panel',
#  'TAB-DIS-LSHH-2003': 'level switch',
#  'DR8013A': 'air handler unit',
#  'TAB-ACC-ZSH-1853A': 'position switch',
#  'THC-SES-SQ-0181': 'emergency eyewash',
#  'THC-PRM-T-1200': 'clarifier',
#  'FHA-SES-LDR-0110': 'ladder',
#  'THR-DIF-TSL-7752A': 'temperature switch',
#  'WTR-PSC-FAR-0004S': nan,
#  'THR-PLT-HS-0210': 'manual switch',
#  'FIS-FL-FSL-0102-SUS': nan,
#  'FHO-MCS-LD-0224': 'dolly or hand truck',
#  'THR-AI-T-0590': 'pressure vessel',
#  'THR-ACC-NR-793': 'space heater',
#  'TAB-WA7-LDR-0004': 'ladder',
#  'FHA-SED-ZSH-0605A': 'limit switch',
#  'FCL-SPC-RPU-1721': 'RPU panel',
#  'TAB-PRM-DRN-P': 'drain',
#  'FHO-TRW-T-0102': 'pressure vessel',
#  'THC-ELS-SQ-6214599': nan,
#  'COL-PHP-SS-0001': 'security system',
#  '378119SUS': nan,
#  'THC-PRM-ZSH-1272': 'position switch',
#  'THC-INC-BU-1030': 'burner',
#  'THR-SES-SCBA-0514': 'SCBA system',
#  'TAB-PRS-PSH-0302': 'pressure switch',
#  'THR-WA3-LD-0041': 'wire-rope sling',
#  'THR-PRS-PSL-0053': 'pressure switch',
#  'TAB-SA-T-1700': 'expansion tank',
#  'TAB-SES-LTG-0002': 'emergency light',
#  'TAB-EL1-MCC-6005': '600V electrical panel',
#  'THR-DIG-SSH-5125A': 'speed switch',
#  'FHO-SES-SQ-0002': 'SCBA system',
#  'THC-THK-PSL-1101': 'pressure switch',
#  'FCL-ELS-LB-02CL': 'load break disconnect switch',
#  'TAB-PLT-G-5401': 'valve',
#  'THR-PRM-T-0300': 'clarifier',
#  'FHO-DOZ-T-0500': 'pressure vessel',
#  'COL-PLB-LSL-0102': 'level switch',
#  'DOS-SES-SCBA-0905': 'SCBA system',
#  'THR-ACC-NX-792': 'air handler unit',
#  'FIS-ELS-MCC-0300': '600V electrical panel',
#  'DOS ADMIN': 'defined collection of assets',
#  'TAB-ELS-LTG-1080': 'emergency light',
#  'THR-SES-SQ-7610S': nan,
#  'WTR-RLL-RPU-0001': 'RPU panel',
#  'FIS-ELS-PDP-0605': '600V electrical panel',
#  'TAB-PLT-G-0404': 'gate',
#  'FIS-WWW-CH-0800-SUS': nan,
#  'SWM-PMG-LSH-0001': 'level switch',
#  'THC-ACC-HTR-6011': 'space heater',
#  'FHA-SES-LDR-0415': 'portable ladder',
#  'TNT-SES-RING-1020': 'personal floatation device',
#  'FHA-FEQ-DT-0011': 'drain',
#  'FCL-FLT-SW-0901-SUS': nan,
#  'WTR-PWT-T-0002': 'expansion tank',
#  'FHO-ELS-WR-1002': 'wielding receptacle',
#  'THR-ACC-CU-3501': 'condenser',
#  'TAB-EL3-LP-6014B': '120V/240V electrical panel',
#  'TAB-WA6-SQ-5939': 'fall arrest lanyard',
#  'THR-WA1-LD-02-33': 'synthetic web sling',
#  'TAB-SES-LTX-2296': nan,
#  'TNT-DCL-LSH-0301': 'level switch',
#  'FHO-GRK-DR-2019L': 'fire rated door',
#  'THC-PRM-ZSH-1275': 'position switch',
#  'COL-MTI-RPU-2300B': 'RPU panel',
#  'TNT-ACC-CU-2009B': 'condenser',
#  'FHA-SES-SQ-0059': 'fall arrest harness',
#  'FHO-DOZ-T-3200-SUS': nan,
#  'THR-MCS-LD-7920': 'hoist',
#  'TAB-ACC-AHU-6102': 'air handler unit',
#  'TAB-EL1-LP-6678': '120V/240V electrical panel',
#  'THR-ACC-ZSH-5010': 'position switch',
#  'THR-ELS-SQ-0050': 'HV insulated blanket',
#  'FCL-RW-FSL-0701': 'flow switch',
#  'DOS-YCM-VEH-67047': 'pickup truck',
#  'THR-DIG-RPU-0018': 'RPU panel',
#  'TAB-WA2-SQ-2024': 'spill kit',
#  'TAB-SES-SQ-6300': 'flow switch',
#  'THR-SPC-COM-2012': 'network panel',
#  'TAB-ACC-TSL-1461': 'temperature switch',
#  'THC-ACC-DR-0602': 'roll up door',
#  'TAB-WA4-SQ-1216': 'synthetic web sling',
#  'FHA-SES-LDR-0418': 'ladder',
#  'FIS-CCS-LSH-0101': 'level switch',
#  'THC-ACC-F-6302': 'replaceable air filter',
#  'FHA-WWW-T-0003': 'storage tank',
#  'DOS-YCM-FAK-VEH270015': 'first aid kit',
#  'WTR-PJS-ZS-0010': 'position switch',
#  'COL-BDC-LSH-0001': 'level switch',
#  'THR-WA3-LD-0008': 'synthetic web sling',
#  'WTR-PRV-LSL-0100': 'level switch',
#  'THR-AER-T-1814': 'aeration tank',
#  'THR-SES-SPL-2668': 'spill kit',
#  'THC-PRM-LSHH-0101': 'level switch',
#  'FCL-FLT-LSL-0005-SUS': nan,
#  'THR-PRM-PSH-2341': 'pressure switch',
#  'COL-BCV-LSH-0001': 'level switch',
#  'TAB-EL1-MCC-6593': '600V electrical panel',
#  'FHO-FLT-F-0801': 'filtration tank',
#  'COL-MTI-RPU-2700B': 'RPU panel',
#  'THC-ACC-DM-6108': 'damper',
#  'SQ-47080': nan,
#  'FHA-SES-LDR-0403': 'ladder',
#  'TAB-ELS-SQ-6002': 'first aid kit',
#  'TAB-RSP-F-1241A': 'replaceable oil or fuel filter',
#  'THR-PRM-DRV-2221': 'VFD',
#  'THC-DIG-RPU-1401A': 'RPU panel',
#  'THC-GRK-DR-B': 'door',
#  'COL-SKW-T-0100': 'detention tank',
#  'THC-ACC-LTG-6101': 'thermostat or zone controller unit',
#  'TAB-ACC-HE-1454': 'heat exchanger',
#  'TAB-DEW-LSHH-8054': 'level switch',
#  'FCL ADMIN': 'defined collection of assets',
#  'TAB-SA-T-6301': 'pressure vessel',
#  'TAB-ELS-SQ-1014': 'storage cabinet',
#  'TNT-ELS-MCC-6101': '600V electrical panel',
#  'THR-CG-RPU-0002': 'RPU panel',
#  'THR-ACC-NR-664': 'space heater',
#  'TAB-ACC-T-7601': 'pressure vessel',
#  'COL-YKP-SRL-085518': 'self-retracting lifeline',
#  'THC-PLT-CP-0904': 'pneumatic control system',
#  'FHA-MCS-MT-1001': 'machine tool (MBC)',
#  'FHA-SES-SCBA-0013': 'portable compressed gas cylinder',
#  'THC-ELS-SQ-1093756': nan,
#  'THC-MCS-PQL-K': nan,
#  'THR-WA1-LD-79-24': 'synthetic web sling',
#  'THR-PLT-LD-2142D': nan,
#  'TAB-DIS-FSL-2201': 'flow switch',
#  'WTR-RDF-DR-0007': 'door',
#  'TAB-ACC-RPU-6540': 'RPU panel',
#  'THC-MCS-CRN-6004': 'hoist',
#  'FHA ADMIN': 'defined collection of assets',
#  'THR-SES-SQ-15P': 'eyewash bottle',
#  'FHO ADMIN': 'defined collection of assets',
#  'THC-ACC-PDIT-6302': 'pressure transmitter',
#  'THR-THK-T-8201': 'chemical storage tank',
#  'VP2026': 'portable gas detector',
#  'THC-ITS-TEL-6010': 'landline telephone',
#  'THC-ACC-RPU-1901': 'RPU panel',
#  'TAB-WA2-SQ-3402': 'self-retracting lifeline',
#  'THC-SPC-COM-1802': 'network termination panel',
#  'THC-GRK-DR-P': 'door',
#  'THR-DIS-CHL-1221': nan,
#  'THR-SES-SQ-5706S': nan,
#  'THC-DCL-LSL-0401': nan,
#  'THR-ACC-NR-671': 'space heater',
#  'TAB-WA4-SQ-1220': 'synthetic web sling',
#  'TAB-DIG-FX-7062': 'flame arrester',
#  'FCL-SES-EYE-0009': 'eyewash bottle',
#  'THR-SES-PGM-75171': nan,
#  'THC-ACC-HTR-0327': 'space heater',
#  'THR-PRM-FSL-3223': 'flow switch',
#  'THC-ACC-TSH-0412': 'temperature switch',
#  'TAB-WA1-SQ-7200': 'pump',
#  'TAB-DIS-F-3502': 'discrete unit of treatment filter',
#  'TAB-ELS-SQ-6166': 'insulated glove',
#  'COL-MTI-T-2000': 'chemical storage tank',
#  'FIS ADMIN': 'defined collection of assets',
#  'TAB-SLO-SQ-0091': 'first aid kit',
#  'TAB-PRM-FSL-2701': 'flow switch',
#  'THR-WA1-LD-90-13': 'synthetic web sling',
#  'THR-OCS-T-0510B': 'chemical storage tank',
#  'THR-PLT-HS-1242': 'manual switch',
#  'TAB-OCS-DM-6631': 'damper',
#  'FHO-SES-SCBA-0029': 'portable compressed gas cylinder',
#  'FHO-GRK-DR-2045S': 'fire rated door',
#  'THR-DIG-PSH-0202': 'pressure switch',
#  'TAB-DIS-PSH-0013': 'pressure switch',
#  'TAB-ACC-TIC-1283': 'thermostat or zone controller unit',
#  'COL-MTI-OIT-2400': 'HMI',
#  'IU2029A': 'pressure vessel',
#  'THR-ACC-PSH-1603': 'pressure switch',
#  'COL-YKP-SRL-002652': 'self-retracting lifeline',
#  'FHA-SES-LDR-0114': 'ladder',
#  'THR-DIG-T-5411': 'air scrubber',
#  'FHA-SES-SQ-0079': 'fall protection system support struture',
#  'WTR-PSC-T-0003-SUS': nan,
#  'TAB-DIG-LSH-1621': 'level switch',
#  'THC-ACC-HTR-6018': 'space heater',
#  'THR-DIG-PSH-2264': 'pressure switch',
#  'THC-ACC-HTR-0015': 'space heater',
#  'TAB-WA5-LDR-6258': 'portable ladder',
#  'FHA-SES-SQ-0052': 'fall arrest harness',
#  'FHA-CLB-CHL-0201': 'chlorinator',
#  'TNT-GAS': 'defined collection of assets',
#  'THR-ELS-MCC-0401S': nan,
#  'FCL-FL-FSL-0101-SUS': nan,
#  'TAB-PRM-FSL-3602?': nan,
#  'TAB-DIS-PSL-0002': 'pressure switch',
#  'THR-WA4-LD-0028': 'synthetic web sling',
#  'TNT-PRM-T-0400': 'clarifier',
#  'TAB-ACC-TSH-1900': 'temperature switch',
#  'THC-ACC-AC-0055': 'air condition',
#  'TAB-DIS-SQ-0010': nan,
#  'TAB-PWA-STR-2001': 'strainer',
#  'FHA-SES-SQ-0045': 'fall arrest harness',
#  'THC-ACC-HTR-0270': 'space heater',
#  'DOS-YCM-FAK-VEH270008': 'first aid kit',
#  'TAB-ACC-RPU-0100': 'RPU panel',
#  'TAB-STR-PSL-4001': 'pressure switch',
#  'FHA-SED-ZSH-0504C': 'limit switch',
#  'TAB-SES-RING-3008': 'personal floatation device',
#  'TAB-ACC-T-6151': 'chemical storage tank',
#  'TAB-PRM-LSL-0211': 'level switch',
#  'THC-ELS-SQ-6180466': 'insulated glove',
#  'THC-ACC-DM-0085': 'damper',
#  'TAB-STR-SQ-0010': nan,
#  'THC-ACC-DM-6521': 'damper',
#  'FHO-ELS-MCC-0930': '600V electrical panel',
#  'THR-CW-T-0001': 'hot water heater',
#  'THC-THK-T-5080': 'storage tank',
#  'FHA-AM-DM-6810': 'damper',
#  'TAB-ACC-FSL-5412': 'flow switch',
#  'FHA-SES-LDR-0512': 'ladder',
#  'TAB-ELS-LTX-1070': 'emergency light',
#  'THR-SES-PGM-41056': nan,
#  'THR-MCS-LD-9866': 'fall protection system support struture',
#  'TAB-WA1-SQ-2038': 'spill kit',
#  'TAB-ACC-TSL-6102': 'temperature switch',
#  'COL-YKP-FAK-189018': 'first aid kit',
#  'THR-SS-WA3': 'security system',
#  'THR-OCS-FSL-2225': 'flow switch',
#  'DA0147A': 'air handler unit',
#  'COL-YKP-FAK-0025S': nan,
#  'WTR-PLW-PPE-0102-SUS': nan,
#  'COL-PSW-LSH-0203': 'level switch',
#  'THC-OCS-RPU-3013': 'RPU panel',
#  'THC-ACC-TIT-6503': 'temperature transmitter',
#  'FHA-SES-SCBA-0005': 'SCBA system',
#  'FHO-TRW-LSL-0001': 'level switch',
#  'THR-FT-PSH-4065S': nan,
#  'TAB-PLT-PLQ-D': 'piping system',
#  'FHO-SPC-COM-0200': 'network panel',
#  'THC-ACC-HTR-6002': 'space heater',
#  'THC-SES-MEQ-1103': 'fall protection system component (MBC)',
#  'TAB-PWA-LS-5146': 'level switch',
#  'FHO-GRK-DR-5007S': 'fire rated door',
#  'FCL-ELS-TSH-02CL': 'temperature switch',
#  'THC-DEW-RPU-2102': 'RPU panel',
#  'THR-ELS-PDP-3222C': '600V electrical panel',
#  'TAB-EL1-MCC-6626A': nan,
#  'FHO-ACC-F-0902': 'replaceable air filter',
#  'IH311': nan,
#  'THR-ELS-MCC-0301': '600V electrical panel',
#  'TAB-ACC-TE-1449B': 'temperature sensor element',
#  'TAB-NGS-PSH-0301': 'pressure switch',
#  'FCL-ELS-TSH-002F': 'temperature switch',
#  'THC-ACC-V-6215': 'valve',
#  'FHO-AM-FS-0202': 'flow switch',
#  'FHO-SPC-RPU-2022': 'RPU panel',
#  'FHO-GRK-DR-2036L': 'fire rated door',
#  'TAB-DIG-LSL-6701': 'level switch',
#  'THC-PRM-T-1010': 'chemical storage tank',
#  'TAB-ACC-HE-1447': 'heat exchanger',
#  'KR2252A': 'space heater',
#  'SWM-PBL-LSL-0102': 'level switch',
#  'TAB-DIG-PSH-1472': 'pressure switch',
#  'TAB-DIG-PSL-4220G': 'pressure switch',
#  '                    50640': 'portable gas detector',
#  'THC-INC-BU-1034': 'burner',
#  'THR-SES-SQ-0902': 'fall arrest harness',
#  'THR-PLT-FSL-1803': 'flow switch',
#  'TAB-DEW-SB-3966': 'discrete unit of treatment filter',
#  'FCL-PAC-F-0201': 'replaceable air filter',
#  'FHO-RW-FSL-0005': 'flow switch',
#  'TAB-ACC-AHU-1409': nan,
#  'THR-ACC-NR-785': 'space heater',
#  'FHO-SES-SQ-0005': 'fall arrest system',
#  'THR-ACC-NR-677': 'space heater',
#  'FIS-SES-FAK-1601': 'first aid kit',
#  'FCL-CLB-PSH-0102': 'pressure switch',
#  'THR-GRK-VEH-378038': nan,
#  'THR-SES-SCBA-0506': 'SCBA system',
#  'THC-ELS-PDP-4041': '600V electrical panel',
#  'KR2204A': 'space heater',
#  'WTR-RRH-ZS-0003': 'position switch',
#  'THC-FT-T-0500': 'clarifier',
#  'FHA-ACC-AHU-6801': 'air handler unit',
#  'THC-MCS-LD-0000000003': 'lifting device sling',
#  'FIS-SES-LDR-5004': 'ladder',
#  'THC-MCS-LD-0000000004': 'lifting device sling',
#  'THC-PRM-ZSH-1114': 'position switch',
#  'TAB-PLT-FSL-0401': 'flow switch',
#  'FCL-ELS-PSH-0101': 'pressure switch',
#  'TAB-SPC-COM-3602': 'network termination panel',
#  'TNT-MCS-LD-0022': 'hoist',
#  'THR-GRK-DR-3803': 'door',
#  'WTR-PKN-PS-0002': 'pressure switch',
#  'THR-WA1-LD-95-12': 'synthetic web sling',
#  'THR-DIS-DP-0200': '600V electrical panel',
#  'DOS-YCM-VEH-323089': 'construction or earthmoving machine (MBC)',
#  'THR-WA2-LD-0004S': nan,
#  'FHO-SES-SQ-CIT18B': 'cable segment',
#  'WTR-PSC-FAR-0003S': nan,
#  'FIS-ACC-FN-4004': 'fan',
#  'FHA-SES-LDR-0107': 'ladder',
#  'SWM-PBL-SW-0002': 'power disconnect switch',
#  'DOS-SES-SCBA-2362': 'SCBA system',
#  'COL-PMM-LSH-0001': 'level switch',
#  'THC-MCS-LD-CK4448XG': 'crane',
#  '                    20666': 'PA system',
#  'WTR ADMIN': 'defined collection of assets',
#  'FCL-SH-13': 'fall arrest harness',
#  'FIS-SES-FSH-1011': 'flow switch',
#  'THR-CG-LSH-1250': 'level switch',
#  'TAB-ACC-V-1455': 'valve',
#  'THC-ACC-V-6010': 'valve',
#  'COL-MTI-F-3401': 'replaceable oil or fuel filter',
#  'THC-DIG-PD-0500': 'digester tank',
#  'THC-PRM-T-1000': 'clarifier',
#  'TAB-ACC-DM-6547': 'damper',
#  'THR-AER-LSL-1401': 'level switch',
#  'FIS-TPA-CP-4001': 'PA system',
#  'TAB-EL1-PDP-6121A': '600V electrical panel',
#  'COL-YKP-DA-150108': 'fall protection system component (MBC)',
#  'TAB-PRS-VEH-1030SUS': nan,
#  'FHO-ELS-LP-0931': '120V/240V electrical panel',
#  'THR-PRS-PSH-0355S': nan,
#  'COL-PMM-D-0100': 'dehumidifier',
#  'THR-PRM-T-3555': 'expansion tank',
#  'FIS-SES-SQ-1019': 'hot stick',
#  'COL-PCF-FN-0200': 'fan',
#  'THR-DIS-T-1350': 'chemical storage tank',
#  'THC-SPC-COM-2304': 'network termination panel',
#  'THR-CW-T-0204': 'hot water heater',
#  'TAB-PRM-PSL-2501?': nan,
#  'TAB-ACC-HE-1455': 'heat exchanger',
#  'THR-ACC-NU-561': 'space heater',
#  'WTR-RDF-ZS-0007': 'position switch',
#  'THR-FT-PSL-4602': 'pressure switch',
#  'THC-MCS-LD-0000000005': 'lifting device sling',
#  'TAB-ACC-LS-0790': 'level switch',
#  'TAB-ACC-PSL-0742': 'pressure switch',
#  'TAB-DEW-RPU-1137': 'RPU panel',
#  'THR-ACC-TSH-0150': 'temperature switch',
#  'THR-SAFT-LSHH': 'level switch',
#  'TAB-RSP-PS-2207D': 'hydraulic power pack',
#  'THC-DIG-PSH-5067': 'pressure switch',
#  'TAB-ACC-DM-6486': 'damper',
#  'FHO-ACC-FS-0106': 'flow switch',
#  'FCL-CLB-PSL-0101': 'pressure switch',
#  'THC-ACC-HTR-0906': 'space heater',
#  'TAB-WA1-SQ-1948': 'self-retracting lifeline',
#  'THC-ACC-HTR-0310': 'space heater',
#  'FCL-ELS-DS-B1B2-A': 'load break disconnect switch',
#  'TAB-ACC-PSL-4901': 'pressure switch',
#  'FHO-GRK-DR-2005L': 'fire rated door',
#  'YTF-SS-UPS-1000': 'security system',
#  'TAB-PRM-FSL-6506': nan,
#  'THR-GRK-ZP-712': 'forklift',
#  'THR-ACC-AC-0750A': 'air condition',
#  'THC-MCS-LD-0000000001': 'lifting device sling',
#  'COL-PNT-PSL-0121': 'pressure switch',
#  'TAB-ACC-DM-6515': 'damper',
#  'COL-PBG-SW-0003': 'power disconnect switch',
#  'THC-MCS-T-0005': 'hot water heater',
#  'DOS-MCS-LD-066916': 'lifting device sling',
#  'THR-DIG-TSH-5860A': 'temperature switch',
#  'TAB-ELS-SQ-6173': 'insulated glove',
#  'SWM-PMG-TSL-0002': 'temperature switch',
#  'WZ2008A': 'pressure vessel',
#  'TAB-ACC-T-6219': 'condensate trap',
#  'THR-SES-SCBA-0508': 'SCBA system',
#  'COL-YKP-FAK-0019': 'first aid kit',
#  'TAB-WA1-LD-1254': 'lifting device or lifting device component (MBC)',
#  'THR-ELS-MCC-3602': '600V electrical panel',
#  'TAB-PWA-F-1001': 'air filter unit',
#  'FHO-ELS-MCC-0731': '600V electrical panel',
#  'COL-YKP-DA-0021S': nan,
#  'TAB-ACC-AHU-8300': 'air handler unit',
#  'THR-AER-RPU-0021': 'RPU panel',
#  'FHA-SED-ZSH-0501B': 'limit switch',
#  'FHA-SPC-RPU-1624': 'RPU panel',
#  'THR-DIS-CP-0009': 'process control panel',
#  'TAB-DEW-PSH-3330': 'pressure switch',
#  'TAB-DIG-CP-7103': 'process control panel',
#  'COL-PWN-LSH-0002': 'level switch',
#  'THR-DIS-CP-0007': 'process control panel',
#  'THC-PRM-LSHH-0174': 'level switch',
#  'TAB-ACC-FSL-4612': 'flow switch',
#  'FHA-SES-SQ-1105': 'fall protection system component (MBC)',
#  'COL-PAB-LSHH-0104': 'level switch',
#  'THC-SES-MEQ-H359276': 'fall arrest harness',
#  'THR-PLT-FSL-2501': 'flow switch',
#  'TAB-SES-SQ-2203': 'emergency eyewash and shower',
#  '378177SUS': nan,
#  'TAB-RSP-RPU-0206': 'RPU panel',
#  'TAB-PAB-RPU-0221': 'RPU panel',
#  'FIS-ACC-HTR-3004': 'space heater',
#  'THR-SES-LD-9591': 'winch',
#  'THR-ELS-SQ-0900': 'insulated glove',
#  'FHO-SPC-COM-1301': 'network termination panel',
#  'FHO-CLB-INJ-0101': 'injector, ejector, or eductor',
#  'THR-GQ-WA2': 'space',
#  'THR-DIG-SSH-5175A': 'speed switch',
#  'TAB-SA-RPU-0732': 'RPU panel',
#  'WTR-PLW-PPE-0103-SUS': nan,
#  'TAB-WA7-LD-1203': 'synthetic web sling',
#  'TAB-DEW-TSH-0521A': 'temperature switch',
#  'THC-ACC-TIT-6304': 'temperature transmitter',
#  'COL-PMM-T-0001': 'hot water heater',
#  'THR-PLQ-ADM': 'defined collection of assets',
#  'FIS-SES-SQ-5001': 'emergency eyewash',
#  'THR-SES-SPL-0101': 'spill kit',
#  'THR-GRK-VEH-396040S': nan,
#  'TAB-INC-LSHH-8046': 'level switch',
#  'THR-DIG-PSH-2369': 'pressure switch',
#  'THC-ELS-LTG-EXIT': nan,
#  'FHA-AUX-ANL-0018': 'pressure calibrator',
#  'TAB-PRM-T-4600': 'storage tank',
#  'THR-FT-T-2100': 'sedimentation tank',
#  'TAB-EL1-MCC-6961': '600V electrical panel',
#  'THC-PRM-T-0500': 'clarifier',
#  'SWM-PMG-LSH-0105': 'level switch',
#  'THC-ACC-AHU-0268': 'air handler unit',
#  'TAB-EL1-MCC-6592': nan,
#  'THR-DIG-PD-0100': 'digester tank',
#  'TAB-SLO-STR-2404': 'strainer',
#  'THR-GQ-WA3': 'space',
#  'THR-ELS-INQ-9179': 'lab equipment (MBC)',
#  'THR-FPW-T-0004S': nan,
#  'WTR-RDF-ZS-0409': 'position switch',
#  'COL-PWN-RPU-0001': 'RPU panel',
#  'THR-AER-RPU-0001': 'RPU panel',
#  'THC-THK-T-5070': 'storage tank',
#  'WTR-PEG-SQ-0001': nan,
#  'THR-DR-DIS-0516': 'roll up door',
#  'THR-DRN-ADM': 'defined collection of assets',
#  'FHA-ELS-WR-0212': 'wielding receptacle',
#  'WTR-RWL-TSL-0001': 'temperature switch',
#  'THC-PRM-ZSH-0974': 'position switch',
#  'FHO-MCS-PSL-0301': 'pressure switch',
#  'FHO-SES-SQ-6018-SU': nan,
#  'THC-ACC-PIT-0013': 'pressure transmitter',
#  'THR-SQ-FAK-RSPS': 'first aid kit',
#  'THC-PLT-G-0260': 'gate',
#  'THC-PRM-V-1272': 'hydraulic power pack',
#  'THR-PRS-TSL-0172S': nan,
#  'THR-GQ-ADM': 'defined collection of assets',
#  'FHA-FLT-F-1501': 'filtration tank',
#  'TAB-WA1-LD-1230': 'hoist',
#  'FHO-SES-SQ-8014': 'safety or hazard management equipment (MBC)',
#  'THC-ACC-HTR-0354': 'space heater',
#  'YCM-BLD-FAK-0001': 'first aid kit',
#  'FCL-ACC-ADMIN': 'defined collection of assets',
#  'THR-SES-SQ-1007': 'fall arrest harness',
#  'COL-PWR-LSL-0202': 'level switch',
#  'THC-SES-AIDKIT-0001': 'first aid kit',
#  'FHA-SES-SQ-0060': 'fall arrest harness',
#  'FHO-SPC-COM-1201': 'network panel',
#  'THC-ACC-V-6043': 'valve',
#  'THC-ACC-BLDG K': 'defined collection of assets',
#  'TAB-WA1-SQ-1974': 'fall arrest lanyard',
#  'THC-DCL-LSH-0401': 'level switch',
#  'TAB-EL2-MCC-6324A': '600V electrical panel',
#  'TAB-ACC-AHU-1837': 'air handler unit',
#  'FIS-RW-LSH-0001': 'level switch',
#  'FHA-SES-SQ-0042': 'fall arrest harness',
#  'TAB-ACC-FSL-2010': 'flow switch',
#  'FHO-BW-FSL-1601': 'flow switch',
#  'FHO-DEW-LS-2401': 'level switch',
#  'THR-ACC-NR-653': 'space heater',
#  'TNT-MCS-LD-0025': 'hoist',
#  'TAB-WA2-SQ-1223': 'synthetic web sling',
#  'THC-FEQ-DM-0013': nan,
#  'TAB-DIG-LSHH-8084A': 'level switch',
#  'THR-ELS-PDP-2602': '600V electrical panel',
#  'FHO-LAB-TPD-0001': 'trap priming device',
#  'TAB-OCS-HTR-6705': 'process controller',
#  'TAB-ACC-TE-1437A': 'temperature sensor element',
#  'THR-ACC-AC-0750B': 'air condition',
#  'MS0120A': 'machine tool (MBC)',
#  'TNT-ELS-SQ-4001': 'storage cabinet',
#  'COL-PSW-PSL-0121': 'pressure switch',
#  'FHO-TRW-PSL-0002': 'pressure switch',
#  'THC-PRM-ZSH-1179': 'position switch',
#  'TAB-ACC-FSL-4011': 'flow switch',
#  'WTR-PSA-PSL-0001': 'pressure switch',
#  'TAB-ACC-HTR-6431': 'space heater',
#  'NX6106A': 'air condition',
#  'FHO-ACC-FS-1632': 'flow switch',
#  'COL-YKP-VEH-080119': 'pickup truck',
#  'FIS-ELS-PS-2102': 'pressure switch',
#  'TAB-ACC-DM-6483': 'damper',
#  'THR-WA2-LD-0015': 'synthetic web sling',
#  'TAB-ACC-TSL-3918': 'temperature switch',
#  'THC-PLT-ZSH-0820': 'position switch',
#  'TAB-ACC-DM-1450': 'damper',
#  'TAB-ACC-TE-1483B': 'temperature sensor element',
#  'THC-ACC-DM-6308': 'damper',
#  'THC-ACC-PSL-3343': 'pressure switch',
#  'THC-ITS-PA-3610': 'PA system',
#  'TAB-WA2-SQ-3403': 'self-retracting lifeline',
#  'THR-WA4-LD-0012': 'synthetic web sling',
#  'TAB-RSP-DRN-M': 'drain',
#  'COL-PQW-LSH-0103': 'level switch',
#  'TAB-STR-F-4002R': 'replaceable oil or fuel filter',
#  'THR-ACC-AC-0790': 'air condition',
#  'TAB-PLT-G-0303': 'gate',
#  'TAB-ACC-RPU-6550': 'RPU panel',
#  'FHO-SES-SQ-6022': 'defined collection of assets',
#  'FCL-AM-T-0301': 'chemical storage tank',
#  'FIS-ACC-DM-4008': 'damper',
#  'THR-SES-T-0505': 'portable compressed gas cylinder',
#  'FHO-DOZ-T-3300-SUS': nan,
#  'THR-AER': 'defined collection of assets',
#  'TAB-AER-ELQ': 'defined collection of assets',
#  'WTR-PJS-PSL-0005': 'pressure switch',
#  'TAB-PRM-PLQ-OPS': 'piping system',
#  'FIS-MCS-MT-4502-SUS': nan,
#  'WTR-PLW-PPE-0101-SUS': nan,
#  'WTR-PKN-VSH-0201': 'vibration sensor element',
#  'THR-ACC-PSL-1702': 'pressure switch',
#  'THR-WA2-LD-0037': 'synthetic web sling',
#  'TAB-WA1-LD-1214': 'hoist',
#  'FHO-GRK-DR-2095S': 'fire rated door',
#  'THR-BG-F-0603': 'replaceable air filter',
#  'THC-SES-MEQ-Q19092319': 'fall arrest lanyard',
#  'THR-ACC-TS-0750': 'temperature switch',
#  'THR-ACC-DM-0230': 'damper',
#  'THC-ACC-FN-0581': 'fan',
#  'THC-PLT-ZHS-0810': 'position switch',
#  'TAB-PLT-G-4204': 'valve',
#  'THR-DIG-PSH-4761': 'pressure switch',
#  'TAB-ACC-ASH-3681': 'flame sensor',
#  'TAB-ACC-TSL-1847': 'temperature switch',
#  'TAB-GRK-VEH-329060': 'forklift',
#  'WTR-PSC-HRN-0009': 'fall arrest harness',
#  'FCL-ACC-FS-0204': 'flow switch',
#  'THR-MCS-LD-0512B': 'hoist',
#  'THR-MCS-LD-9853': 'hoist',
#  'TAB-AER-INQ': 'defined collection of assets',
#  'TAB-WA6-SQ-2389': 'fall arrest harness',
#  'THC-THK-RPU-1604': 'RPU panel',
#  'THC-PRM-ZSH-1251': 'position switch',
#  'THC-OCS-F-6300': 'filtration tank',
#  'THR-PLT-RPU-0002': 'RPU panel',
#  'THR-SPC-RPU-0003B': 'RPU panel',
#  'FHO-ELS-DP-1021': '600V electrical panel',
#  'FIS-SES-SQ-4501': 'emergency eyewash',
#  'TAB-STR-PSH-4004': 'pressure switch',
#  'THR-ACC-FSL-0849': 'flow switch',
#  'WTR-PJS-LSH-0068': 'level switch',
#  'TAB-DIG-T-7601': 'condensate trap',
#  'TAB-PWA-F-0429': 'air filter unit',
#  'THR-AER-BL': 'defined collection of assets',
#  'TAB-SES-LTX-2281': 'emergency light',
#  'FHO-SPC-COM-1401': 'network termination panel',
#  'THR-ELS-TS-2922': 'transfer switch',
#  'THR-ACC-HE-4000': 'hot water heater',
#  'THC-ACC-T-0577': 'hot water heater',
#  'TAB-ACC-AC-1304': 'air condition',
#  'FCL-ACC-AHU-0904': 'air handler unit',
#  'THC-NGS-PSL-3062': nan,
#  'THR-ELS-LSL-0100': 'level switch',
#  'FHA-SPC-RPU-1821': 'RPU panel',
#  'THC-ITS-PA-3640': 'PA system',
#  'WTR-PPD-T-2101': 'hot water heater',
#  'THR-ACC-DM-0243': 'damper',
#  'THC-AER-TSH-7442': 'temperature switch',
#  'THC - A01 - S191': 'door',
#  'THC-MCS-MT-0010': 'lathe',
#  'FIS-FEQ-DM-4001': 'damper',
#  'THR-FT-PSL-2324': 'pressure switch',
#  'THR-SS-DR1': 'roll up door',
#  'THC-ACC-T-0005': 'expansion tank',
#  'THR-SES-LD-6476': 'winch',
#  'TAB-ACC-HTR-1438': 'space heater',
#  'TAB-AER': 'defined collection of assets',
#  'FIS-ACC-CP-4000': 'process control panel',
#  'TAB-RSP-PSL-1241': 'pressure switch',
#  'FHO-GRK-DR-2030S': 'fire rated door',
#  'THR-ACC-FSL-0012': 'flow switch',
#  'THR-FT-LSHH-2655': 'level switch',
#  'TAB-PLT-T-1201': nan,
#  'COL-PRG-TS-0001': 'transfer switch',
#  'TAB-PRM-T-2600': 'storage tank',
#  'FHA-WWW-T-4011': 'sedimentation tank',
#  'FIS-MCS-MEQ-3006': 'fall protection system component (MBC)',
#  'TAB-WA1-LD-1252': 'lifting device or lifting device component (MBC)',
#  'FCL-ACC-AHU-0907': 'air handler unit',
#  'FCL-ACC-RPU-0101': 'RPU panel',
#  'THR-FT-LSHH-4820': 'level switch',
#  'THC-ITS-PA-3910': 'PA system',
#  'TAB-ACC-TSL-0950': 'temperature switch',
#  'COL-YKP-DA-0014(S)': nan,
#  'TNT-ELS-TS-6104B': 'transfer switch',
#  'FHO-GRK-DR-2013L': 'fire rated door',
#  'TAB-AER-T-0900': 'aeration tank',
#  'FCL-CW-T-0002': 'hot water heater',
#  'FCL-ELS-TSH-001D': 'temperature switch',
#  'COL-PCU-TSH-0101': 'temperature switch',
#  'THR-BG-PSL-1101': 'pressure switch',
#  'TAB-WA4-SQ-8774': 'fall arrest lanyard',
#  'THR-ELS-PDP-0701': '600V electrical panel',
#  'TAB-STR-PSLL-4009': 'pressure switch',
#  'TAB-RSP-F-4005': 'replaceable air filter',
#  'THR-FT-PSL-2521S': nan,
#  'TAB-PRM-PSL-3602': 'pressure switch',
#  'COL-YKP-VEH-0023S': nan,
#  'WTR-PKL-LSL-0600': 'level switch',
#  'TAB-ACC-DM-6563': 'damper',
#  'TAB-ACC-TE-1436A': 'temperature sensor element',
#  'TAB-WA1-LD-1253': 'lifting device or lifting device component (MBC)',
#  'THR-ACC-FSL-0750': 'flow switch',
#  'THC-AER-T-2900': 'aeration tank',
#  'TAB-ACC-TE-1404A': 'temperature sensor element',
#  'FHO-SES-DEF-0001': 'automatic external defibrillator',
#  'TAB-CW-SQ-0003S': nan,
#  'TAB-STR-ZSH-1201': 'position switch',
#  'FHO-ELS-DP-0313-SUS': nan,
#  'TAB-WA6-SQ-5472': 'fall arrest harness',
#  'THR-DIG-SSH-5128A': 'speed switch',
#  'COL-PSW-LSH-0108': nan,
#  'FHA-SES-SQ-0081': 'fall protection system support struture',
#  'TAB-RSP-T-1211': 'chemical storage tank',
#  'DRN18473': 'drain',
#  'TAB-HRS-LS-8044': 'level switch',
#  'THR-ACC-TSL-0240': 'temperature switch',
#  'THR-ELS-SQ-0052': 'HV insulated blanket',
#  'FIS-MCS-MT-4507': 'machine tool (MBC)',
#  'THC-SES-MEQ-0602': 'fall protection system component (MBC)',
#  'TAB-STR-ZSL-0210': 'position switch',
#  'THC-DIG-FX-0600C': 'flame arrester',
#  'THR-PLT-LD-2152D': nan,
#  'THR-MCS-LD-0603': 'winch',
#  'TAB-ACC-PDSH-1461': 'pressure switch',
#  'THR-SES-PGM-17428': 'portable gas detector',
#  'FCL-ACC-FS-0409': 'flow switch',
#  'THR-ELS-SQ-0897': 'insulated glove',
#  'THR-FT-PSH-4066S': nan,
#  'COL-PCU-LTG-0001S': nan,
#  'COL-YKP-DA': 'fall protection system support struture',
#  'JH2006A': 'roll up door',
#  'THR-ACC-AC-4000': 'air condition',
#  'TAB-ACC-ACC-6101': 'air condition',
#  'THR-SS-WA2': 'security system',
#  'THC-OCS-RPU-1802': 'RPU panel',
#  'FIS-WWW-T-0901': 'sedimentation tank',
#  'FIS-SES-SCBA-3502': 'SCBA system',
#  'THR-DIS-DP-0100': '600V electrical panel',
#  'THC-DIG-FX-0700C': 'flame arrester',
#  'FHO-SES-SQ-7003': 'emergency eyewash and shower',
#  ...}

# %% [markdown]
# ## Applying the Mapping
# The mapping will now be applied, starting with the lest likely to be accurate to the most likely to be accurate

# %%
df['Valid_Class'] = None

df['Valid_Class'] = df['Category'].map(dict_supercategory).fillna(df['Valid_Class'])
print(f"After mapping Supercategory, {df['Valid_Class'].notna().sum()/df.shape[0]:.1%} mapped")
df['Valid_Class'] = df['Category'].map(dict_category).fillna(df['Valid_Class'])
print(f"After mapping Category, {df['Valid_Class'].notna().sum()/df.shape[0]:.1%} mapped, {df['Category'].map(dict_category).notna().sum()/df.shape[0]:.1%} changed")

df['Valid_Class'] = df['Extracted_Code'].map(dict_supertag).fillna(df['Valid_Class'])
print(f"After mapping Supertag, {df['Valid_Class'].notna().sum()/df.shape[0]:.1%} mapped, {df['Extracted_Code'].map(dict_supertag).notna().sum()/df.shape[0]:.1%} changed")
df['Valid_Class'] = df['Extracted_Code'].map(dict_tag).fillna(df['Valid_Class'])
print(f"After mapping Tag, {df['Valid_Class'].notna().sum()/df.shape[0]:.1%} mapped, {df['Extracted_Code'].map(dict_tag).notna().sum()/df.shape[0]:.1%} changed")

df['Valid_Class'] = df['Class'].map(dict_superclass).fillna(df['Valid_Class'])
print(f"After mapping SuperClass, {df['Valid_Class'].notna().sum()/df.shape[0]:.1%} mapped, {df['Class'].map(dict_superclass).notna().sum()/df.shape[0]:.1%} changed")
df['Valid_Class'] = df['Class'].map(dict_class).fillna(df['Valid_Class'])
print(f"After mapping Class, {df['Valid_Class'].notna().sum()/df.shape[0]:.1%} mapped, {df['Class'].map(dict_class).notna().sum()/df.shape[0]:.1%} changed")
df['Valid_Class'] = df['Entity_number'].map(dict_manual).fillna(df['Valid_Class'])

print(f"After mapping Manual Mapping, {df['Valid_Class'].notna().sum()/df.shape[0]:.1%} mapped, {df['Entity_number'].map(dict_manual).notna().sum()/df.shape[0]:.1%} changed")

df
# Out:
# After mapping Supercategory, 58.1% mapped
# After mapping Category, 89.0% mapped, 57.0% changed
# After mapping Supertag, 91.3% mapped, 31.0% changed
# After mapping Tag, 98.1% mapped, 81.9% changed
# After mapping SuperClass, 98.2% mapped, 8.8% changed
# After mapping Class, 99.0% mapped, 83.6% changed
# After mapping Manual Mapping, 100.0% mapped, 27.6% changed
#              Entity_number                                        Description  \
# 0       \tFCL_ELS_CBL_001L  Electrical Power Line,4.16KV,From BUS-00B1-A t...
# 1       \tFCL_ELS_CBL_002D  Electrical Power Line,4.16KV,From BUS-00B2-A t...
# 2       \tFCL_ELS_CBL_002F  Electrical Power Line,4.16KV,From BUS-00B2 to ...
# 3       \tFCL_ELS_CBL_002H  Electrical Power Line,4.16KV,From BUS-00B1 to ...
# 4       \tFCL_ELS_CBL_002L  Electrical Power Line,4.16KV,From BUS-00B2-A t...
# ...                    ...                                                ...
# 126013          YTF-VSTORE                          Computer Storage Location
# 126014             YX2411A                Pump, Unwatering, Primary Tanks 1-2
# 126015          ZB20-CA-31            Damper,Combustion Air, Steam Boiler #20
# 126016       ZXDATA-PILOT1      DO NOT USE - City of Toronto Pump, RW Pump 18
# 126017      ZXDP VALVE COL                 DO NOT USE - Toronto Water DP Pump
#
#                       Parent  \
# 0       FCL_ELS_4.16KV_LINES
# 1       FCL_ELS_4.16KV_LINES
# 2       FCL_ELS_4.16KV_LINES
# 3       FCL_ELS_4.16KV_LINES
# 4       FCL_ELS_4.16KV_LINES
# ...                      ...
# 126013               YTF EUS
# 126014        TAB-PRM-P-SUMP
# 126015       TAB-ACC-BO-0500
# 126016                  None
# 126017                  None
#
#                                        Parent_Description  \
# 0                            Electrical Power Line,4.16KV
# 1                            Electrical Power Line,4.16KV
# 2                            Electrical Power Line,4.16KV
# 3                            Electrical Power Line,4.16KV
# 4                            Electrical Power Line,4.16KV
# ...                                                   ...
# 126013                     Production & End User  Support
# 126014  P Bldg & Old PS Buildings, Primary Treatment S...
# 126015                                Boiler #20, Volcano
# 126016                                               None
# 126017                                               None
#
#                              Category                  Class Suspended  \
# 0                   Air Handling Unit  Electrical Power Line      None
# 1                   Air Handling Unit  Electrical Power Line      None
# 2                   Air Handling Unit  Electrical Power Line      None
# 3                   Air Handling Unit  Electrical Power Line      None
# 4                   Air Handling Unit  Electrical Power Line      None
# ...                               ...                    ...       ...
# 126013                           None                   None      None
# 126014  Pump,Centrifugal,single-Stage                   Pump      None
# 126015                  Damper/Louver          Damper/Louver      None
# 126016               Pump,Centrifugal                   Pump      None
# 126017                           None                   None      None
#
#        Extracted_Code Matched_Code                   Valid_Class
# 0                None         None                 cable segment
# 1                None         None                 cable segment
# 2                None         None                 cable segment
# 3                None         None                 cable segment
# 4                None         None                 cable segment
# ...               ...          ...                           ...
# 126013           None         None  defined collection of assets
# 126014           None         None                          pump
# 126015           None         None                        damper
# 126016           None         None          water-glycol mixture
# 126017           None         None          water-glycol mixture
#
# [126018 rows x 10 columns]
