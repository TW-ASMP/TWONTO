# %% [markdown]
# # Avnatis Mapping Instructions
#
# The following describes the process for mapping the current Avantis Classes to the new Classification system.
#
# ## Load SPARQL data
#
# The first step is to run SPARQL queires in protege to get the revelent metadata from the new classes. The SPARQL queires should look for classes with the specific annotation propertys:
# 1. is_equivalent_to_Avantis_class
# 2. is_equivalent_to_Avantis_category
# 3. is_equivalent_to_tag_code
# 4. is_superclass_of_Avantis_class
# 5. is_superclass_of_Avantis_category
# 6. is_superclass_of_tag_code
# The following code can be modified to acomplish this task.
#
# ```sparql
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
# PREFIX tw: <http://www.toronto.ca/TWONTO#>
#
# SELECT ?SPARQL (STR(?object) as ?Avantis)
# 	WHERE { ?SPARQL tw:is_equivalent_to_Avantis_class ?object }
# ```
# Once the SPARQL queires are saved, they are open in python pandas dataframes. This is done with the following code:

# %%
import pandas as pd

df = pd.read_excel("SPARQL_class.xlsx", header= 1)
Class = dict(zip(df['Avantis_Class'],df['TWONTO']))
df
# Out:
#                                         TWONTO             Avantis_Class
# 0                                 channel_gate                      Gate
# 1    instrument_air_or_pneumatic_control_panel            Air Instrument
# 2                     UV_disinfection_assembly  Ultraviolet Disinfection
# 3                                    clarifier                 Clarifier
# 4                       controlled_door_access                      Door
# ..                                         ...                       ...
# 96                                     chiller                   Chiller
# 97                            hydraulic_system          Hydraulic System
# 98                             filtration_tank                 Biofilter
# 99                load_break_disconnect_switch         Load Break Switch
# 100                              cooling_tower             Cooling Tower
#
# [101 rows x 2 columns]

# %% [markdown]
# There is an additonal step were the two column are saved as a dictionary. A python dictionary is a simple key value pair.

# %%
df = pd.read_excel("SPARQL_superclass.xlsx", header= 1)
Super_Class = dict(zip(df['Super_Class'],df['TWONTO']))

df = pd.read_excel("SPARQL_tag.xlsx", header= 1)
Tag = dict(zip(df['Tag'],df['TWONTO']))

df = pd.read_excel("SPARQL_supertag.xlsx", header= 1)
Super_Tag = dict(zip(df['Super_Tag'],df['TWONTO']))

df = pd.read_excel("SPARQL_category.xlsx", header= 1)
Category = dict(zip(df['Category'],df['TWONTO']))

df = pd.read_excel("SPARQL_supercategory.xlsx", header= 1)
Super_Category = dict(zip(df['Super_Category'],df['TWONTO']))

Tag
# Out:
# {'HU': 'humidier',
#  'CHL': 'chlorinator_system',
#  'OZ': 'ozone_generator',
#  'GB': 'gearbox',
#  'ALR': 'alarm_device',
#  'CLR': 'clarifier',
#  'AE': 'instrument_element',
#  'FM': 'pressurized_sewer_segment',
#  'G': 'channel_gate',
#  'PDP': '600V_insulated_case_electrical_cabinet',
#  'SCAM': 'security_camera',
#  'AMP_x000D_\nPA': 'public_annoucement_speaker',
#  'EV': 'AC_evaporator_unit',
#  'D': 'dehumidifier',
#  'CU': 'ac_condenser_unit',
#  'PDM': 'pulsation_dampener',
#  'CRN': 'crane',
#  'ENG': 'engine',
#  'RD': 'rupture_disc',
#  'PIP': 'pipe_segment',
#  'CI': 'chiller',
#  'CF': 'centrifuge',
#  'AHU': 'air_handler_unit',
#  'SP': 'auto_sampler',
#  'DEF': 'automatic_external_defibrillator',
#  'ELV': 'elevator',
#  'SCBA': 'self-contained_breathing_apparatus',
#  'LS': 'level_switch',
#  'TIT_x000D_\nTT': 'temperature_transmitter',
#  'PWU': 'power_washer',
#  'WIT_x000D_\nWRT_x000D_\nWSC': 'weight_scale',
#  'MH': 'manhole',
#  'DD': 'display_panel',
#  'DR': 'controlled_door_access',
#  'UV': 'UV_disinfection_assembly',
#  'GA': 'instrument_gauge_or_display',
#  'TR': 'transformer',
#  'FE': 'flow_element',
#  'CBL': 'cable_segment',
#  'AM': 'fixed_gas_detector',
#  'DIT': 'slude_density_meter',
#  'STR': 'strainer',
#  'HF': 'power_harmonic_filter',
#  'V_x000D_\nFCV_x000D_\nPCV': 'valve',
#  'SB': 'air_scrubber',
#  'GDR': 'grinder_or_comminutor',
#  'AC': 'air_condition',
#  'LP': '120V-208V_electrical_panel',
#  'HE': 'heat_exchanger',
#  'CPU': 'computer',
#  'OIT': 'SCADA_computer_terminal',
#  'AIT': 'instrument_transmitter',
#  'TE': 'temperature_sensor_element',
#  'INJ': 'ejector',
#  'ZIT_x000D_\nZRT_x000D_\nZT': 'position_sensing_instrument',
#  'DT': 'condensate_trap',
#  'CL': 'classifier',
#  'FX': 'flame_arrestor',
#  'OTF': 'outfall_or_discharge_point',
#  'BUS_x000D_\nSWG': '5kV_electrical_cabinet',
#  'DU': 'air_duct_segment',
#  'HYD': 'hydrant',
#  'DCU': 'dust_collector',
#  'PIT_x000D_\nPT': 'pressure_transmitter',
#  'SC': 'screen',
#  'BAT': 'battery',
#  'MX': 'mixer_or_agitator',
#  'UPS': 'UPS',
#  'FU': 'furnace',
#  'RES': 'reservoir_tank',
#  'VAV': 'variable_air_volume_unit',
#  'BU': 'burner_component_of_asset',
#  'FIT_x000D_\nFT': 'flow_transmitter',
#  'BUS': 'electrical_panel_or_cabinet',
#  'DS': 'disconnect_switch',
#  'FS': 'flow_switch',
#  'HTR': 'heater',
#  'GEN': 'generator-set',
#  'WEL': 'well',
#  'CM': 'collector_mechanism',
#  'CAP': 'capacitor',
#  'LE': 'level_sensor_element',
#  'CMP': 'compactor',
#  'BL_x000D_\nFN': 'blower',
#  'CT': 'controller',
#  'P': 'pump_-_without_drive',
#  'DP': 'material_distribution_panel',
#  'SERV': 'server_appliance',
#  'm': 'motor',
#  'QUEN': 'quencher',
#  'AFR': 'protection_relay',
#  'CP': 'process_control_panel',
#  'TS': 'transfer_switch',
#  'RX': 'reactor',
#  'TPD': 'trap_priming_device',
#  'INQ': 'instrumentation',
#  'LAG': 'ash_lagoon',
#  'T': 'storage_tank',
#  'WR': 'welding_receptacle',
#  'VIT': 'vibration_analyzer',
#  'RPU_x000D_\nRTU': 'RTU',
#  'C': 'compressor',
#  'DM': 'air_damper',
#  'ST': 'motor_starter',
#  'SPL': 'spill_kit',
#  'XSH': 'torque_switch',
#  'BO': 'boiler',
#  'CV': 'conveyor',
#  'CH': 'equipment_or_access_chamber',
#  'HPU': 'hydraulic_power_pack',
#  'SM': 'large_stationary_tool',
#  'MON': 'display_panel',
#  'LRT_x000D_\nLIT_x000D_\nLT': 'level_transmitter',
#  'VSS': 'surge_suppressor',
#  'BFP': 'backflow_preventer',
#  'FA': 'annunciator_panel',
#  'FAK': 'first_aid_kit',
#  'LDR': 'ladder',
#  'RC': 'data_logger',
#  'GRF': 'ground_and_test_device',
#  'SEN': 'instrument_element'}

# %% [markdown]
# ## SQL connection
# The next step connects to the Avantis SQL server to get the list of entities

# %%
import pyodbc
import os
from sqlalchemy.engine import URL
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

sns.set_theme()

connect = 'DSN=Avantis6-P;UID='+ os.environ['Avantis_User'] + ';PWD=' + os.environ['Avantis_Pass']
connection_url = URL.create("mssql+pyodbc", query={"odbc_connect": connect})

engine = create_engine(connection_url)

SQL1 = """SELECT Distinct MAINTENT.id as [Entity_number],
[MAINTENT].[aenm] as [Description],
MAINTENT2.id as [Parent],
MAINTENT2.aenm as [Parent_Description],
[contname] as [Category],
[entclsid] as [Class],
SUSPEND.suspoi as [Suspended]

FROM  [AvantisP].[mc].[MAINTENT]
	  Left Join [AvantisP].[mc].[ENTCLASS] on MAINTENT.entclsref_oi = ENTCLASS.entcloi
	  Left Join [AvantisP].[mc].CATVAL ON MAINTENT.cat1_oi = CATVAL.cvoi
	  Left Join MC.SUSPEND ON MAINTENT.susp_oi = SUSPEND.suspoi
	  Left Join MC.MELINK ON MAINTENT.mtnoi = MELINK.mtnchild_oi
	  Left Join MC.MAINTENT MAINTENT2 ON MELINK.mtnparn_oi = MAINTENT2.mtnoi"""


df1 = pd.read_sql(SQL1,engine)
df1 = df1[df1['Entity_number'].values != None]
df1['Tag'] = df1['Entity_number'].str.extract(r"-([a-zA-Z]+)-\d+")
df1
# Out:
#                Entity_number  \
# 0         \tFCL_ELS_CBL_001D
# 1         \tFCL_ELS_CBL_001F
# 2         \tFCL_ELS_CBL_001G
# 3         \tFCL_ELS_CBL_001H
# 4         \tFCL_ELS_CBL_003F
# ...                      ...
# 147871               YX2413A
# 147872           ZDATA PILOT
# 147873       ZXDP ENTITY COL
# 147874        ZXDP OTHER COL
# 147875  ZXDP WTR CH LOCN ORO
#
#                                               Description  \
# 0       Electrical Power Line,4.16KV,From BUS-00B1-A t...
# 1       Electrical Power Line,4.16KV,From BUS-00B1 to ...
# 2       Electrical Power Line,4.16KV,From BUS-00B1 to ...
# 3       Electrical Power Line,4.16KV,From BUS-00B1 to ...
# 4       Electrical Power Line,4.16KV,From BUS-00B2 to ...
# ...                                                   ...
# 147871                  Pump, Dewatering, Old PS House #3
# 147872                                   ZCity of Toronto
# 147873                       DO NOT USE - City of Toronto
# 147874                     DO NOT USE - DP Other Entities
# 147875                 DO NOT USE - Toronto Water Chamber
#
#                       Parent  \
# 0       FCL_ELS_4.16KV_LINES
# 1       FCL_ELS_4.16KV_LINES
# 2       FCL_ELS_4.16KV_LINES
# 3       FCL_ELS_4.16KV_LINES
# 4       FCL_ELS_4.16KV_LINES
# ...                      ...
# 147871        TAB-PRM-P-SUMP
# 147872                  None
# 147873                  None
# 147874                  None
# 147875              MAIN-001
#
#                                        Parent_Description  \
# 0                            Electrical Power Line,4.16KV
# 1                            Electrical Power Line,4.16KV
# 2                            Electrical Power Line,4.16KV
# 3                            Electrical Power Line,4.16KV
# 4                            Electrical Power Line,4.16KV
# ...                                                   ...
# 147871  P Bldg & Old PS Buildings, Primary Treatment S...
# 147872                                               None
# 147873                                               None
# 147874                                               None
# 147875                                           Main 001
#
#                               Category                  Class  Suspended  Tag
# 0                    Air Handling Unit  Electrical Power Line        NaN  NaN
# 1                    Air Handling Unit  Electrical Power Line        NaN  NaN
# 2                    Air Handling Unit  Electrical Power Line        NaN  NaN
# 3                    Air Handling Unit  Electrical Power Line        NaN  NaN
# 4                    Air Handling Unit  Electrical Power Line        NaN  NaN
# ...                                ...                    ...        ...  ...
# 147871  Pump,Non Positive Displacement                   Pump        NaN  NaN
# 147872                            None                   None    39026.0  NaN
# 147873                            None                   None        NaN  NaN
# 147874                            None                   None        NaN  NaN
# 147875               Air Handling Unit                Chamber        NaN  NaN
#
# [147876 rows x 8 columns]

# %%
#df1 = df1[df1['Suspended'].isna()]

# %%
entityMatch = pd.DataFrame()
entityMatch['Entity_number'] = df1['Entity_number'] 
entityMatch['Class_Match'] = [Class.get(x,"") for x in df1['Class']]
entityMatch['Super_Class_Match'] = [Super_Class.get(x,"") for x in df1['Class']]
entityMatch['Tag_Match'] = [Tag.get(x,"") for x in df1['Tag']]
entityMatch['Super_Tag_Match'] = [Super_Tag.get(x,"") for x in df1['Tag']]
entityMatch['Category_Match'] = [Category.get(x,"") for x in df1['Category']]
entityMatch['Super_Category_Match'] = [Super_Category.get(x,"") for x in df1['Category']]
entityMatch
# Out:
#                Entity_number                  Class_Match Super_Class_Match  \
# 0         \tFCL_ELS_CBL_001D                                  cable_segment
# 1         \tFCL_ELS_CBL_001F                                  cable_segment
# 2         \tFCL_ELS_CBL_001G                                  cable_segment
# 3         \tFCL_ELS_CBL_001H                                  cable_segment
# 4         \tFCL_ELS_CBL_003F                                  cable_segment
# ...                      ...                          ...               ...
# 147871               YX2413A         pump_-_without_drive
# 147872           ZDATA PILOT
# 147873       ZXDP ENTITY COL
# 147874        ZXDP OTHER COL
# 147875  ZXDP WTR CH LOCN ORO  equipment_or_access_chamber
#
#        Tag_Match Super_Tag_Match Category_Match Super_Category_Match
# 0                                                   air_handler_unit
# 1                                                   air_handler_unit
# 2                                                   air_handler_unit
# 3                                                   air_handler_unit
# 4                                                   air_handler_unit
# ...          ...             ...            ...                  ...
# 147871
# 147872
# 147873
# 147874
# 147875                                              air_handler_unit
#
# [147876 rows x 7 columns]

# %%
counts = [entityMatch['Class_Match'] != ""]
counts.append(counts[0] | (entityMatch['Super_Class_Match'] != ""))
counts.append(counts[1] | (entityMatch['Tag_Match'] != ""))
counts.append(counts[2] | (entityMatch['Super_Tag_Match'] != ""))
counts.append(counts[3] | (entityMatch['Category_Match'] != ""))
counts.append(counts[4] | (entityMatch['Super_Category_Match'] != ""))

for row in counts:
    print(sum(row)/len(row)*100)
# Out:
# 76.04614677161946
# 76.91308934512699
# 80.73588682409586
# 81.37696448375667
# 84.3483729611296
# 84.74262219697584

# %%
entityMatch.groupby('Class_Match').count()['Entity_number'].sort_values(ascending=False)
# Out:
# Class_Match
# valve                       44168
#                             35422
# instrument_transmitter       8691
# manhole                      5901
# computer                     5216
#                             ...
# quencher                        3
# vortex_classifier               3
# UV_disinfection_assembly        2
# boat                            1
# network_switch                  1
# Name: Entity_number, Length: 93, dtype: int64

# %%
Tag
# Out:
# {'HU': 'humidier',
#  'CHL': 'chlorinator_system',
#  'OZ': 'ozone_generator',
#  'GB': 'gearbox',
#  'ALR': 'alarm_device',
#  'CLR': 'clarifier',
#  'AE': 'instrument_element',
#  'FM': 'pressurized_sewer_segment',
#  'G': 'channel_gate',
#  'PDP': '600V_insulated_case_electrical_cabinet',
#  'SCAM': 'security_camera',
#  'AMP_x000D_\nPA': 'public_annoucement_speaker',
#  'EV': 'AC_evaporator_unit',
#  'D': 'dehumidifier',
#  'CU': 'ac_condenser_unit',
#  'PDM': 'pulsation_dampener',
#  'CRN': 'crane',
#  'ENG': 'engine',
#  'RD': 'rupture_disc',
#  'PIP': 'pipe_segment',
#  'CI': 'chiller',
#  'CF': 'centrifuge',
#  'AHU': 'air_handler_unit',
#  'SP': 'auto_sampler',
#  'DEF': 'automatic_external_defibrillator',
#  'ELV': 'elevator',
#  'SCBA': 'self-contained_breathing_apparatus',
#  'LS': 'level_switch',
#  'TIT_x000D_\nTT': 'temperature_transmitter',
#  'PWU': 'power_washer',
#  'WIT_x000D_\nWRT_x000D_\nWSC': 'weight_scale',
#  'MH': 'manhole',
#  'DD': 'display_panel',
#  'DR': 'controlled_door_access',
#  'UV': 'UV_disinfection_assembly',
#  'GA': 'instrument_gauge_or_display',
#  'TR': 'transformer',
#  'FE': 'flow_element',
#  'CBL': 'cable_segment',
#  'AM': 'fixed_gas_detector',
#  'DIT': 'slude_density_meter',
#  'STR': 'strainer',
#  'HF': 'power_harmonic_filter',
#  'V_x000D_\nFCV_x000D_\nPCV': 'valve',
#  'SB': 'air_scrubber',
#  'GDR': 'grinder_or_comminutor',
#  'AC': 'air_condition',
#  'LP': '120V-208V_electrical_panel',
#  'HE': 'heat_exchanger',
#  'CPU': 'computer',
#  'OIT': 'SCADA_computer_terminal',
#  'AIT': 'instrument_transmitter',
#  'TE': 'temperature_sensor_element',
#  'INJ': 'ejector',
#  'ZIT_x000D_\nZRT_x000D_\nZT': 'position_sensing_instrument',
#  'DT': 'condensate_trap',
#  'CL': 'classifier',
#  'FX': 'flame_arrestor',
#  'OTF': 'outfall_or_discharge_point',
#  'BUS_x000D_\nSWG': '5kV_electrical_cabinet',
#  'DU': 'air_duct_segment',
#  'HYD': 'hydrant',
#  'DCU': 'dust_collector',
#  'PIT_x000D_\nPT': 'pressure_transmitter',
#  'SC': 'screen',
#  'BAT': 'battery',
#  'MX': 'mixer_or_agitator',
#  'UPS': 'UPS',
#  'FU': 'furnace',
#  'RES': 'reservoir_tank',
#  'VAV': 'variable_air_volume_unit',
#  'BU': 'burner_component_of_asset',
#  'FIT_x000D_\nFT': 'flow_transmitter',
#  'BUS': 'electrical_panel_or_cabinet',
#  'DS': 'disconnect_switch',
#  'FS': 'flow_switch',
#  'HTR': 'heater',
#  'GEN': 'generator-set',
#  'WEL': 'well',
#  'CM': 'collector_mechanism',
#  'CAP': 'capacitor',
#  'LE': 'level_sensor_element',
#  'CMP': 'compactor',
#  'BL_x000D_\nFN': 'blower',
#  'CT': 'controller',
#  'P': 'pump_-_without_drive',
#  'DP': 'material_distribution_panel',
#  'SERV': 'server_appliance',
#  'm': 'motor',
#  'QUEN': 'quencher',
#  'AFR': 'protection_relay',
#  'CP': 'process_control_panel',
#  'TS': 'transfer_switch',
#  'RX': 'reactor',
#  'TPD': 'trap_priming_device',
#  'INQ': 'instrumentation',
#  'LAG': 'ash_lagoon',
#  'T': 'storage_tank',
#  'WR': 'welding_receptacle',
#  'VIT': 'vibration_analyzer',
#  'RPU_x000D_\nRTU': 'RTU',
#  'C': 'compressor',
#  'DM': 'air_damper',
#  'ST': 'motor_starter',
#  'SPL': 'spill_kit',
#  'XSH': 'torque_switch',
#  'BO': 'boiler',
#  'CV': 'conveyor',
#  'CH': 'equipment_or_access_chamber',
#  'HPU': 'hydraulic_power_pack',
#  'SM': 'large_stationary_tool',
#  'MON': 'display_panel',
#  'LRT_x000D_\nLIT_x000D_\nLT': 'level_transmitter',
#  'VSS': 'surge_suppressor',
#  'BFP': 'backflow_preventer',
#  'FA': 'annunciator_panel',
#  'FAK': 'first_aid_kit',
#  'LDR': 'ladder',
#  'RC': 'data_logger',
#  'GRF': 'ground_and_test_device',
#  'SEN': 'instrument_element'}

# %%
df1[[not x for x in counts[5]]].to_csv("test.csv")

# %%
df1['Class'].isna().sum()
df1[[not x for x in counts[5]]][df1[[not x for x in counts[5]]]['Tag']=='PS']
# Out:
#             Entity_number                                        Description  \
# 7706      COL-RBB-PS-0001                                   Power Supply, DC
# 22814     COL-RBB-PS-0001                                   Power Supply, DC
# 22897     FHO-AMT-PS-0001  Power Supply, Inverter, Weather Monitoring Sta...
# 24502     FHO-DOZ-PS-1150  Power Supply Unit, Ozone Generator OZ-1100, Oz...
# 25439     FHO-ELS-PS-0004                                 Solar Power system
# ...                   ...                                                ...
# 125218  THC-ELS-PS-0003-L  Emergency Power Equipment, Diesel & UPS, Build...
# 125219  THC-ELS-PS-0003-M  Emergency Power Equipment, Diesel & UPS, Build...
# 125220  THC-ELS-PS-0003-O  Emergency Power Equipment, Diesel & UPS, Build...
# 145533    WTR-PMI-PS-0003  Switch, Pressure, Low/High, Discharge, Distric...
# 146254    WTR-PSA-PS-0002  Switch, Pressure-High/Pressure-Low, Line to Di...
#
#                  Parent                                 Parent_Description  \
# 7706       COL-RBB-MISC                            Miscellaneous Equipment
# 22814           COL-RBB        Western Beaches Tunnel (Battery Park)-Storm
# 22897   FHO-ELS-PS-0004                                 Solar Power system
# 24502   FHO-DOZ-OZ-1100  Ozonator, Ozone Generator 1, Ozone Building, L...
# 25439   FHO WORK AREA 2                                           Services
# ...                 ...                                                ...
# 125218  THC-ELS-PS-0003                                  Power supply, UPS
# 125219  THC-ELS-PS-0003                                  Power supply, UPS
# 125220  THC-ELS-PS-0003                                  Power supply, UPS
# 145533      WTR-PMI-TRW                       Treated Water (Transmission)
# 146254      WTR-PSA-TRW                       Treated Water (Transmission)
#
#                             Category                     Class  Suspended Tag
# 7706    Uninterruptible Power Supply                      None        NaN  PS
# 22814   Uninterruptible Power Supply                      None        NaN  PS
# 22897                           None  Power Distribution Panel        NaN  PS
# 24502          Generator,Electricity                    Switch        NaN  PS
# 25439                           None                      None        NaN  PS
# ...                              ...                       ...        ...  ..
# 125218                          None                      None        NaN  PS
# 125219                          None                      None        NaN  PS
# 125220                          None                      None        NaN  PS
# 145533                        Switch                    Switch        NaN  PS
# 146254                        Switch                    Switch        NaN  PS
#
# [81 rows x 8 columns]

# %%
excel_class = ["Control Panel,MCC"]

with pd.ExcelWriter('missing.xlsx', engine='openpyxl', mode='w') as writer:
   for Value in excel_class:  
      df1[df1['Class'] == Value].to_excel(writer, sheet_name = Value.replace(" ", "_"))
   
   df1[df1['Class'].isna()].to_excel(writer, sheet_name = "None")

# %%
df1[df1['Class'].isna()]
# Out:
#                     Entity_number  \
# 11               \tTAB_EL1_L_1501
# 12               \tTAB_EL1_L_1504
# 14                          16821
# 15                          16825
# 16                          16856
# ...                           ...
# 147835                    YTF-NGS
# 147863                     YTF-SS
# 147872                ZDATA PILOT
# 147873            ZXDP ENTITY COL
# 147874             ZXDP OTHER COL
#
#                                               Description  \
# 11      Electrical Power Line,EL1-BUS-1501,EL1-TR-1501...
# 12      Electrical Power Line,EL1-BUS-1502,EL1-TR-1504...
# 14                                       Raw Water Intake
# 15                                        Raw Water Flume
# 16                          Emergency Power, Diesel & UPS
# ...                                                   ...
# 147835                                  HVAC, Natural Gas
# 147863                                   Security Systems
# 147872                                   ZCity of Toronto
# 147873                       DO NOT USE - City of Toronto
# 147874                     DO NOT USE - DP Other Entities
#
#                       Parent                             Parent_Description  \
# 11      TAB_EL1_13.8KV_LINES  Electrical Power Line,13.8KV,North Substation
# 12      TAB_EL1_13.8KV_LINES  Electrical Power Line,13.8KV,North Substation
# 14                    FIS-RW                           Raw Water Production
# 15                    FIS-RW                           Raw Water Production
# 16                   FIS-ELS         System, Electrical Distribution System
# ...                      ...                                            ...
# 147835              YTF-BLDG                              Bullding Services
# 147863                   YTF                           Tiffield Data Center
# 147872                  None                                           None
# 147873                  None                                           None
# 147874                  None                                           None
#
#        Category Class  Suspended  Tag
# 11         None  None        NaN  NaN
# 12         None  None        NaN  NaN
# 14         None  None        NaN  NaN
# 15         None  None        NaN  NaN
# 16         None  None        NaN  NaN
# ...         ...   ...        ...  ...
# 147835     None  None        NaN  NaN
# 147863     None  None        NaN  NaN
# 147872     None  None    39026.0  NaN
# 147873     None  None        NaN  NaN
# 147874     None  None        NaN  NaN
#
# [8017 rows x 8 columns]
